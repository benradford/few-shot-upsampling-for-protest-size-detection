# %%
import os
import re
import json
import string
import numpy as np
import tensorflow as tf
from pprint import pprint
from tensorflow import keras
from tensorflow.keras import layers
from tokenizers import BertWordPieceTokenizer
from transformers import RobertaTokenizer, RobertaTokenizerFast, TFRobertaModel
from tensorflow import keras
import jsonlines

tf.random.set_seed(1234)
np.random.seed(1234)

# %% [markdown]
# # Load Data

# %%
seq_len = 450
max_len = 512

###################
## TRAINING DATA ##
###################
ccc_train = []

with open('../data/ccc_train.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    ccc_train.append(json.loads(json_str))

for ex in ccc_train:
    ex["text"] = " ".join(ex["text"].split())
    ex["size_text"] = " ".join(ex["size_text"].split())

print(f"Training examples from raw data: {len(ccc_train)}")
ccc_train = [a for a in ccc_train if a["size_text"].lower() in a["text"].lower()]
print(f"Training examples after removing unmatched size_text strings: {len(ccc_train)}")


######################
## SPAN TUNING DATA ##
######################
ccc_tune = []

with open('../data/ccc_span_tune.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    ccc_tune.append(json.loads(json_str))

for ex in ccc_tune:
    ex["para"] = " ".join(ex["para"].split())
    ex["size_text"] = " ".join(ex["size_text"].split())    

print(f"Span tune examples in raw data: {len(ccc_tune)}")
ccc_tune = [a for a in ccc_tune if a["size_text"].lower() in a["para"].lower()]
print(f"Span tune examples after removing unmatched size_text strings: {len(ccc_tune)}")

ccc_tune = {"data":[{"paragraphs":[{"context":qq["para"],
                             "qas":[
                                 {"answers":[{"answer_start":qq["para"].lower().index(qq["size_text"].lower()),
                                              "text":qq["size_text"]}],
                                  "question":"How many people protested?"}
                             ]}]} for qq in ccc_tune]}


##################
## TESTING DATA ##
##################
ccc_test = []

with open('../data/ccc_test_set.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    ccc_test.append(json.loads(json_str))
    
for ex in ccc_test:
    ex["text"] = " ".join(ex["text"].split())
    ex["size_text"] = " ".join(ex["size_text"].split())
    
print(f"Testing examples from raw data: {len(ccc_test)}")
ccc_test = [a for a in ccc_test if a["size_text"].lower() in a["text"].lower()]
print(f"Testing examples after removing unmatched size_text strings: {len(ccc_test)}")

ccc_test = {"data":[{"paragraphs":[{"context":" ".join(qq["text"].split()),
                             "qas":[
                                 {"answers":[{"answer_start":qq["text"].lower().index(qq["size_text"].lower()),
                                              "text":qq["size_text"]}],
                                  "question":"How many people protested?"}
                             ]}]} for qq in ccc_test]}

#####################
## VALIDATION DATA ##
#####################
ccc_valid = []

with open('../data/ccc_validation_set.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    ccc_valid.append(json.loads(json_str))
    
for ex in ccc_valid:
    ex["text"] = " ".join(ex["text"].split())
    ex["size_text"] = " ".join(ex["size_text"].split())
    
print(f"Valid examples from raw data: {len(ccc_valid)}")
ccc_valid = [a for a in ccc_valid if a["size_text"].lower() in a["text"].lower()]
print(f"Valid examples after removing unmatched size_text strings: {len(ccc_valid)}")

ccc_valid = {"data":[{"paragraphs":[{"context":" ".join(qq["text"].split()),
                             "qas":[
                                 {"answers":[{"answer_start":qq["text"].lower().index(qq["size_text"].lower()),
                                              "text":qq["size_text"]}],
                                  "question":"How many people protested?"}
                             ]}]} for qq in ccc_valid]}

########################
## SOFT-LABELED TRAIN ##
########################
soft_train = []

with open('../data/soft_labeled_train.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    soft_train.append(json.loads(json_str))
    
for ex in soft_train:
    ex["context"] = " ".join(ex["context"].split())
    ex["labeled_text"] = " ".join(ex["labeled_text"].split())
    
print(f"Soft examples from raw data: {len(soft_train)}")
soft_train = [a for a in soft_train if a["labeled_text"].lower() in a["context"].lower()]
print(f"Soft examples after removing unmatched size_text strings: {len(soft_train)}")

soft_train = {"data":[{"paragraphs":[{"context":" ".join(qq["context"].split()),
                             "qas":[
                                 {"answers":[{"answer_start":qq["context"].lower().index(qq["labeled_text"].lower()),
                                              "text":qq["labeled_text"]}],
                                  "question":"How many people protested?"}
                             ]}]} for qq in soft_train]}

#########################
## TOKENIZER AND MODEL ##
#########################

tokenizer = RobertaTokenizerFast.from_pretrained("roberta-base")
# Out:
# Training examples from raw data: 2694
# Training examples after removing unmatched size_text strings: 2685
# Span tune examples in raw data: 25
# Span tune examples after removing unmatched size_text strings: 25
# Testing examples from raw data: 930
# Testing examples after removing unmatched size_text strings: 925
# Valid examples from raw data: 200
# Valid examples after removing unmatched size_text strings: 200
# Soft examples from raw data: 2694
# Soft examples after removing unmatched size_text strings: 2351

# %% [markdown]
# # Prepare Data

# %%
class SquadExample:
    def __init__(self, question, context, start_char_idx, answer_text, all_answers, seq_len, max_len):
        
        # Clean context, answer and question
        context = " ".join(str(context).split())
        question = " ".join(str(question).split())
        answer = " ".join(str(answer_text).split())

        self.question = str(question)
        self.context = str(context)
        self.start_char_idx = start_char_idx
        self.answer_text = str(answer)
        self.all_answers = all_answers
        self.max_len = max_len
        self.seq_len = seq_len
        self.skip_doc = False
        
        self.input_ids = None
        self.attention_mask = None
        self.token_type_ids = None
        self.start_token_idx = None
        self.end_token_idx = None
        self.skip = None
        
    def __str__(self):
        print(np.stack(self.input_ids).shape)
        print(np.stack(self.token_type_ids).shape)
        print(np.stack(self.attention_mask).shape)
        return "<SquadExample>"
        
    def __repr__(self):
        return repr({"input_ids":self.input_ids, 
                     "token_type_ids":self.token_type_ids, 
                     "attention_mask":self.attention_mask,
                     "start_token_idx":self.start_token_idx,
                     "end_token_idx":self.end_token_idx,
                     "skip":self.skip})

    def preprocess(self):
        context = self.context
        question = self.question
        answer = self.answer_text
        start_char_idx = self.start_char_idx

        # Find end character index of answer in context
        end_char_idx = start_char_idx + len(answer)
        if (end_char_idx >= len(context)) or (start_char_idx < 0):
            self.skip_doc = True
            return

        # Mark the character indexes in context that are in answer
        is_char_in_ans = [0] * len(context)
        for idx in range(start_char_idx, end_char_idx):
            is_char_in_ans[idx] = 1
            
        # Tokenize context
        tokenized_context = tokenizer(context, return_offsets_mapping=True)
        
        context_input_ids = tokenized_context.input_ids
        context_offset_mapping = tokenized_context.offset_mapping
        context_attention_mask = tokenized_context.attention_mask
        
        self.context_input_ids = context_input_ids
        self.context_offset_mapping = context_offset_mapping
        
        # Find tokens that were created from answer characters
        ans_token_idx = []
        for idx, (start, end) in enumerate(context_offset_mapping):
            if sum(is_char_in_ans[start:end]) > 0:
                ans_token_idx.append(idx)

#         if len(ans_token_idx) == 0:
#             self.skip_doc = True
#             return
        if (len(ans_token_idx) == 0):
            ans_token_idx = [-1]

        # Find start and end token index for tokens from answer
        start_token_idx = ans_token_idx[0]
        end_token_idx = ans_token_idx[-1]
        
        self.start_token_idx_master = start_token_idx
        self.end_token_idx_master = end_token_idx
        
        # Tokenize question
        tokenized_question = tokenizer("</s> "+question, return_offsets_mapping=True)
        
        ## Crop start and end tokens
        question_input_ids = tokenized_question.input_ids[1:]
        context_input_ids = context_input_ids[1:-1]

        ##
        ## SPLIT UP CONTEXT INTO MULTIPLE QUESTIONS OF max_len
        ##
        
        if seq_len >= len(context_input_ids):
            offsets = [0]
        else:
            ii = 0
            offsets = []
            while (ii+seq_len) <= len(context_input_ids):
                offsets.append(ii)
                ii = ii + round(seq_len/2)
            offsets = offsets + [len(context_input_ids)-seq_len]
        
        list_input_ids = []
        list_start_token_idx = []
        list_end_token_idx = []
        list_attention_mask = []
        list_token_type_ids = []
        list_skip = []
        
        for ii in offsets:
            subcontext_input_ids = [0]+context_input_ids[ii:(ii+seq_len)]+question_input_ids
            subcontext_start_token_idx = start_token_idx - ii
            subcontext_end_token_idx = end_token_idx - ii
            subcontext_padding = [0] * (self.max_len - len(subcontext_input_ids))
            
            subcontext_attention_mask = [1] * len(subcontext_input_ids) + subcontext_padding
            subcontext_token_type_ids = [0] + [0]*len(context_input_ids[ii:(ii+seq_len)]) + [1]*len(question_input_ids) + (np.array(subcontext_padding)+1).tolist()
            subcontext_input_ids = subcontext_input_ids + (np.array(subcontext_padding)+1).tolist()
            
            if (subcontext_start_token_idx >= 0) and (subcontext_end_token_idx < seq_len):
                skip = False
            else:
                subcontext_start_token_idx = 0
                subcontext_end_token_idx = 0
                skip = False
                
            list_input_ids.append(subcontext_input_ids)
            list_attention_mask.append(subcontext_attention_mask)
            list_token_type_ids.append(subcontext_token_type_ids)
            list_start_token_idx.append(subcontext_start_token_idx)
            list_end_token_idx.append(subcontext_end_token_idx)
            list_skip.append(skip)
        
        self.input_ids = (list_input_ids)
        self.attention_mask = (list_attention_mask)
        self.token_type_ids = (list_token_type_ids)
        self.start_token_idx = (list_start_token_idx)
        self.end_token_idx = (list_end_token_idx)
        self.skip = list_skip
        self.example_offset = offsets
        
    def train_examples(self, include_impossible=False):
        for idx, skip_ex in enumerate(self.skip):
            if include_impossible is False:
                if skip_ex is False:
                    yield  {"input_ids":self.input_ids[idx],
                            "token_type_ids":self.token_type_ids[idx],
                            "attention_mask":self.attention_mask[idx],
                            "start_token_idx":self.start_token_idx[idx],
                            "end_token_idx":self.end_token_idx[idx]}
            else:
                yield  {"input_ids":self.input_ids[idx],
                            "token_type_ids":self.token_type_ids[idx],
                            "attention_mask":self.attention_mask[idx],
                            "start_token_idx":self.start_token_idx[idx],
                            "end_token_idx":self.end_token_idx[idx]}
    
    
    def inference_from_onehot(self, pred_start, pred_end):

#         if force_answer == False:
        if (np.max(np.argmax(pred_start, axis=1)) == 0) and (np.max(np.argmax(pred_end, axis=1)) == 0):
            return("", {"all_answers":self.all_answers,
                        "start_token_pred":-1, 
                        "end_token_pred":-1, 
                        "start_char_pred":-1, 
                        "end_char_pred":-1,
                        "start_token":self.start_token_idx_master,
                        "end_token":self.end_token_idx_master,
                        "tokens_pred":set(list([])),
                        "tokens":set(list(range(self.start_token_idx_master,(self.end_token_idx_master+1))))})
        
        seq_len = min(self.seq_len, len(self.context_input_ids))
        
        pred_start_matrix = np.zeros((len(self.input_ids), len(self.context_input_ids)))
        pred_end_matrix = np.zeros((len(self.input_ids), len(self.context_input_ids)))
        
        for idx, value in enumerate(pred_start):
            offset = self.example_offset[idx]+1
            pred_start_sub = pred_start[idx][1:seq_len]
            pred_end_sub   = pred_end[idx][1:seq_len]
            pred_start_matrix[idx,(offset):(offset+seq_len-1)] = pred_start_sub
            pred_end_matrix[idx,(offset):(offset+seq_len-1)] = pred_end_sub
            
        highest_prob = np.argmax(np.max(pred_start_matrix, axis=1) + np.max(pred_end_matrix, axis=1))
        
        top_start = np.argmax(pred_start_matrix[highest_prob,:])
        top_end   = np.argmax(pred_end_matrix[highest_prob,:])
        
#         pred_start = np.max(pred_start_matrix, axis=0)
#         pred_end   = np.max(pred_end_matrix, axis=0)
        
#         top_start = np.argmax(pred_start)
#         top_end = np.argmax(pred_end)
        
        start_char = self.context_offset_mapping[top_start][0]
        end_char = self.context_offset_mapping[top_end][1]
        
        return (self.context[start_char:end_char], {"all_answers":self.all_answers,
                                                    "start_token_pred":top_start, 
                                                    "end_token_pred":top_end, 
                                                    "start_char_pred":start_char, 
                                                    "end_char_pred":end_char,
                                                    "start_token":self.start_token_idx_master,
                                                    "end_token":self.end_token_idx_master,
                                                    "tokens_pred":set(list(range(top_start,(top_end+1)))),
                                                    "tokens":set(list(range(self.start_token_idx_master,(self.end_token_idx_master+1))))})
                
    def model_inference(self, model):
        pred = model.predict([np.stack(self.input_ids),
                      np.stack(self.attention_mask),
                      np.stack(self.token_type_ids)], batch_size=8)
        pred_start = pred[0]
        pred_end   = pred[1]
        
        return self.inference_from_onehot(pred_start, pred_end)
    
    def fake_inference(self):
        pred_start_mat = []
        pred_end_mat = []
        for idx, val in enumerate(self.start_token_idx):
            pred_start = np.zeros_like(np.array(self.input_ids[idx]))
            pred_end = np.zeros_like(np.array(self.input_ids[idx]))
            if self.skip[idx] == False:
                pred_start[val] = 1.0
                pred_end[self.end_token_idx[idx]] = 1.0
            pred_start_mat.append(pred_start)
            pred_end_mat.append(pred_end)
            
        pred_start_mat = np.array(pred_start_mat)
        pred_end_mat = np.array(pred_end_mat)
        
        return self.inference_from_onehot(pred_start_mat,pred_end_mat)
        

def create_squad_examples(raw_data, seq_len, max_len):
    squad_examples = []
    for item in raw_data["data"]:
        for para in item["paragraphs"]:
            context = para["context"]
            for qa in para["qas"]:
                if len(qa["answers"]) > 0:
                    question = qa["question"]
                    answer_text = qa["answers"][0]["text"]
                    all_answers = [_["text"] for _ in qa["answers"]]
                    start_char_idx = qa["answers"][0]["answer_start"]
                    squad_eg = SquadExample(
                        question, context, start_char_idx, answer_text, all_answers, seq_len, max_len
                    )
                    squad_eg.preprocess()
                    squad_examples.append(squad_eg)
                else:
                    question = qa["question"]
                    answer_text = ""
                    all_answers = [""]
                    start_char_idx = 0
                    squad_eg = SquadExample(
                        question, context, start_char_idx, answer_text, all_answers, seq_len, max_len
                    )
                    squad_eg.preprocess()
                    squad_examples.append(squad_eg)
    return squad_examples


def create_inputs_targets(squad_examples, include_impossible=False):
    dataset_dict = {
        "input_ids": [],
        "token_type_ids": [],
        "attention_mask": [],
        "start_token_idx": [],
        "end_token_idx": [],
    }
    for item in squad_examples:
        if item.skip_doc is False:
            for example in item.train_examples(include_impossible):
                for key in dataset_dict:
                    dataset_dict[key].append(np.array(example[key]))
    for key in dataset_dict:
        dataset_dict[key] = np.array(dataset_dict[key])

    x = (
        dataset_dict["input_ids"],
        dataset_dict["token_type_ids"],
        dataset_dict["attention_mask"])
    y = (dataset_dict["start_token_idx"], dataset_dict["end_token_idx"])
    return x, y


def merge_squad_results(squad_examples, start_preds, end_preds):
    ii = 0
    tally = []
    answers = []
    f1_list = []
    for ex in squad_examples:
        if ex.skip_doc is False:
            n_sub = len(ex.skip)
            pred_out = ex.inference_from_onehot(start_preds[ii:(ii+n_sub),:], end_preds[ii:(ii+n_sub),:])
            tally.append(pred_out[0].lower() in [a.lower() for a in ex.all_answers])
            answers.append(pred_out)
            tp = len(pred_out[1]["tokens_pred"].intersection(pred_out[1]["tokens"]))
            fp = len(pred_out[1]["tokens_pred"].difference(pred_out[1]["tokens"]))
            fn = len(pred_out[1]["tokens"].difference(pred_out[1]["tokens_pred"]))
            ii = ii + n_sub
            if tp>0:
                precision = tp/(tp+fp)
                recall=tp/(tp+fn)
                f1_list.append((2*precision*recall)/(precision+recall))
            else:
                f1_list.append(0)
    return (np.mean(tally), 
            np.mean(f1_list), 
            answers)


#train_squad_examples = create_squad_examples(ccc_train, seq_len, max_len)
#x_train, y_train = create_inputs_targets(train_squad_examples)
#print(f"{len(train_squad_examples)} docs, {x_train.shape[0]} training points created.")

test_examples = create_squad_examples(ccc_test, seq_len, max_len)
x_test, y_test = create_inputs_targets(test_examples)
print(f"{len(test_examples)} docs, {x_test[0].shape} test points created.")

valid_examples = create_squad_examples(ccc_valid, seq_len, max_len)
x_valid, y_valid = create_inputs_targets(valid_examples)
print(f"{len(valid_examples)} docs, {x_valid[0].shape} valid points created.")

span_examples = create_squad_examples(ccc_tune, seq_len, max_len)
x_span, y_span = create_inputs_targets(span_examples)
print(f"{len(span_examples)} docs, {x_span[0].shape} span points created.")

soft_examples = create_squad_examples(soft_train, seq_len, max_len)
x_soft, y_soft = create_inputs_targets(soft_examples)
print(f"{len(soft_examples)} docs, {x_soft[0].shape} soft points created.")
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1205 > 512). Running this sequence through the model will result in indexing errors
# 925 docs, (3306, 512) test points created.
# 200 docs, (725, 512) valid points created.
# 25 docs, (25, 512) span points created.
# 2351 docs, (2346, 512) soft points created.

# %% [markdown]
# # Train and Validate

# %%
strategy = tf.distribute.MirroredStrategy()
print("Number of devices: {}".format(strategy.num_replicas_in_sync))

with strategy.scope():
    model = keras.models.load_model('./roberta_base_squad2_512in')
model.summary()
keras.backend.set_value(model.optimizer.learning_rate, (5e-6))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# roberta (TFRobertaMainLayer)    {'last_hidden_state' 124645632   input_1[0][0]
# __________________________________________________________________________________________________
# start_logit (Dense)             (None, 512, 1)       768         roberta[0][0]
# __________________________________________________________________________________________________
# end_logit (Dense)               (None, 512, 1)       768         roberta[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           start_logit[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           end_logit[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 512)          0           flatten[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 512)          0           flatten_1[0][0]
# ==================================================================================================
# Total params: 124,647,168
# Trainable params: 124,647,168
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
pred_start_v, pred_end_v = model.predict((x_valid[0], x_valid[1], x_valid[2]), batch_size=36, verbose=1)
valid_acc = merge_squad_results(valid_examples, pred_start_v, pred_end_v)

pred_start_t, pred_end_t = model.predict((x_test[0], x_test[1], x_test[2]), batch_size=36, verbose=1)
test_acc = merge_squad_results(test_examples, pred_start_t, pred_end_t)

print(f"Validation set accuracy (EM): {valid_acc[0]}")
print(f"Test set accuracy (EM): {test_acc[0]}")
print(f"Validation set F1: {valid_acc[1]}")
print(f"Test set F1: {test_acc[1]}")
# Out:
# 21/21 [==============================] - 5s 261ms/step
# 92/92 [==============================] - 26s 285ms/step
# Validation set accuracy (EM): 0.19
# Test set accuracy (EM): 0.16972972972972972
# Validation set F1: 0.27271624189581933
# Test set F1: 0.2658847892310077

# %%
# validation_loss = []
# validation_accuracy = []
# batch = []
log_list = []

batch_size = 12


for ii in range(75):
    print(f"ITERATION: {ii} of 75.")
#     valid_loss = model.evaluate((x_valid[0],
#                             x_valid[1],
#                             x_valid[2]),
#                             y_valid,
#                            verbose=1,
#                            batch_size=36,
#                            return_dict=True)
#     pred_start, pred_end = model.predict((x_valid[0], x_valid[1], x_valid[2]), batch_size=36, verbose=1)
#     valid_acc = merge_squad_results(valid_examples, pred_start, pred_end)[0]
    
#     print(f"ACCURACY: {valid_acc}")
    
#     validation_loss.append(valid_loss)
#     validation_accuracy.append(valid_acc)
#     batch.append(ii*2)
    
    span_ii = np.random.choice(range(x_span[0].shape[0]), batch_size, replace=True)
    soft_ii = np.random.choice(range(x_soft[0].shape[0]), batch_size, replace=True)
    
    model.fit(
        (x_soft[0][soft_ii,:], 
         x_soft[1][soft_ii,:], 
         x_soft[2][soft_ii,:]),
        (y_soft[0][soft_ii],
         y_soft[1][soft_ii]),
        epochs=1,  # Just one epoch for the rough data
        verbose=1,
        batch_size=batch_size,  # Made this smaller. Bump up.
    )

    log = model.fit(
        (x_span[0][span_ii,:],
         x_span[1][span_ii,:],
         x_span[2][span_ii,:]),
        (y_span[0][span_ii],
         y_span[1][span_ii]),
        epochs=1,  # For demonstration, 3 epochs are recommended
        verbose=1,
        batch_size=batch_size,  # Made this smaller. Bump up.
        validation_data=((x_valid[0],
                                        x_valid[1],
                                        x_valid[2]),
                                        y_valid[0]),
                    validation_batch_size=36
    )
    
    log_list.append(log.history)
    
    
# valid_loss = model.evaluate((x_valid[0],
#                             x_valid[1],
#                             x_valid[2]),
#                             y_valid[0],
#                            verbose=1,
#                            batch_size=36,
#                            return_dict=True)
# pred_start, pred_end = model.predict((x_valid[0], x_valid[1], x_valid[2]), batch_size=36, verbose=1)
# valid_acc = merge_squad_results(valid_examples, pred_start, pred_end)[0]

# validation_loss.append(valid_loss)
# validation_accuracy.append(valid_acc)
# batch.append(ii*2)
# Out:
# ITERATION: 0 of 75.
# WARNING:tensorflow:5 out of the last 5 calls to <function recreate_function.<locals>.restored_function_body at 0x7f0458657268> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function recreate_function.<locals>.restored_function_body at 0x7f0458657268> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# INFO:tensorflow:batch_all_reduce: 198 all-reduces with algorithm = nccl, num_packs = 1
# WARNING:tensorflow:Efficient allreduce is not supported for 3 IndexedSlices
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 198 all-reduces with algorithm = nccl, num_packs = 1
# WARNING:tensorflow:Efficient allreduce is not supported for 3 IndexedSlices
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 2.0301 - loss: 3.7274 - activation_4_loss: 1.6973
# 1/1 [==============================] - 9s 9s/step - activation_5_loss: 0.5222 - loss: 1.9706 - activation_4_loss: 1.4485 - val_activation_5_loss: 2.8964 - val_loss: 4.1715 - val_activation_4_loss: 1.2750
# ITERATION: 1 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.5578 - loss: 1.4272 - activation_4_loss: 0.8694
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.5878 - loss: 1.5902 - activation_4_loss: 1.0025 - val_activation_5_loss: 2.9615 - val_loss: 4.2543 - val_activation_4_loss: 1.2928
# ITERATION: 2 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.5483 - loss: 1.9779 - activation_4_loss: 1.4296
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.1636 - loss: 0.9455 - activation_4_loss: 0.7819 - val_activation_5_loss: 3.0568 - val_loss: 4.4094 - val_activation_4_loss: 1.3526
# ITERATION: 3 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 1.0542 - loss: 2.0967 - activation_4_loss: 1.0425
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.2406 - loss: 1.4072 - activation_4_loss: 1.1666 - val_activation_5_loss: 3.1703 - val_loss: 4.6101 - val_activation_4_loss: 1.4398
# ITERATION: 4 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 1.9053 - loss: 2.7445 - activation_4_loss: 0.8392
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.2062 - loss: 0.8033 - activation_4_loss: 0.5971 - val_activation_5_loss: 3.2753 - val_loss: 4.8040 - val_activation_4_loss: 1.5287
# ITERATION: 5 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 1.1532 - loss: 1.9787 - activation_4_loss: 0.8255
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.1774 - loss: 1.0530 - activation_4_loss: 0.8756 - val_activation_5_loss: 3.3614 - val_loss: 4.9721 - val_activation_4_loss: 1.6108
# ITERATION: 6 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.7653 - loss: 1.6956 - activation_4_loss: 0.9303
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0894 - loss: 0.6283 - activation_4_loss: 0.5389 - val_activation_5_loss: 3.4335 - val_loss: 5.1152 - val_activation_4_loss: 1.6817
# ITERATION: 7 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.5106 - loss: 1.7977 - activation_4_loss: 1.2871
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.1248 - loss: 1.0758 - activation_4_loss: 0.9510 - val_activation_5_loss: 3.4963 - val_loss: 5.2362 - val_activation_4_loss: 1.7400
# ITERATION: 8 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.8354 - loss: 1.7791 - activation_4_loss: 0.9437
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0598 - loss: 0.7439 - activation_4_loss: 0.6841 - val_activation_5_loss: 3.5464 - val_loss: 5.3383 - val_activation_4_loss: 1.7919
# ITERATION: 9 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.4214 - loss: 0.9134 - activation_4_loss: 0.4919
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.1157 - loss: 0.6160 - activation_4_loss: 0.5003 - val_activation_5_loss: 3.5882 - val_loss: 5.4230 - val_activation_4_loss: 1.8348
# ITERATION: 10 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 1.6116 - loss: 3.0131 - activation_4_loss: 1.4015
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0980 - loss: 0.3171 - activation_4_loss: 0.2191 - val_activation_5_loss: 3.6207 - val_loss: 5.4955 - val_activation_4_loss: 1.8748
# ITERATION: 11 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.8407 - loss: 1.2641 - activation_4_loss: 0.4234
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0801 - loss: 0.4003 - activation_4_loss: 0.3202 - val_activation_5_loss: 3.6518 - val_loss: 5.5653 - val_activation_4_loss: 1.9135
# ITERATION: 12 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.4608 - loss: 0.8549 - activation_4_loss: 0.3942
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0680 - loss: 0.3978 - activation_4_loss: 0.3297 - val_activation_5_loss: 3.6808 - val_loss: 5.6297 - val_activation_4_loss: 1.9489
# ITERATION: 13 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.3795 - loss: 0.6993 - activation_4_loss: 0.3198
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.1495 - loss: 0.5118 - activation_4_loss: 0.3623 - val_activation_5_loss: 3.7053 - val_loss: 5.6821 - val_activation_4_loss: 1.9767
# ITERATION: 14 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.3413 - loss: 0.6618 - activation_4_loss: 0.3204
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0809 - loss: 0.5013 - activation_4_loss: 0.4205 - val_activation_5_loss: 3.7336 - val_loss: 5.7366 - val_activation_4_loss: 2.0030
# ITERATION: 15 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.8763 - loss: 1.8508 - activation_4_loss: 0.9745
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.1479 - loss: 0.6340 - activation_4_loss: 0.4861 - val_activation_5_loss: 3.7545 - val_loss: 5.7791 - val_activation_4_loss: 2.0246
# ITERATION: 16 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.3045 - loss: 0.9160 - activation_4_loss: 0.6115
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.1135 - loss: 0.5482 - activation_4_loss: 0.4346 - val_activation_5_loss: 3.7801 - val_loss: 5.8293 - val_activation_4_loss: 2.0492
# ITERATION: 17 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.5401 - loss: 0.7095 - activation_4_loss: 0.1694
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0688 - loss: 0.2828 - activation_4_loss: 0.2140 - val_activation_5_loss: 3.8018 - val_loss: 5.8716 - val_activation_4_loss: 2.0698
# ITERATION: 18 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.0685 - loss: 0.4714 - activation_4_loss: 0.4029
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0583 - loss: 0.1872 - activation_4_loss: 0.1289 - val_activation_5_loss: 3.8205 - val_loss: 5.9040 - val_activation_4_loss: 2.0835
# ITERATION: 19 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.6779 - loss: 1.7115 - activation_4_loss: 1.0335
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0396 - loss: 0.5266 - activation_4_loss: 0.4870 - val_activation_5_loss: 3.8368 - val_loss: 5.9389 - val_activation_4_loss: 2.1021
# ITERATION: 20 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.7154 - loss: 1.4111 - activation_4_loss: 0.6957
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0836 - loss: 0.3177 - activation_4_loss: 0.2341 - val_activation_5_loss: 3.8470 - val_loss: 5.9606 - val_activation_4_loss: 2.1136
# ITERATION: 21 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.0672 - loss: 0.2079 - activation_4_loss: 0.1407
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0770 - loss: 0.2934 - activation_4_loss: 0.2164 - val_activation_5_loss: 3.8562 - val_loss: 5.9766 - val_activation_4_loss: 2.1204
# ITERATION: 22 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.7568 - loss: 1.9303 - activation_4_loss: 1.1735
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0886 - loss: 0.5355 - activation_4_loss: 0.4469 - val_activation_5_loss: 3.8612 - val_loss: 5.9885 - val_activation_4_loss: 2.1273
# ITERATION: 23 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.3048 - loss: 0.8005 - activation_4_loss: 0.4956
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0668 - loss: 0.4919 - activation_4_loss: 0.4251 - val_activation_5_loss: 3.8688 - val_loss: 6.0033 - val_activation_4_loss: 2.1345
# ITERATION: 24 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.7598 - loss: 1.6852 - activation_4_loss: 0.9254
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0505 - loss: 0.3687 - activation_4_loss: 0.3182 - val_activation_5_loss: 3.8900 - val_loss: 6.0451 - val_activation_4_loss: 2.1551
# ITERATION: 25 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.6735 - loss: 0.9818 - activation_4_loss: 0.3083
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0381 - loss: 0.3260 - activation_4_loss: 0.2878 - val_activation_5_loss: 3.9008 - val_loss: 6.0693 - val_activation_4_loss: 2.1686
# ITERATION: 26 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.4329 - loss: 1.0850 - activation_4_loss: 0.6522
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0515 - loss: 0.3401 - activation_4_loss: 0.2887 - val_activation_5_loss: 3.9131 - val_loss: 6.0945 - val_activation_4_loss: 2.1814
# ITERATION: 27 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.7029 - loss: 1.3703 - activation_4_loss: 0.6674
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.1217 - loss: 0.5331 - activation_4_loss: 0.4114 - val_activation_5_loss: 3.9211 - val_loss: 6.1144 - val_activation_4_loss: 2.1933
# ITERATION: 28 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 1.1482 - loss: 1.5762 - activation_4_loss: 0.4280
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0537 - loss: 0.2674 - activation_4_loss: 0.2137 - val_activation_5_loss: 3.9193 - val_loss: 6.1195 - val_activation_4_loss: 2.2002
# ITERATION: 29 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.1372 - loss: 0.9538 - activation_4_loss: 0.8165
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0485 - loss: 0.2594 - activation_4_loss: 0.2109 - val_activation_5_loss: 3.9341 - val_loss: 6.1521 - val_activation_4_loss: 2.2180
# ITERATION: 30 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.1847 - loss: 0.4361 - activation_4_loss: 0.2514
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0963 - loss: 0.2765 - activation_4_loss: 0.1802 - val_activation_5_loss: 3.9645 - val_loss: 6.2117 - val_activation_4_loss: 2.2472
# ITERATION: 31 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.5920 - loss: 1.0965 - activation_4_loss: 0.5046
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0950 - loss: 0.2593 - activation_4_loss: 0.1642 - val_activation_5_loss: 3.9936 - val_loss: 6.2691 - val_activation_4_loss: 2.2756
# ITERATION: 32 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.6630 - loss: 1.1510 - activation_4_loss: 0.4880
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0256 - loss: 0.3479 - activation_4_loss: 0.3223 - val_activation_5_loss: 4.0185 - val_loss: 6.3201 - val_activation_4_loss: 2.3016
# ITERATION: 33 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.3895 - loss: 1.4260 - activation_4_loss: 1.0364
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.1669 - loss: 0.5438 - activation_4_loss: 0.3769 - val_activation_5_loss: 4.0531 - val_loss: 6.3899 - val_activation_4_loss: 2.3369
# ITERATION: 34 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.7835 - loss: 2.2351 - activation_4_loss: 1.4516
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0731 - loss: 0.2815 - activation_4_loss: 0.2084 - val_activation_5_loss: 4.0992 - val_loss: 6.4818 - val_activation_4_loss: 2.3826
# ITERATION: 35 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.7164 - loss: 1.4922 - activation_4_loss: 0.7758
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0405 - loss: 0.4526 - activation_4_loss: 0.4120 - val_activation_5_loss: 4.1382 - val_loss: 6.5600 - val_activation_4_loss: 2.4217
# ITERATION: 36 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.6348 - loss: 2.1777 - activation_4_loss: 1.5429
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0288 - loss: 0.2084 - activation_4_loss: 0.1797 - val_activation_5_loss: 4.2076 - val_loss: 6.6979 - val_activation_4_loss: 2.4903
# ITERATION: 37 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.1337 - loss: 0.2604 - activation_4_loss: 0.1268
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0538 - loss: 0.2994 - activation_4_loss: 0.2456 - val_activation_5_loss: 4.2809 - val_loss: 6.8386 - val_activation_4_loss: 2.5577
# ITERATION: 38 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.2712 - loss: 0.7145 - activation_4_loss: 0.4433
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0513 - loss: 0.3761 - activation_4_loss: 0.3248 - val_activation_5_loss: 4.3522 - val_loss: 6.9737 - val_activation_4_loss: 2.6215
# ITERATION: 39 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.4971 - loss: 1.2786 - activation_4_loss: 0.7816
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0746 - loss: 0.2012 - activation_4_loss: 0.1266 - val_activation_5_loss: 4.4035 - val_loss: 7.0701 - val_activation_4_loss: 2.6666
# ITERATION: 40 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.4587 - loss: 0.8926 - activation_4_loss: 0.4339
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.1581 - loss: 0.3720 - activation_4_loss: 0.2139 - val_activation_5_loss: 4.4495 - val_loss: 7.1539 - val_activation_4_loss: 2.7044
# ITERATION: 41 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.5774 - loss: 1.7498 - activation_4_loss: 1.1724
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0749 - loss: 0.2892 - activation_4_loss: 0.2143 - val_activation_5_loss: 4.4944 - val_loss: 7.2390 - val_activation_4_loss: 2.7446
# ITERATION: 42 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.0888 - loss: 0.6017 - activation_4_loss: 0.5129
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0425 - loss: 0.2365 - activation_4_loss: 0.1940 - val_activation_5_loss: 4.5508 - val_loss: 7.3441 - val_activation_4_loss: 2.7933
# ITERATION: 43 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.5575 - loss: 0.8081 - activation_4_loss: 0.2505
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0774 - loss: 0.1959 - activation_4_loss: 0.1184 - val_activation_5_loss: 4.5843 - val_loss: 7.4086 - val_activation_4_loss: 2.8244
# ITERATION: 44 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.2942 - loss: 0.5071 - activation_4_loss: 0.2129
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0590 - loss: 0.1667 - activation_4_loss: 0.1077 - val_activation_5_loss: 4.6169 - val_loss: 7.4694 - val_activation_4_loss: 2.8525
# ITERATION: 45 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.0839 - loss: 0.5626 - activation_4_loss: 0.4787
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0979 - loss: 0.2572 - activation_4_loss: 0.1593 - val_activation_5_loss: 4.6499 - val_loss: 7.5273 - val_activation_4_loss: 2.8773
# ITERATION: 46 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.3090 - loss: 0.7802 - activation_4_loss: 0.4712
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0502 - loss: 0.1995 - activation_4_loss: 0.1493 - val_activation_5_loss: 4.6961 - val_loss: 7.6095 - val_activation_4_loss: 2.9134
# ITERATION: 47 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.1255 - loss: 0.2643 - activation_4_loss: 0.1388
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0405 - loss: 0.3254 - activation_4_loss: 0.2848 - val_activation_5_loss: 4.7365 - val_loss: 7.6769 - val_activation_4_loss: 2.9404
# ITERATION: 48 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.0798 - loss: 0.2793 - activation_4_loss: 0.1995
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0356 - loss: 0.1871 - activation_4_loss: 0.1515 - val_activation_5_loss: 4.7722 - val_loss: 7.7347 - val_activation_4_loss: 2.9625
# ITERATION: 49 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.0633 - loss: 0.4045 - activation_4_loss: 0.3412
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0162 - loss: 0.2305 - activation_4_loss: 0.2143 - val_activation_5_loss: 4.8065 - val_loss: 7.7889 - val_activation_4_loss: 2.9824
# ITERATION: 50 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.4051 - loss: 1.2361 - activation_4_loss: 0.8309
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0585 - loss: 0.1174 - activation_4_loss: 0.0589 - val_activation_5_loss: 4.8219 - val_loss: 7.8086 - val_activation_4_loss: 2.9868
# ITERATION: 51 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.1294 - loss: 0.3723 - activation_4_loss: 0.2429
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0274 - loss: 0.1593 - activation_4_loss: 0.1319 - val_activation_5_loss: 4.8372 - val_loss: 7.8267 - val_activation_4_loss: 2.9895
# ITERATION: 52 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.1858 - loss: 1.0944 - activation_4_loss: 0.9085
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0588 - loss: 0.1740 - activation_4_loss: 0.1152 - val_activation_5_loss: 4.8467 - val_loss: 7.8288 - val_activation_4_loss: 2.9822
# ITERATION: 53 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.1144 - loss: 0.4540 - activation_4_loss: 0.3396
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0564 - loss: 0.2972 - activation_4_loss: 0.2408 - val_activation_5_loss: 4.8511 - val_loss: 7.8222 - val_activation_4_loss: 2.9712
# ITERATION: 54 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.4794 - loss: 0.9969 - activation_4_loss: 0.5175
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0786 - loss: 0.2266 - activation_4_loss: 0.1481 - val_activation_5_loss: 4.8508 - val_loss: 7.8120 - val_activation_4_loss: 2.9611
# ITERATION: 55 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.5924 - loss: 1.2162 - activation_4_loss: 0.6238
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0298 - loss: 0.0773 - activation_4_loss: 0.0475 - val_activation_5_loss: 4.8571 - val_loss: 7.8132 - val_activation_4_loss: 2.9561
# ITERATION: 56 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.0514 - loss: 0.0970 - activation_4_loss: 0.0456
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0215 - loss: 0.0826 - activation_4_loss: 0.0611 - val_activation_5_loss: 4.8633 - val_loss: 7.8131 - val_activation_4_loss: 2.9499
# ITERATION: 57 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.2454 - loss: 0.6926 - activation_4_loss: 0.4472
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0397 - loss: 0.0930 - activation_4_loss: 0.0533 - val_activation_5_loss: 4.8847 - val_loss: 7.8428 - val_activation_4_loss: 2.9581
# ITERATION: 58 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.0390 - loss: 0.2988 - activation_4_loss: 0.2598
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0530 - loss: 0.2758 - activation_4_loss: 0.2228 - val_activation_5_loss: 4.9087 - val_loss: 7.8792 - val_activation_4_loss: 2.9705
# ITERATION: 59 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.0660 - loss: 0.2005 - activation_4_loss: 0.1345
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0569 - loss: 0.1091 - activation_4_loss: 0.0522 - val_activation_5_loss: 4.9406 - val_loss: 7.9313 - val_activation_4_loss: 2.9907
# ITERATION: 60 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.3111 - loss: 1.0912 - activation_4_loss: 0.7802
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0281 - loss: 0.1123 - activation_4_loss: 0.0842 - val_activation_5_loss: 4.9689 - val_loss: 7.9790 - val_activation_4_loss: 3.0101
# ITERATION: 61 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.2585 - loss: 0.5969 - activation_4_loss: 0.3384
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0119 - loss: 0.1226 - activation_4_loss: 0.1107 - val_activation_5_loss: 4.9910 - val_loss: 8.0155 - val_activation_4_loss: 3.0245
# ITERATION: 62 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.1600 - loss: 0.2925 - activation_4_loss: 0.1325
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0448 - loss: 0.2668 - activation_4_loss: 0.2220 - val_activation_5_loss: 5.0132 - val_loss: 8.0518 - val_activation_4_loss: 3.0386
# ITERATION: 63 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.5388 - loss: 1.2702 - activation_4_loss: 0.7315
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0485 - loss: 0.1794 - activation_4_loss: 0.1309 - val_activation_5_loss: 5.0382 - val_loss: 8.0950 - val_activation_4_loss: 3.0568
# ITERATION: 64 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.2527 - loss: 0.8223 - activation_4_loss: 0.5697
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0627 - loss: 0.2166 - activation_4_loss: 0.1539 - val_activation_5_loss: 5.0617 - val_loss: 8.1358 - val_activation_4_loss: 3.0741
# ITERATION: 65 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.1774 - loss: 1.1282 - activation_4_loss: 0.9508
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0308 - loss: 0.1012 - activation_4_loss: 0.0704 - val_activation_5_loss: 5.0934 - val_loss: 8.1909 - val_activation_4_loss: 3.0975
# ITERATION: 66 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.7289 - loss: 2.1935 - activation_4_loss: 1.4646
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0241 - loss: 0.2143 - activation_4_loss: 0.1902 - val_activation_5_loss: 5.1130 - val_loss: 8.2232 - val_activation_4_loss: 3.1102
# ITERATION: 67 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.1605 - loss: 0.7077 - activation_4_loss: 0.5473
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0570 - loss: 0.2451 - activation_4_loss: 0.1881 - val_activation_5_loss: 5.1104 - val_loss: 8.2120 - val_activation_4_loss: 3.1016
# ITERATION: 68 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 1.0540 - loss: 2.3346 - activation_4_loss: 1.2806
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0233 - loss: 0.1099 - activation_4_loss: 0.0866 - val_activation_5_loss: 5.1125 - val_loss: 8.2154 - val_activation_4_loss: 3.1029
# ITERATION: 69 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.1866 - loss: 0.4215 - activation_4_loss: 0.2349
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0203 - loss: 0.0756 - activation_4_loss: 0.0553 - val_activation_5_loss: 5.1190 - val_loss: 8.2265 - val_activation_4_loss: 3.1075
# ITERATION: 70 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.5658 - loss: 1.3048 - activation_4_loss: 0.7390
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0193 - loss: 0.1375 - activation_4_loss: 0.1181 - val_activation_5_loss: 5.1164 - val_loss: 8.2242 - val_activation_4_loss: 3.1078
# ITERATION: 71 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.8585 - loss: 1.8067 - activation_4_loss: 0.9481
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0260 - loss: 0.0744 - activation_4_loss: 0.0484 - val_activation_5_loss: 5.1057 - val_loss: 8.2115 - val_activation_4_loss: 3.1057
# ITERATION: 72 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.1773 - loss: 0.9582 - activation_4_loss: 0.7808
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0382 - loss: 0.1310 - activation_4_loss: 0.0928 - val_activation_5_loss: 5.1046 - val_loss: 8.2140 - val_activation_4_loss: 3.1095
# ITERATION: 73 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.3979 - loss: 1.3780 - activation_4_loss: 0.9800
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0636 - loss: 0.1101 - activation_4_loss: 0.0466 - val_activation_5_loss: 5.1026 - val_loss: 8.2138 - val_activation_4_loss: 3.1113
# ITERATION: 74 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_5_loss: 0.1035 - loss: 0.5399 - activation_4_loss: 0.4364
# 1/1 [==============================] - 6s 6s/step - activation_5_loss: 0.0365 - loss: 0.0817 - activation_4_loss: 0.0453 - val_activation_5_loss: 5.1064 - val_loss: 8.2211 - val_activation_4_loss: 3.1146

# %%
import pandas as pd

stats = pd.DataFrame(log_list)
stats.to_csv("results/roberta_base_squad2_512in_cccspans_softspans_75ii.csv")
model.save("roberta_base_squad2_512in_cccspans_softspans_75ii")
# Out:
# WARNING:tensorflow:7 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f0458657268> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:7 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f0458657268> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:From /home/ben/anaconda3/envs/distant_crowds/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: roberta_base_squad2_512in_cccspans_softspans_75ii/assets

# %%
pred_start_v, pred_end_v = model.predict((x_valid[0], x_valid[1], x_valid[2]), batch_size=36, verbose=1)
valid_acc = merge_squad_results(valid_examples, pred_start_v, pred_end_v)

pred_start_t, pred_end_t = model.predict((x_test[0], x_test[1], x_test[2]), batch_size=36, verbose=1)
test_acc = merge_squad_results(test_examples, pred_start_t, pred_end_t)

print(f"Validation set accuracy (EM): {valid_acc[0]}")
print(f"Test set accuracy (EM): {test_acc[0]}")
print(f"Validation set F1: {valid_acc[1]}")
print(f"Test set F1: {test_acc[1]}")

pd.DataFrame([{"model":"roberta_base_squad2_512in_cccspans_softspans_75ii",
              "f1_valid":valid_acc[1],"f1_test":test_acc[1],
              "em_valid":valid_acc[0],"em_test":test_acc[0]}]).to_csv("results/roberta_f1v_f1t_emv_emt.csv",mode="a",header=False)
# Out:
# 21/21 [==============================] - 6s 265ms/step
# 92/92 [==============================] - 27s 293ms/step
# Validation set accuracy (EM): 0.655
# Test set accuracy (EM): 0.6248648648648648
# Validation set F1: 0.6193650793650793
# Test set F1: 0.6099081696441716

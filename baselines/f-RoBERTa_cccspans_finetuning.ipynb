# %%
import os
import re
import json
import string
import numpy as np
import tensorflow as tf
from pprint import pprint
from tensorflow import keras
from tensorflow.keras import layers
from tokenizers import BertWordPieceTokenizer
from transformers import RobertaTokenizer, RobertaTokenizerFast, TFRobertaModel
from tensorflow import keras
import jsonlines

tf.random.set_seed(1234)
np.random.seed(1234)

# %% [markdown]
# # Load Data

# %%
seq_len = 450
max_len = 512

###################
## TRAINING DATA ##
###################
ccc_train = []

with open('../data/ccc_train.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    ccc_train.append(json.loads(json_str))

for ex in ccc_train:
    ex["text"] = " ".join(ex["text"].split())
    ex["size_text"] = " ".join(ex["size_text"].split())

print(f"Training examples from raw data: {len(ccc_train)}")
ccc_train = [a for a in ccc_train if a["size_text"].lower() in a["text"].lower()]
print(f"Training examples after removing unmatched size_text strings: {len(ccc_train)}")


######################
## SPAN TUNING DATA ##
######################
ccc_tune = []

with open('../data/ccc_span_tune.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    ccc_tune.append(json.loads(json_str))

for ex in ccc_tune:
    ex["para"] = " ".join(ex["para"].split())
    ex["size_text"] = " ".join(ex["size_text"].split())    

print(f"Span tune examples in raw data: {len(ccc_tune)}")
ccc_tune = [a for a in ccc_tune if a["size_text"].lower() in a["para"].lower()]
print(f"Span tune examples after removing unmatched size_text strings: {len(ccc_tune)}")

ccc_tune = {"data":[{"paragraphs":[{"context":qq["para"],
                             "qas":[
                                 {"answers":[{"answer_start":qq["para"].lower().index(qq["size_text"].lower()),
                                              "text":qq["size_text"]}],
                                  "question":"How many people protested?"}
                             ]}]} for qq in ccc_tune]}


##################
## TESTING DATA ##
##################
ccc_test = []

with open('../data/ccc_test_set.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    ccc_test.append(json.loads(json_str))
    
for ex in ccc_test:
    ex["text"] = " ".join(ex["text"].split())
    ex["size_text"] = " ".join(ex["size_text"].split())
    
print(f"Testing examples from raw data: {len(ccc_test)}")
ccc_test = [a for a in ccc_test if a["size_text"].lower() in a["text"].lower()]
print(f"Testing examples after removing unmatched size_text strings: {len(ccc_test)}")

ccc_test = {"data":[{"paragraphs":[{"context":" ".join(qq["text"].split()),
                             "qas":[
                                 {"answers":[{"answer_start":qq["text"].lower().index(qq["size_text"].lower()),
                                              "text":qq["size_text"]}],
                                  "question":"How many people protested?"}
                             ]}]} for qq in ccc_test]}

#####################
## VALIDATION DATA ##
#####################
ccc_valid = []

with open('../data/ccc_validation_set.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    ccc_valid.append(json.loads(json_str))
    
for ex in ccc_valid:
    ex["text"] = " ".join(ex["text"].split())
    ex["size_text"] = " ".join(ex["size_text"].split())
    
print(f"Valid examples from raw data: {len(ccc_valid)}")
ccc_valid = [a for a in ccc_valid if a["size_text"].lower() in a["text"].lower()]
print(f"Valid examples after removing unmatched size_text strings: {len(ccc_valid)}")

ccc_valid = {"data":[{"paragraphs":[{"context":" ".join(qq["text"].split()),
                             "qas":[
                                 {"answers":[{"answer_start":qq["text"].lower().index(qq["size_text"].lower()),
                                              "text":qq["size_text"]}],
                                  "question":"How many people protested?"}
                             ]}]} for qq in ccc_valid]}

########################
## SOFT-LABELED TRAIN ##
########################
soft_train = []

with open('../data/soft_labeled_train.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    soft_train.append(json.loads(json_str))
    
for ex in soft_train:
    ex["context"] = " ".join(ex["context"].split())
    ex["labeled_text"] = " ".join(ex["labeled_text"].split())
    
print(f"Soft examples from raw data: {len(soft_train)}")
soft_train = [a for a in soft_train if a["labeled_text"].lower() in a["context"].lower()]
print(f"Soft examples after removing unmatched size_text strings: {len(soft_train)}")

soft_train = {"data":[{"paragraphs":[{"context":" ".join(qq["context"].split()),
                             "qas":[
                                 {"answers":[{"answer_start":qq["context"].lower().index(qq["labeled_text"].lower()),
                                              "text":qq["labeled_text"]}],
                                  "question":"How many people protested?"}
                             ]}]} for qq in soft_train]}

#########################
## TOKENIZER AND MODEL ##
#########################

tokenizer = RobertaTokenizerFast.from_pretrained("roberta-base")
# Out:
# Training examples from raw data: 2694
# Training examples after removing unmatched size_text strings: 2685
# Span tune examples in raw data: 25
# Span tune examples after removing unmatched size_text strings: 25
# Testing examples from raw data: 930
# Testing examples after removing unmatched size_text strings: 925
# Valid examples from raw data: 200
# Valid examples after removing unmatched size_text strings: 200
# Soft examples from raw data: 2694
# Soft examples after removing unmatched size_text strings: 2351

# %% [markdown]
# # Prepare Data

# %%
class SquadExample:
    def __init__(self, question, context, start_char_idx, answer_text, all_answers, seq_len, max_len):
        
        # Clean context, answer and question
        context = " ".join(str(context).split())
        question = " ".join(str(question).split())
        answer = " ".join(str(answer_text).split())

        self.question = str(question)
        self.context = str(context)
        self.start_char_idx = start_char_idx
        self.answer_text = str(answer)
        self.all_answers = all_answers
        self.max_len = max_len
        self.seq_len = seq_len
        self.skip_doc = False
        
        self.input_ids = None
        self.attention_mask = None
        self.token_type_ids = None
        self.start_token_idx = None
        self.end_token_idx = None
        self.skip = None
        
    def __str__(self):
        print(np.stack(self.input_ids).shape)
        print(np.stack(self.token_type_ids).shape)
        print(np.stack(self.attention_mask).shape)
        return "<SquadExample>"
        
    def __repr__(self):
        return repr({"input_ids":self.input_ids, 
                     "token_type_ids":self.token_type_ids, 
                     "attention_mask":self.attention_mask,
                     "start_token_idx":self.start_token_idx,
                     "end_token_idx":self.end_token_idx,
                     "skip":self.skip})

    def preprocess(self):
        context = self.context
        question = self.question
        answer = self.answer_text
        start_char_idx = self.start_char_idx

        # Find end character index of answer in context
        end_char_idx = start_char_idx + len(answer)
        if (end_char_idx >= len(context)) or (start_char_idx < 0):
            self.skip_doc = True
            return

        # Mark the character indexes in context that are in answer
        is_char_in_ans = [0] * len(context)
        for idx in range(start_char_idx, end_char_idx):
            is_char_in_ans[idx] = 1
            
        # Tokenize context
        tokenized_context = tokenizer(context, return_offsets_mapping=True)
        
        context_input_ids = tokenized_context.input_ids
        context_offset_mapping = tokenized_context.offset_mapping
        context_attention_mask = tokenized_context.attention_mask
        
        self.context_input_ids = context_input_ids
        self.context_offset_mapping = context_offset_mapping
        
        # Find tokens that were created from answer characters
        ans_token_idx = []
        for idx, (start, end) in enumerate(context_offset_mapping):
            if sum(is_char_in_ans[start:end]) > 0:
                ans_token_idx.append(idx)

#         if len(ans_token_idx) == 0:
#             self.skip_doc = True
#             return
        if (len(ans_token_idx) == 0):
            ans_token_idx = [-1]

        # Find start and end token index for tokens from answer
        start_token_idx = ans_token_idx[0]
        end_token_idx = ans_token_idx[-1]
        
        self.start_token_idx_master = start_token_idx
        self.end_token_idx_master = end_token_idx
        
        # Tokenize question
        tokenized_question = tokenizer("</s> "+question, return_offsets_mapping=True)
        
        ## Crop start and end tokens
        question_input_ids = tokenized_question.input_ids[1:]
        context_input_ids = context_input_ids[1:-1]

        ##
        ## SPLIT UP CONTEXT INTO MULTIPLE QUESTIONS OF max_len
        ##
        
        if seq_len >= len(context_input_ids):
            offsets = [0]
        else:
            ii = 0
            offsets = []
            while (ii+seq_len) <= len(context_input_ids):
                offsets.append(ii)
                ii = ii + round(seq_len/2)
            offsets = offsets + [len(context_input_ids)-seq_len]
        
        list_input_ids = []
        list_start_token_idx = []
        list_end_token_idx = []
        list_attention_mask = []
        list_token_type_ids = []
        list_skip = []
        
        for ii in offsets:
            subcontext_input_ids = [0]+context_input_ids[ii:(ii+seq_len)]+question_input_ids
            subcontext_start_token_idx = start_token_idx - ii
            subcontext_end_token_idx = end_token_idx - ii
            subcontext_padding = [0] * (self.max_len - len(subcontext_input_ids))
            
            subcontext_attention_mask = [1] * len(subcontext_input_ids) + subcontext_padding
            subcontext_token_type_ids = [0] + [0]*len(context_input_ids[ii:(ii+seq_len)]) + [1]*len(question_input_ids) + (np.array(subcontext_padding)+1).tolist()
            subcontext_input_ids = subcontext_input_ids + (np.array(subcontext_padding)+1).tolist()
            
            if (subcontext_start_token_idx >= 0) and (subcontext_end_token_idx < seq_len):
                skip = False
            else:
                subcontext_start_token_idx = 0
                subcontext_end_token_idx = 0
                skip = False
                
            list_input_ids.append(subcontext_input_ids)
            list_attention_mask.append(subcontext_attention_mask)
            list_token_type_ids.append(subcontext_token_type_ids)
            list_start_token_idx.append(subcontext_start_token_idx)
            list_end_token_idx.append(subcontext_end_token_idx)
            list_skip.append(skip)
        
        self.input_ids = (list_input_ids)
        self.attention_mask = (list_attention_mask)
        self.token_type_ids = (list_token_type_ids)
        self.start_token_idx = (list_start_token_idx)
        self.end_token_idx = (list_end_token_idx)
        self.skip = list_skip
        self.example_offset = offsets
        
    def train_examples(self, include_impossible=False):
        for idx, skip_ex in enumerate(self.skip):
            if include_impossible is False:
                if skip_ex is False:
                    yield  {"input_ids":self.input_ids[idx],
                            "token_type_ids":self.token_type_ids[idx],
                            "attention_mask":self.attention_mask[idx],
                            "start_token_idx":self.start_token_idx[idx],
                            "end_token_idx":self.end_token_idx[idx]}
            else:
                yield  {"input_ids":self.input_ids[idx],
                            "token_type_ids":self.token_type_ids[idx],
                            "attention_mask":self.attention_mask[idx],
                            "start_token_idx":self.start_token_idx[idx],
                            "end_token_idx":self.end_token_idx[idx]}
    
    
    def inference_from_onehot(self, pred_start, pred_end):

#         if force_answer == False:
        if (np.max(np.argmax(pred_start, axis=1)) == 0) and (np.max(np.argmax(pred_end, axis=1)) == 0):
            return("", {"all_answers":self.all_answers,
                        "start_token_pred":-1, 
                        "end_token_pred":-1, 
                        "start_char_pred":-1, 
                        "end_char_pred":-1,
                        "start_token":self.start_token_idx_master,
                        "end_token":self.end_token_idx_master,
                        "tokens_pred":set(list([])),
                        "tokens":set(list(range(self.start_token_idx_master,(self.end_token_idx_master+1))))})
        
        seq_len = min(self.seq_len, len(self.context_input_ids))
        
        pred_start_matrix = np.zeros((len(self.input_ids), len(self.context_input_ids)))
        pred_end_matrix = np.zeros((len(self.input_ids), len(self.context_input_ids)))
        
        for idx, value in enumerate(pred_start):
            offset = self.example_offset[idx]+1
            pred_start_sub = pred_start[idx][1:seq_len]
            pred_end_sub   = pred_end[idx][1:seq_len]
            pred_start_matrix[idx,(offset):(offset+seq_len-1)] = pred_start_sub
            pred_end_matrix[idx,(offset):(offset+seq_len-1)] = pred_end_sub
            
        highest_prob = np.argmax(np.max(pred_start_matrix, axis=1) + np.max(pred_end_matrix, axis=1))
        
        top_start = np.argmax(pred_start_matrix[highest_prob,:])
        top_end   = np.argmax(pred_end_matrix[highest_prob,:])
        
#         pred_start = np.max(pred_start_matrix, axis=0)
#         pred_end   = np.max(pred_end_matrix, axis=0)
        
#         top_start = np.argmax(pred_start)
#         top_end = np.argmax(pred_end)
        
        start_char = self.context_offset_mapping[top_start][0]
        end_char = self.context_offset_mapping[top_end][1]
        
        return (self.context[start_char:end_char], {"all_answers":self.all_answers,
                                                    "start_token_pred":top_start, 
                                                    "end_token_pred":top_end, 
                                                    "start_char_pred":start_char, 
                                                    "end_char_pred":end_char,
                                                    "start_token":self.start_token_idx_master,
                                                    "end_token":self.end_token_idx_master,
                                                    "tokens_pred":set(list(range(top_start,(top_end+1)))),
                                                    "tokens":set(list(range(self.start_token_idx_master,(self.end_token_idx_master+1))))})
                
    def model_inference(self, model):
        pred = model.predict([np.stack(self.input_ids),
                      np.stack(self.attention_mask),
                      np.stack(self.token_type_ids)], batch_size=8)
        pred_start = pred[0]
        pred_end   = pred[1]
        
        return self.inference_from_onehot(pred_start, pred_end)
    
    def fake_inference(self):
        pred_start_mat = []
        pred_end_mat = []
        for idx, val in enumerate(self.start_token_idx):
            pred_start = np.zeros_like(np.array(self.input_ids[idx]))
            pred_end = np.zeros_like(np.array(self.input_ids[idx]))
            if self.skip[idx] == False:
                pred_start[val] = 1.0
                pred_end[self.end_token_idx[idx]] = 1.0
            pred_start_mat.append(pred_start)
            pred_end_mat.append(pred_end)
            
        pred_start_mat = np.array(pred_start_mat)
        pred_end_mat = np.array(pred_end_mat)
        
        return self.inference_from_onehot(pred_start_mat,pred_end_mat)
        

def create_squad_examples(raw_data, seq_len, max_len):
    squad_examples = []
    for item in raw_data["data"]:
        for para in item["paragraphs"]:
            context = para["context"]
            for qa in para["qas"]:
                if len(qa["answers"]) > 0:
                    question = qa["question"]
                    answer_text = qa["answers"][0]["text"]
                    all_answers = [_["text"] for _ in qa["answers"]]
                    start_char_idx = qa["answers"][0]["answer_start"]
                    squad_eg = SquadExample(
                        question, context, start_char_idx, answer_text, all_answers, seq_len, max_len
                    )
                    squad_eg.preprocess()
                    squad_examples.append(squad_eg)
                else:
                    question = qa["question"]
                    answer_text = ""
                    all_answers = [""]
                    start_char_idx = 0
                    squad_eg = SquadExample(
                        question, context, start_char_idx, answer_text, all_answers, seq_len, max_len
                    )
                    squad_eg.preprocess()
                    squad_examples.append(squad_eg)
    return squad_examples


def create_inputs_targets(squad_examples, include_impossible=False):
    dataset_dict = {
        "input_ids": [],
        "token_type_ids": [],
        "attention_mask": [],
        "start_token_idx": [],
        "end_token_idx": [],
    }
    for item in squad_examples:
        if item.skip_doc is False:
            for example in item.train_examples(include_impossible):
                for key in dataset_dict:
                    dataset_dict[key].append(np.array(example[key]))
    for key in dataset_dict:
        dataset_dict[key] = np.array(dataset_dict[key])

    x = (
        dataset_dict["input_ids"],
        dataset_dict["token_type_ids"],
        dataset_dict["attention_mask"])
    y = (dataset_dict["start_token_idx"], dataset_dict["end_token_idx"])
    return x, y


def merge_squad_results(squad_examples, start_preds, end_preds):
    ii = 0
    tally = []
    answers = []
    f1_list = []
    for ex in squad_examples:
        if ex.skip_doc is False:
            n_sub = len(ex.skip)
            pred_out = ex.inference_from_onehot(start_preds[ii:(ii+n_sub),:], end_preds[ii:(ii+n_sub),:])
            tally.append(pred_out[0].lower() in [a.lower() for a in ex.all_answers])
            answers.append(pred_out)
            tp = len(pred_out[1]["tokens_pred"].intersection(pred_out[1]["tokens"]))
            fp = len(pred_out[1]["tokens_pred"].difference(pred_out[1]["tokens"]))
            fn = len(pred_out[1]["tokens"].difference(pred_out[1]["tokens_pred"]))
            ii = ii + n_sub
            if tp>0:
                precision = tp/(tp+fp)
                recall=tp/(tp+fn)
                f1_list.append((2*precision*recall)/(precision+recall))
            else:
                f1_list.append(0)
    return (np.mean(tally), 
            np.mean(f1_list), 
            answers)


#train_squad_examples = create_squad_examples(ccc_train, seq_len, max_len)
#x_train, y_train = create_inputs_targets(train_squad_examples)
#print(f"{len(train_squad_examples)} docs, {x_train.shape[0]} training points created.")

test_examples = create_squad_examples(ccc_test, seq_len, max_len)
x_test, y_test = create_inputs_targets(test_examples)
print(f"{len(test_examples)} docs, {x_test[0].shape} test points created.")

valid_examples = create_squad_examples(ccc_valid, seq_len, max_len)
x_valid, y_valid = create_inputs_targets(valid_examples)
print(f"{len(valid_examples)} docs, {x_valid[0].shape} valid points created.")

span_examples = create_squad_examples(ccc_tune, seq_len, max_len)
x_span, y_span = create_inputs_targets(span_examples)
print(f"{len(span_examples)} docs, {x_span[0].shape} span points created.")

soft_examples = create_squad_examples(soft_train, seq_len, max_len)
x_soft, y_soft = create_inputs_targets(soft_examples)
print(f"{len(soft_examples)} docs, {x_soft[0].shape} soft points created.")
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1205 > 512). Running this sequence through the model will result in indexing errors
# 925 docs, (3306, 512) test points created.
# 200 docs, (725, 512) valid points created.
# 25 docs, (25, 512) span points created.
# 2351 docs, (2346, 512) soft points created.

# %% [markdown]
# # Train Batch-wise and Fine Tune on Validation Set

# %%
strategy = tf.distribute.MirroredStrategy()
print("Number of devices: {}".format(strategy.num_replicas_in_sync))

with strategy.scope():
    model = keras.models.load_model('./roberta_base_squad2_512in')
model.summary()
keras.backend.set_value(model.optimizer.learning_rate, (5e-6))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# roberta (TFRobertaMainLayer)    {'pooler_output': (N 124645632   input_1[0][0]
# __________________________________________________________________________________________________
# start_logit (Dense)             (None, 512, 1)       768         roberta[0][0]
# __________________________________________________________________________________________________
# end_logit (Dense)               (None, 512, 1)       768         roberta[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           start_logit[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           end_logit[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 512)          0           flatten[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 512)          0           flatten_1[0][0]
# ==================================================================================================
# Total params: 124,647,168
# Trainable params: 124,647,168
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
pred_start_v, pred_end_v = model.predict((x_valid[0], x_valid[1], x_valid[2]), batch_size=36, verbose=1)
valid_acc = merge_squad_results(valid_examples, pred_start_v, pred_end_v)

pred_start_t, pred_end_t = model.predict((x_test[0], x_test[1], x_test[2]), batch_size=36, verbose=1)
test_acc = merge_squad_results(test_examples, pred_start_t, pred_end_t)

print(f"Validation set accuracy (EM): {valid_acc[0]}")
print(f"Test set accuracy (EM): {test_acc[0]}")
print(f"Validation set F1: {valid_acc[1]}")
print(f"Test set F1: {test_acc[1]}")

import pandas as pd

pd.DataFrame([{"model":"roberta_base_squad2_512in_zeroshot_75ii",
              "f1_valid":valid_acc[1],"f1_test":test_acc[1],
              "em_valid":valid_acc[0],"em_test":test_acc[0]}]).to_csv("results/roberta_f1v_f1t_emv_emt.csv",mode="a",header=False)
# Out:
# 21/21 [==============================] - 5s 258ms/step
# 92/92 [==============================] - 26s 280ms/step
# Validation set accuracy (EM): 0.31
# Test set accuracy (EM): 0.23567567567567568
# Validation set F1: 0.444513974864605
# Test set F1: 0.39735217336617246

# %%
# validation_loss = []
# validation_accuracy = []
# batch = []
log_list = []

batch_size = 12


for ii in range(75):
    print(f"ITERATION: {ii} of 75.")
#     valid_loss = model.evaluate((x_valid[0],
#                             x_valid[1],
#                             x_valid[2]),
#                             y_valid,
#                            verbose=1,
#                            batch_size=36,
#                            return_dict=True)
#     pred_start, pred_end = model.predict((x_valid[0], x_valid[1], x_valid[2]), batch_size=36, verbose=1)
#     valid_acc = merge_squad_results(valid_examples, pred_start, pred_end)[0]
    
#     print(f"ACCURACY: {valid_acc}")
    
#     validation_loss.append(valid_loss)
#     validation_accuracy.append(valid_acc)
#     batch.append(ii*2)
    
    span_ii = np.random.choice(range(x_span[0].shape[0]), batch_size, replace=True)
    
    model.fit(
        (x_span[0][span_ii,:],
         x_span[1][span_ii,:],
         x_span[2][span_ii,:]),
        (y_span[0][span_ii],
         y_span[1][span_ii]),
        epochs=1,  # For demonstration, 3 epochs are recommended
        verbose=1,
        batch_size=batch_size,  # Made this smaller. Bump up.
    )
    
    span_ii = np.random.choice(range(x_span[0].shape[0]), batch_size, replace=True)

    log = model.fit((x_span[0][span_ii,:],
                     x_span[1][span_ii,:],
                     x_span[2][span_ii,:]),
                    (y_span[0][span_ii],
                     y_span[1][span_ii]),
                    epochs=1,  # For demonstration, 3 epochs are recommended
                    verbose=1,
                    batch_size=batch_size,  # Made this smaller. Bump up.
                    validation_data=((x_valid[0],
                                        x_valid[1],
                                        x_valid[2]),
                                        y_valid[0]),
                    validation_batch_size=36
    )
    log_list.append(log.history)
    
    
# valid_loss = model.evaluate((x_valid[0],
#                             x_valid[1],
#                             x_valid[2]),
#                             y_valid[0],
#                            verbose=1,
#                            batch_size=36,
#                            return_dict=True)
# pred_start, pred_end = model.predict((x_valid[0], x_valid[1], x_valid[2]), batch_size=36, verbose=1)
# valid_acc = merge_squad_results(valid_examples, pred_start, pred_end)[0]

# validation_loss.append(valid_loss)
# validation_accuracy.append(valid_acc)
# batch.append(ii*2)
# Out:
# ITERATION: 0 of 75.
# WARNING:tensorflow:5 out of the last 5 calls to <function recreate_function.<locals>.restored_function_body at 0x7f50382f42f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function recreate_function.<locals>.restored_function_body at 0x7f50382f42f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# INFO:tensorflow:batch_all_reduce: 198 all-reduces with algorithm = nccl, num_packs = 1
# WARNING:tensorflow:Efficient allreduce is not supported for 3 IndexedSlices
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 198 all-reduces with algorithm = nccl, num_packs = 1
# WARNING:tensorflow:Efficient allreduce is not supported for 3 IndexedSlices
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 1.5583 - loss: 2.4062 - activation_5_loss: 0.8478
# 1/1 [==============================] - 9s 9s/step - activation_4_loss: 1.1385 - loss: 1.5056 - activation_5_loss: 0.3671 - val_activation_4_loss: 1.2671 - val_loss: 4.2188 - val_activation_5_loss: 2.9518
# ITERATION: 1 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.9525 - loss: 1.4171 - activation_5_loss: 0.4646
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.8011 - loss: 1.1293 - activation_5_loss: 0.3282 - val_activation_4_loss: 1.2930 - val_loss: 4.3402 - val_activation_5_loss: 3.0472
# ITERATION: 2 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.9734 - loss: 1.2707 - activation_5_loss: 0.2973
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.7615 - loss: 0.9063 - activation_5_loss: 0.1448 - val_activation_4_loss: 1.3752 - val_loss: 4.5609 - val_activation_5_loss: 3.1857
# ITERATION: 3 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 1.0038 - loss: 1.1768 - activation_5_loss: 0.1730
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.8083 - loss: 1.0028 - activation_5_loss: 0.1945 - val_activation_4_loss: 1.4814 - val_loss: 4.8146 - val_activation_5_loss: 3.3332
# ITERATION: 4 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.9452 - loss: 1.3166 - activation_5_loss: 0.3715
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.5902 - loss: 0.7652 - activation_5_loss: 0.1750 - val_activation_4_loss: 1.5803 - val_loss: 5.0409 - val_activation_5_loss: 3.4606
# ITERATION: 5 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.5993 - loss: 0.9491 - activation_5_loss: 0.3498
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.3075 - loss: 0.4042 - activation_5_loss: 0.0967 - val_activation_4_loss: 1.6639 - val_loss: 5.2271 - val_activation_5_loss: 3.5632
# ITERATION: 6 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.4866 - loss: 0.6487 - activation_5_loss: 0.1621
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.5330 - loss: 0.6167 - activation_5_loss: 0.0837 - val_activation_4_loss: 1.7392 - val_loss: 5.3934 - val_activation_5_loss: 3.6542
# ITERATION: 7 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.3800 - loss: 0.4363 - activation_5_loss: 0.0563
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.3123 - loss: 0.3867 - activation_5_loss: 0.0744 - val_activation_4_loss: 1.8068 - val_loss: 5.5401 - val_activation_5_loss: 3.7333
# ITERATION: 8 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.2518 - loss: 0.2974 - activation_5_loss: 0.0456
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.6130 - loss: 0.7008 - activation_5_loss: 0.0877 - val_activation_4_loss: 1.8696 - val_loss: 5.6748 - val_activation_5_loss: 3.8052
# ITERATION: 9 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.1380 - loss: 0.1722 - activation_5_loss: 0.0343
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.1745 - loss: 0.2393 - activation_5_loss: 0.0647 - val_activation_4_loss: 1.9242 - val_loss: 5.7926 - val_activation_5_loss: 3.8684
# ITERATION: 10 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.4829 - loss: 0.5709 - activation_5_loss: 0.0880
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.1470 - loss: 0.1719 - activation_5_loss: 0.0249 - val_activation_4_loss: 1.9738 - val_loss: 5.9000 - val_activation_5_loss: 3.9261
# ITERATION: 11 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.2886 - loss: 0.3398 - activation_5_loss: 0.0513
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.4171 - loss: 0.4822 - activation_5_loss: 0.0652 - val_activation_4_loss: 2.0199 - val_loss: 6.0004 - val_activation_5_loss: 3.9805
# ITERATION: 12 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.2220 - loss: 0.2987 - activation_5_loss: 0.0767
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0912 - loss: 0.1194 - activation_5_loss: 0.0282 - val_activation_4_loss: 2.0633 - val_loss: 6.0950 - val_activation_5_loss: 4.0318
# ITERATION: 13 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.3791 - loss: 0.4210 - activation_5_loss: 0.0419
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.2290 - loss: 0.2517 - activation_5_loss: 0.0228 - val_activation_4_loss: 2.0996 - val_loss: 6.1758 - val_activation_5_loss: 4.0762
# ITERATION: 14 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0391 - loss: 0.0478 - activation_5_loss: 0.0087
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.3392 - loss: 0.4020 - activation_5_loss: 0.0628 - val_activation_4_loss: 2.1293 - val_loss: 6.2435 - val_activation_5_loss: 4.1142
# ITERATION: 15 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.2354 - loss: 0.2683 - activation_5_loss: 0.0329
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.1255 - loss: 0.1558 - activation_5_loss: 0.0303 - val_activation_4_loss: 2.1548 - val_loss: 6.3018 - val_activation_5_loss: 4.1470
# ITERATION: 16 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.2345 - loss: 0.2446 - activation_5_loss: 0.0101
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.1922 - loss: 0.2231 - activation_5_loss: 0.0309 - val_activation_4_loss: 2.1779 - val_loss: 6.3564 - val_activation_5_loss: 4.1784
# ITERATION: 17 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0878 - loss: 0.1012 - activation_5_loss: 0.0134
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.4083 - loss: 0.4314 - activation_5_loss: 0.0231 - val_activation_4_loss: 2.2020 - val_loss: 6.4142 - val_activation_5_loss: 4.2122
# ITERATION: 18 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.2300 - loss: 0.2610 - activation_5_loss: 0.0310
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0273 - loss: 0.0454 - activation_5_loss: 0.0181 - val_activation_4_loss: 2.2264 - val_loss: 6.4736 - val_activation_5_loss: 4.2472
# ITERATION: 19 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.2755 - loss: 0.2916 - activation_5_loss: 0.0161
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0594 - loss: 0.0730 - activation_5_loss: 0.0136 - val_activation_4_loss: 2.2478 - val_loss: 6.5274 - val_activation_5_loss: 4.2796
# ITERATION: 20 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.1570 - loss: 0.1936 - activation_5_loss: 0.0366
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0540 - loss: 0.0655 - activation_5_loss: 0.0116 - val_activation_4_loss: 2.2657 - val_loss: 6.5755 - val_activation_5_loss: 4.3098
# ITERATION: 21 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0783 - loss: 0.1121 - activation_5_loss: 0.0338
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0913 - loss: 0.1259 - activation_5_loss: 0.0346 - val_activation_4_loss: 2.2845 - val_loss: 6.6260 - val_activation_5_loss: 4.3416
# ITERATION: 22 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0473 - loss: 0.0597 - activation_5_loss: 0.0125
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0342 - loss: 0.1044 - activation_5_loss: 0.0702 - val_activation_4_loss: 2.2977 - val_loss: 6.6639 - val_activation_5_loss: 4.3661
# ITERATION: 23 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.3249 - loss: 0.3611 - activation_5_loss: 0.0361
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0521 - loss: 0.0573 - activation_5_loss: 0.0052 - val_activation_4_loss: 2.3062 - val_loss: 6.6887 - val_activation_5_loss: 4.3825
# ITERATION: 24 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.2483 - loss: 0.2988 - activation_5_loss: 0.0505
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0326 - loss: 0.0420 - activation_5_loss: 0.0094 - val_activation_4_loss: 2.3130 - val_loss: 6.7103 - val_activation_5_loss: 4.3973
# ITERATION: 25 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0862 - loss: 0.0902 - activation_5_loss: 0.0040
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0300 - loss: 0.0372 - activation_5_loss: 0.0072 - val_activation_4_loss: 2.3178 - val_loss: 6.7273 - val_activation_5_loss: 4.4094
# ITERATION: 26 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0897 - loss: 0.0969 - activation_5_loss: 0.0072
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0560 - loss: 0.0611 - activation_5_loss: 0.0051 - val_activation_4_loss: 2.3233 - val_loss: 6.7451 - val_activation_5_loss: 4.4218
# ITERATION: 27 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.3542 - loss: 0.3734 - activation_5_loss: 0.0193
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.1153 - loss: 0.1202 - activation_5_loss: 0.0049 - val_activation_4_loss: 2.3225 - val_loss: 6.7475 - val_activation_5_loss: 4.4250
# ITERATION: 28 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0365 - loss: 0.0427 - activation_5_loss: 0.0062
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.1241 - loss: 0.1478 - activation_5_loss: 0.0238 - val_activation_4_loss: 2.3223 - val_loss: 6.7523 - val_activation_5_loss: 4.4299
# ITERATION: 29 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.1065 - loss: 0.1287 - activation_5_loss: 0.0222
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0236 - loss: 0.0270 - activation_5_loss: 0.0034 - val_activation_4_loss: 2.3238 - val_loss: 6.7618 - val_activation_5_loss: 4.4380
# ITERATION: 30 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.1522 - loss: 0.1681 - activation_5_loss: 0.0159
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0439 - loss: 0.0466 - activation_5_loss: 0.0027 - val_activation_4_loss: 2.3258 - val_loss: 6.7728 - val_activation_5_loss: 4.4470
# ITERATION: 31 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0260 - loss: 0.0294 - activation_5_loss: 0.0034
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.1304 - loss: 0.1332 - activation_5_loss: 0.0028 - val_activation_4_loss: 2.3288 - val_loss: 6.7856 - val_activation_5_loss: 4.4568
# ITERATION: 32 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0640 - loss: 0.0688 - activation_5_loss: 0.0047
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0482 - loss: 0.0590 - activation_5_loss: 0.0108 - val_activation_4_loss: 2.3332 - val_loss: 6.8017 - val_activation_5_loss: 4.4685
# ITERATION: 33 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0367 - loss: 0.0427 - activation_5_loss: 0.0060
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0666 - loss: 0.0736 - activation_5_loss: 0.0070 - val_activation_4_loss: 2.3382 - val_loss: 6.8195 - val_activation_5_loss: 4.4813
# ITERATION: 34 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.1402 - loss: 0.1493 - activation_5_loss: 0.0092
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0084 - loss: 0.0107 - activation_5_loss: 0.0023 - val_activation_4_loss: 2.3447 - val_loss: 6.8408 - val_activation_5_loss: 4.4960
# ITERATION: 35 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0214 - loss: 0.0242 - activation_5_loss: 0.0028
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0584 - loss: 0.0714 - activation_5_loss: 0.0130 - val_activation_4_loss: 2.3510 - val_loss: 6.8607 - val_activation_5_loss: 4.5097
# ITERATION: 36 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0823 - loss: 0.0932 - activation_5_loss: 0.0109
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0281 - loss: 0.0331 - activation_5_loss: 0.0050 - val_activation_4_loss: 2.3603 - val_loss: 6.8872 - val_activation_5_loss: 4.5269
# ITERATION: 37 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0347 - loss: 0.0364 - activation_5_loss: 0.0017
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0278 - loss: 0.0321 - activation_5_loss: 0.0043 - val_activation_4_loss: 2.3702 - val_loss: 6.9146 - val_activation_5_loss: 4.5444
# ITERATION: 38 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.1372 - loss: 0.1415 - activation_5_loss: 0.0044
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0751 - loss: 0.0768 - activation_5_loss: 0.0017 - val_activation_4_loss: 2.3783 - val_loss: 6.9364 - val_activation_5_loss: 4.5582
# ITERATION: 39 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.1054 - loss: 0.1097 - activation_5_loss: 0.0043
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0156 - loss: 0.0192 - activation_5_loss: 0.0036 - val_activation_4_loss: 2.3881 - val_loss: 6.9613 - val_activation_5_loss: 4.5732
# ITERATION: 40 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0189 - loss: 0.0222 - activation_5_loss: 0.0033
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0435 - loss: 0.0471 - activation_5_loss: 0.0036 - val_activation_4_loss: 2.3979 - val_loss: 6.9868 - val_activation_5_loss: 4.5889
# ITERATION: 41 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0353 - loss: 0.0370 - activation_5_loss: 0.0017
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.1041 - loss: 0.1114 - activation_5_loss: 0.0073 - val_activation_4_loss: 2.4093 - val_loss: 7.0164 - val_activation_5_loss: 4.6072
# ITERATION: 42 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0954 - loss: 0.1084 - activation_5_loss: 0.0130
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0552 - loss: 0.0691 - activation_5_loss: 0.0140 - val_activation_4_loss: 2.4204 - val_loss: 7.0461 - val_activation_5_loss: 4.6257
# ITERATION: 43 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0197 - loss: 0.0226 - activation_5_loss: 0.0030
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0291 - loss: 0.0304 - activation_5_loss: 0.0013 - val_activation_4_loss: 2.4322 - val_loss: 7.0771 - val_activation_5_loss: 4.6449
# ITERATION: 44 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0745 - loss: 0.0770 - activation_5_loss: 0.0025
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0081 - loss: 0.0098 - activation_5_loss: 0.0017 - val_activation_4_loss: 2.4465 - val_loss: 7.1129 - val_activation_5_loss: 4.6663
# ITERATION: 45 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0140 - loss: 0.0147 - activation_5_loss: 6.9978e-04
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0914 - loss: 0.0961 - activation_5_loss: 0.0047 - val_activation_4_loss: 2.4605 - val_loss: 7.1473 - val_activation_5_loss: 4.6868
# ITERATION: 46 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0155 - loss: 0.0167 - activation_5_loss: 0.0012
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0301 - loss: 0.0340 - activation_5_loss: 0.0040 - val_activation_4_loss: 2.4747 - val_loss: 7.1817 - val_activation_5_loss: 4.7070
# ITERATION: 47 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0240 - loss: 0.0259 - activation_5_loss: 0.0019
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0081 - loss: 0.0089 - activation_5_loss: 8.5138e-04 - val_activation_4_loss: 2.4877 - val_loss: 7.2133 - val_activation_5_loss: 4.7255
# ITERATION: 48 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0136 - loss: 0.0184 - activation_5_loss: 0.0049
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0491 - loss: 0.0532 - activation_5_loss: 0.0041 - val_activation_4_loss: 2.4987 - val_loss: 7.2410 - val_activation_5_loss: 4.7423
# ITERATION: 49 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0302 - loss: 0.0332 - activation_5_loss: 0.0030
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0151 - loss: 0.0163 - activation_5_loss: 0.0012 - val_activation_4_loss: 2.5098 - val_loss: 7.2688 - val_activation_5_loss: 4.7589
# ITERATION: 50 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0352 - loss: 0.0362 - activation_5_loss: 0.0010
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0038 - loss: 0.0052 - activation_5_loss: 0.0013 - val_activation_4_loss: 2.5201 - val_loss: 7.2948 - val_activation_5_loss: 4.7747
# ITERATION: 51 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0084 - loss: 0.0098 - activation_5_loss: 0.0013
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0255 - loss: 0.0266 - activation_5_loss: 0.0010 - val_activation_4_loss: 2.5305 - val_loss: 7.3204 - val_activation_5_loss: 4.7900
# ITERATION: 52 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0030 - loss: 0.0047 - activation_5_loss: 0.0017
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0306 - loss: 0.0318 - activation_5_loss: 0.0012 - val_activation_4_loss: 2.5405 - val_loss: 7.3452 - val_activation_5_loss: 4.8047
# ITERATION: 53 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0211 - loss: 0.0241 - activation_5_loss: 0.0031
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0043 - loss: 0.0059 - activation_5_loss: 0.0016 - val_activation_4_loss: 2.5504 - val_loss: 7.3699 - val_activation_5_loss: 4.8196
# ITERATION: 54 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0262 - loss: 0.1062 - activation_5_loss: 0.0799
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0352 - loss: 0.0484 - activation_5_loss: 0.0132 - val_activation_4_loss: 2.5463 - val_loss: 7.3674 - val_activation_5_loss: 4.8211
# ITERATION: 55 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0136 - loss: 0.0167 - activation_5_loss: 0.0031
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0095 - loss: 0.0106 - activation_5_loss: 0.0011 - val_activation_4_loss: 2.5412 - val_loss: 7.3626 - val_activation_5_loss: 4.8214
# ITERATION: 56 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0043 - loss: 0.0062 - activation_5_loss: 0.0019
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0402 - loss: 0.0423 - activation_5_loss: 0.0021 - val_activation_4_loss: 2.5382 - val_loss: 7.3614 - val_activation_5_loss: 4.8232
# ITERATION: 57 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0142 - loss: 0.0148 - activation_5_loss: 6.7575e-04
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0087 - loss: 0.0099 - activation_5_loss: 0.0011 - val_activation_4_loss: 2.5369 - val_loss: 7.3630 - val_activation_5_loss: 4.8261
# ITERATION: 58 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0055 - loss: 0.0065 - activation_5_loss: 0.0010
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0093 - loss: 0.0119 - activation_5_loss: 0.0026 - val_activation_4_loss: 2.5374 - val_loss: 7.3688 - val_activation_5_loss: 4.8314
# ITERATION: 59 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0423 - loss: 0.0480 - activation_5_loss: 0.0058
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0398 - loss: 0.0429 - activation_5_loss: 0.0031 - val_activation_4_loss: 2.5420 - val_loss: 7.3836 - val_activation_5_loss: 4.8417
# ITERATION: 60 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0024 - loss: 0.0047 - activation_5_loss: 0.0023
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0022 - loss: 0.0043 - activation_5_loss: 0.0020 - val_activation_4_loss: 2.5466 - val_loss: 7.3988 - val_activation_5_loss: 4.8522
# ITERATION: 61 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0021 - loss: 0.0037 - activation_5_loss: 0.0016
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0114 - loss: 0.0125 - activation_5_loss: 0.0011 - val_activation_4_loss: 2.5509 - val_loss: 7.4127 - val_activation_5_loss: 4.8618
# ITERATION: 62 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 8.1896e-04 - loss: 0.0014 - activation_5_loss: 5.6094e-04
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0052 - loss: 0.0076 - activation_5_loss: 0.0023 - val_activation_4_loss: 2.5546 - val_loss: 7.4247 - val_activation_5_loss: 4.8702
# ITERATION: 63 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0832 - loss: 0.0851 - activation_5_loss: 0.0019
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0027 - loss: 0.0041 - activation_5_loss: 0.0014 - val_activation_4_loss: 2.5595 - val_loss: 7.4404 - val_activation_5_loss: 4.8810
# ITERATION: 64 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0088 - loss: 0.0094 - activation_5_loss: 6.7847e-04
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0157 - loss: 0.0169 - activation_5_loss: 0.0012 - val_activation_4_loss: 2.5657 - val_loss: 7.4582 - val_activation_5_loss: 4.8925
# ITERATION: 65 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0013 - loss: 0.0034 - activation_5_loss: 0.0020
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0076 - loss: 0.0084 - activation_5_loss: 7.8244e-04 - val_activation_4_loss: 2.5714 - val_loss: 7.4744 - val_activation_5_loss: 4.9030
# ITERATION: 66 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0221 - loss: 0.0272 - activation_5_loss: 0.0051
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0021 - loss: 0.0027 - activation_5_loss: 5.2673e-04 - val_activation_4_loss: 2.5773 - val_loss: 7.4913 - val_activation_5_loss: 4.9140
# ITERATION: 67 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0011 - loss: 0.0019 - activation_5_loss: 8.2812e-04
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0044 - loss: 0.0072 - activation_5_loss: 0.0028 - val_activation_4_loss: 2.5825 - val_loss: 7.5065 - val_activation_5_loss: 4.9239
# ITERATION: 68 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0015 - loss: 0.0029 - activation_5_loss: 0.0014
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0014 - loss: 0.0025 - activation_5_loss: 0.0011 - val_activation_4_loss: 2.5875 - val_loss: 7.5205 - val_activation_5_loss: 4.9330
# ITERATION: 69 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0026 - loss: 0.0038 - activation_5_loss: 0.0012
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0103 - loss: 0.0114 - activation_5_loss: 0.0011 - val_activation_4_loss: 2.5926 - val_loss: 7.5345 - val_activation_5_loss: 4.9419
# ITERATION: 70 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0224 - loss: 0.0234 - activation_5_loss: 9.9106e-04
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0072 - loss: 0.0079 - activation_5_loss: 6.6978e-04 - val_activation_4_loss: 2.5963 - val_loss: 7.5457 - val_activation_5_loss: 4.9493
# ITERATION: 71 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0012 - loss: 0.0024 - activation_5_loss: 0.0011
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0071 - loss: 0.0079 - activation_5_loss: 8.3107e-04 - val_activation_4_loss: 2.5997 - val_loss: 7.5559 - val_activation_5_loss: 4.9562
# ITERATION: 72 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0010 - loss: 0.0017 - activation_5_loss: 6.3394e-04
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0018 - loss: 0.0023 - activation_5_loss: 5.8448e-04 - val_activation_4_loss: 2.6031 - val_loss: 7.5656 - val_activation_5_loss: 4.9625
# ITERATION: 73 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0018 - loss: 0.0033 - activation_5_loss: 0.0016
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0099 - loss: 0.0147 - activation_5_loss: 0.0048 - val_activation_4_loss: 2.6067 - val_loss: 7.5753 - val_activation_5_loss: 4.9686
# ITERATION: 74 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0424 - loss: 0.0515 - activation_5_loss: 0.0091
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 9.0609e-04 - loss: 0.0014 - activation_5_loss: 4.9496e-04 - val_activation_4_loss: 2.6113 - val_loss: 7.5874 - val_activation_5_loss: 4.9761

# %%
import pandas as pd

stats = pd.DataFrame(log_list)
stats.to_csv("results/roberta_base_squad2_512in_cccspans_75ii.csv")
model.save("roberta_base_squad2_512in_cccspans_75ii")
# Out:
# WARNING:tensorflow:7 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f50382f42f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:7 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7f50382f42f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:From /home/ben/anaconda3/envs/distant_crowds/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: roberta_base_squad2_512in_cccspans_75ii/assets

# %%
pred_start_v, pred_end_v = model.predict((x_valid[0], x_valid[1], x_valid[2]), batch_size=36, verbose=1)
valid_acc = merge_squad_results(valid_examples, pred_start_v, pred_end_v)

pred_start_t, pred_end_t = model.predict((x_test[0], x_test[1], x_test[2]), batch_size=36, verbose=1)
test_acc = merge_squad_results(test_examples, pred_start_t, pred_end_t)

print(f"Validation set accuracy (EM): {valid_acc[0]}")
print(f"Test set accuracy (EM): {test_acc[0]}")
print(f"Validation set F1: {valid_acc[1]}")
print(f"Test set F1: {test_acc[1]}")

pd.DataFrame([{"model":"roberta_base_squad2_512in_cccspans_75ii",
              "f1_valid":valid_acc[1],"f1_test":test_acc[1],
              "em_valid":valid_acc[0],"em_test":test_acc[0]}]).to_csv("results/roberta_f1v_f1t_emv_emt.csv",mode="a",header=False)
# Out:
# 21/21 [==============================] - 6s 273ms/step
# 92/92 [==============================] - 27s 299ms/step
# Validation set accuracy (EM): 0.705
# Test set accuracy (EM): 0.667027027027027
# Validation set F1: 0.6840390048598239
# Test set F1: 0.6529010970065571

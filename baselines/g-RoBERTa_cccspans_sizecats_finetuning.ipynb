# %%
import os
# os.environ["CUDA_VISIBLE_DEVICES"]="0"
import re
import json
import string
import numpy as np
import tensorflow as tf
from pprint import pprint
from tensorflow import keras
from tensorflow.keras import layers
from tokenizers import BertWordPieceTokenizer
from transformers import RobertaTokenizer, RobertaTokenizerFast, TFRobertaModel
from tensorflow import keras

tf.random.set_seed(1234)
np.random.seed(1234)

seq_len = 450
max_len = 512

###################
## TRAINING DATA ##
###################
ccc_train = []

with open('/home/ben/GDrive/Projects/distant_crowds/data/ccc_train.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    ccc_train.append(json.loads(json_str))

for ex in ccc_train:
    ex["text"] = " ".join(ex["text"].split())
    ex["size_text"] = " ".join(ex["size_text"].split())

print(f"Training examples from raw data: {len(ccc_train)}")
# ccc_train = [a for a in ccc_train if a["size_text"].lower() in a["text"].lower()]
print(f"Training examples after removing unmatched size_text strings: {len(ccc_train)}")


######################
## SPAN TUNING DATA ##
######################
ccc_tune = []

with open('../data/ccc_span_tune.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    ccc_tune.append(json.loads(json_str))

for ex in ccc_tune:
    ex["para"] = " ".join(ex["para"].split())
    ex["size_text"] = " ".join(ex["size_text"].split())    

print(f"Span tune examples in raw data: {len(ccc_tune)}")
ccc_tune = [a for a in ccc_tune if a["size_text"].lower() in a["para"].lower()]
print(f"Span tune examples after removing unmatched size_text strings: {len(ccc_tune)}")

ccc_tune = {"data":[{"paragraphs":[{"context":qq["para"],
                             "qas":[
                                 {"answers":[{"answer_start":qq["para"].lower().index(qq["size_text"].lower()),
                                              "text":qq["size_text"]}],
                                  "question":"How many people protested?"}
                             ]}]} for qq in ccc_tune]}


##################
## TESTING DATA ##
##################
ccc_test = []

with open('../data/ccc_test_set.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    ccc_test.append(json.loads(json_str))
    
for ex in ccc_test:
    ex["text"] = " ".join(ex["text"].split())
    ex["size_text"] = " ".join(ex["size_text"].split())
    
print(f"Testing examples from raw data: {len(ccc_test)}")
ccc_test = [a for a in ccc_test if a["size_text"].lower() in a["text"].lower()]
print(f"Testing examples after removing unmatched size_text strings: {len(ccc_test)}")

ccc_test = {"data":[{"paragraphs":[{"context":" ".join(qq["text"].split()),
                             "qas":[
                                 {"answers":[{"answer_start":qq["text"].lower().index(qq["size_text"].lower()),
                                              "text":qq["size_text"]}],
                                  "question":"How many people protested?"}
                             ]}]} for qq in ccc_test]}

#####################
## VALIDATION DATA ##
#####################
ccc_valid = []

with open('../data/ccc_validation_set.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    ccc_valid.append(json.loads(json_str))
    
for ex in ccc_valid:
    ex["text"] = " ".join(ex["text"].split())
    ex["size_text"] = " ".join(ex["size_text"].split())
    
print(f"Valid examples from raw data: {len(ccc_valid)}")
ccc_valid = [a for a in ccc_valid if a["size_text"].lower() in a["text"].lower()]
print(f"Valid examples after removing unmatched size_text strings: {len(ccc_valid)}")

ccc_valid = {"data":[{"paragraphs":[{"context":" ".join(qq["text"].split()),
                             "qas":[
                                 {"answers":[{"answer_start":qq["text"].lower().index(qq["size_text"].lower()),
                                              "text":qq["size_text"]}],
                                  "question":"How many people protested?"}
                             ]}]} for qq in ccc_valid]}

#########################
## TOKENIZER AND MODEL ##
#########################

tokenizer = RobertaTokenizerFast.from_pretrained("roberta-base")
# Out:
# Training examples from raw data: 2694
# Training examples after removing unmatched size_text strings: 2694
# Span tune examples in raw data: 25
# Span tune examples after removing unmatched size_text strings: 25
# Testing examples from raw data: 930
# Testing examples after removing unmatched size_text strings: 925
# Valid examples from raw data: 200
# Valid examples after removing unmatched size_text strings: 200

# %%
x_cat_inputs = []
x_cat_attentions = []
x_cat_types = []
y_cat = []

for ex in ccc_train:
    text = ex["text"]
    
    tokenized_context = tokenizer(text, return_offsets_mapping=True)
    tokenized_question = tokenizer("</s> How many people protested?", return_offsets_mapping=True)
    
    if len(tokenized_context.input_ids) > seq_len:
        continue
    
    context_ids = tokenized_context.input_ids[0:-1]
    question_ids = tokenized_question.input_ids[1:]
    input_ids = context_ids + question_ids
    
    padding = [0]*(max_len - len(input_ids))
    
    input_ids = input_ids + (np.array(padding)+1).tolist()
    attention_mask = [1]*len(context_ids) + [1]*len(question_ids) + [0]*len(padding)
    token_type_ids = [0]*len(context_ids) + [1]*len(question_ids) + [1]*len(padding)
    
    x_cat_inputs.append(input_ids)
    x_cat_attentions.append(attention_mask)
    x_cat_types.append(token_type_ids)
    y_cat.append(ex["size_cat"])

x_cat = (np.array(x_cat_inputs),
         np.array(x_cat_types),
         np.array(x_cat_attentions))
y_cat = np.array(y_cat)
print(len(x_cat_inputs))
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1134 > 512). Running this sequence through the model will result in indexing errors
# 606

# %%
class SquadExample:
    def __init__(self, question, context, start_char_idx, answer_text, all_answers, seq_len, max_len):
        
        # Clean context, answer and question
        context = " ".join(str(context).split())
        question = " ".join(str(question).split())
        answer = " ".join(str(answer_text).split())

        self.question = str(question)
        self.context = str(context)
        self.start_char_idx = start_char_idx
        self.answer_text = str(answer)
        self.all_answers = all_answers
        self.max_len = max_len
        self.seq_len = seq_len
        self.skip_doc = False
        
        self.input_ids = None
        self.attention_mask = None
        self.token_type_ids = None
        self.start_token_idx = None
        self.end_token_idx = None
        self.skip = None
        
    def __str__(self):
        print(np.stack(self.input_ids).shape)
        print(np.stack(self.token_type_ids).shape)
        print(np.stack(self.attention_mask).shape)
        return "<SquadExample>"
        
    def __repr__(self):
        return repr({"input_ids":self.input_ids, 
                     "token_type_ids":self.token_type_ids, 
                     "attention_mask":self.attention_mask,
                     "start_token_idx":self.start_token_idx,
                     "end_token_idx":self.end_token_idx,
                     "skip":self.skip})

    def preprocess(self):
        context = self.context
        question = self.question
        answer = self.answer_text
        start_char_idx = self.start_char_idx

        # Find end character index of answer in context
        end_char_idx = start_char_idx + len(answer)
        if (end_char_idx >= len(context)) or (start_char_idx < 0):
            self.skip_doc = True
            return

        # Mark the character indexes in context that are in answer
        is_char_in_ans = [0] * len(context)
        for idx in range(start_char_idx, end_char_idx):
            is_char_in_ans[idx] = 1
            
        # Tokenize context
        tokenized_context = tokenizer(context, return_offsets_mapping=True)
        
        context_input_ids = tokenized_context.input_ids
        context_offset_mapping = tokenized_context.offset_mapping
        context_attention_mask = tokenized_context.attention_mask
        
        self.context_input_ids = context_input_ids
        self.context_offset_mapping = context_offset_mapping
        
        # Find tokens that were created from answer characters
        ans_token_idx = []
        for idx, (start, end) in enumerate(context_offset_mapping):
            if sum(is_char_in_ans[start:end]) > 0:
                ans_token_idx.append(idx)

#         if len(ans_token_idx) == 0:
#             self.skip_doc = True
#             return
        if (len(ans_token_idx) == 0):
            ans_token_idx = [-1]

        # Find start and end token index for tokens from answer
        start_token_idx = ans_token_idx[0]
        end_token_idx = ans_token_idx[-1]
        
        self.start_token_idx_master = start_token_idx
        self.end_token_idx_master = end_token_idx
        
        # Tokenize question
        tokenized_question = tokenizer("</s> "+question, return_offsets_mapping=True)
        
        ## Crop start and end tokens
        question_input_ids = tokenized_question.input_ids[1:]
        context_input_ids = context_input_ids[1:-1]

        ##
        ## SPLIT UP CONTEXT INTO MULTIPLE QUESTIONS OF max_len
        ##
        
        if seq_len >= len(context_input_ids):
            offsets = [0]
        else:
            ii = 0
            offsets = []
            while (ii+seq_len) <= len(context_input_ids):
                offsets.append(ii)
                ii = ii + round(seq_len/2)
            offsets = offsets + [len(context_input_ids)-seq_len]
        
        list_input_ids = []
        list_start_token_idx = []
        list_end_token_idx = []
        list_attention_mask = []
        list_token_type_ids = []
        list_skip = []
        
        for ii in offsets:
            subcontext_input_ids = [0]+context_input_ids[ii:(ii+seq_len)]+question_input_ids
            subcontext_start_token_idx = start_token_idx - ii
            subcontext_end_token_idx = end_token_idx - ii
            subcontext_padding = [0] * (self.max_len - len(subcontext_input_ids))
            
            subcontext_attention_mask = [1] * len(subcontext_input_ids) + subcontext_padding
            subcontext_token_type_ids = [0] + [0]*len(context_input_ids[ii:(ii+seq_len)]) + [1]*len(question_input_ids) + (np.array(subcontext_padding)+1).tolist()
            subcontext_input_ids = subcontext_input_ids + (np.array(subcontext_padding)+1).tolist()
            
            if (subcontext_start_token_idx >= 0) and (subcontext_end_token_idx < seq_len):
                skip = False
            else:
                subcontext_start_token_idx = 0
                subcontext_end_token_idx = 0
                skip = False
                
            list_input_ids.append(subcontext_input_ids)
            list_attention_mask.append(subcontext_attention_mask)
            list_token_type_ids.append(subcontext_token_type_ids)
            list_start_token_idx.append(subcontext_start_token_idx)
            list_end_token_idx.append(subcontext_end_token_idx)
            list_skip.append(skip)
        
        self.input_ids = (list_input_ids)
        self.attention_mask = (list_attention_mask)
        self.token_type_ids = (list_token_type_ids)
        self.start_token_idx = (list_start_token_idx)
        self.end_token_idx = (list_end_token_idx)
        self.skip = list_skip
        self.example_offset = offsets
        
    def train_examples(self, include_impossible=False):
        for idx, skip_ex in enumerate(self.skip):
            if include_impossible is False:
                if skip_ex is False:
                    yield  {"input_ids":self.input_ids[idx],
                            "token_type_ids":self.token_type_ids[idx],
                            "attention_mask":self.attention_mask[idx],
                            "start_token_idx":self.start_token_idx[idx],
                            "end_token_idx":self.end_token_idx[idx]}
            else:
                yield  {"input_ids":self.input_ids[idx],
                            "token_type_ids":self.token_type_ids[idx],
                            "attention_mask":self.attention_mask[idx],
                            "start_token_idx":self.start_token_idx[idx],
                            "end_token_idx":self.end_token_idx[idx]}
    
    
    def inference_from_onehot(self, pred_start, pred_end):

#         if force_answer == False:
        if (np.max(np.argmax(pred_start, axis=1)) == 0) and (np.max(np.argmax(pred_end, axis=1)) == 0):
            return("", {"all_answers":self.all_answers,
                        "start_token_pred":-1, 
                        "end_token_pred":-1, 
                        "start_char_pred":-1, 
                        "end_char_pred":-1,
                        "start_token":self.start_token_idx_master,
                        "end_token":self.end_token_idx_master,
                        "tokens_pred":set(list([])),
                        "tokens":set(list(range(self.start_token_idx_master,(self.end_token_idx_master+1))))})
        
        seq_len = min(self.seq_len, len(self.context_input_ids))
        
        pred_start_matrix = np.zeros((len(self.input_ids), len(self.context_input_ids)))
        pred_end_matrix = np.zeros((len(self.input_ids), len(self.context_input_ids)))
        
        for idx, value in enumerate(pred_start):
            offset = self.example_offset[idx]+1
            pred_start_sub = pred_start[idx][1:seq_len]
            pred_end_sub   = pred_end[idx][1:seq_len]
            pred_start_matrix[idx,(offset):(offset+seq_len-1)] = pred_start_sub
            pred_end_matrix[idx,(offset):(offset+seq_len-1)] = pred_end_sub
            
        highest_prob = np.argmax(np.max(pred_start_matrix, axis=1) + np.max(pred_end_matrix, axis=1))
        
        top_start = np.argmax(pred_start_matrix[highest_prob,:])
        top_end   = np.argmax(pred_end_matrix[highest_prob,:])
        
#         pred_start = np.max(pred_start_matrix, axis=0)
#         pred_end   = np.max(pred_end_matrix, axis=0)
        
#         top_start = np.argmax(pred_start)
#         top_end = np.argmax(pred_end)
        
        start_char = self.context_offset_mapping[top_start][0]
        end_char = self.context_offset_mapping[top_end][1]
        
        return (self.context[start_char:end_char], {"all_answers":self.all_answers,
                                                    "start_token_pred":top_start, 
                                                    "end_token_pred":top_end, 
                                                    "start_char_pred":start_char, 
                                                    "end_char_pred":end_char,
                                                    "start_token":self.start_token_idx_master,
                                                    "end_token":self.end_token_idx_master,
                                                    "tokens_pred":set(list(range(top_start,(top_end+1)))),
                                                    "tokens":set(list(range(self.start_token_idx_master,(self.end_token_idx_master+1))))})
                
    def model_inference(self, model):
        pred = model.predict([np.stack(self.input_ids),
                      np.stack(self.attention_mask),
                      np.stack(self.token_type_ids)], batch_size=8)
        pred_start = pred[0]
        pred_end   = pred[1]
        
        return self.inference_from_onehot(pred_start, pred_end)
    
    def fake_inference(self):
        pred_start_mat = []
        pred_end_mat = []
        for idx, val in enumerate(self.start_token_idx):
            pred_start = np.zeros_like(np.array(self.input_ids[idx]))
            pred_end = np.zeros_like(np.array(self.input_ids[idx]))
            if self.skip[idx] == False:
                pred_start[val] = 1.0
                pred_end[self.end_token_idx[idx]] = 1.0
            pred_start_mat.append(pred_start)
            pred_end_mat.append(pred_end)
            
        pred_start_mat = np.array(pred_start_mat)
        pred_end_mat = np.array(pred_end_mat)
        
        return self.inference_from_onehot(pred_start_mat,pred_end_mat)
        

def create_squad_examples(raw_data, seq_len, max_len):
    squad_examples = []
    for item in raw_data["data"]:
        for para in item["paragraphs"]:
            context = para["context"]
            for qa in para["qas"]:
                if len(qa["answers"]) > 0:
                    question = qa["question"]
                    answer_text = qa["answers"][0]["text"]
                    all_answers = [_["text"] for _ in qa["answers"]]
                    start_char_idx = qa["answers"][0]["answer_start"]
                    squad_eg = SquadExample(
                        question, context, start_char_idx, answer_text, all_answers, seq_len, max_len
                    )
                    squad_eg.preprocess()
                    squad_examples.append(squad_eg)
                else:
                    question = qa["question"]
                    answer_text = ""
                    all_answers = [""]
                    start_char_idx = 0
                    squad_eg = SquadExample(
                        question, context, start_char_idx, answer_text, all_answers, seq_len, max_len
                    )
                    squad_eg.preprocess()
                    squad_examples.append(squad_eg)
    return squad_examples


def create_inputs_targets(squad_examples, include_impossible=False):
    dataset_dict = {
        "input_ids": [],
        "token_type_ids": [],
        "attention_mask": [],
        "start_token_idx": [],
        "end_token_idx": [],
    }
    for item in squad_examples:
        if item.skip_doc is False:
            for example in item.train_examples(include_impossible):
                for key in dataset_dict:
                    dataset_dict[key].append(np.array(example[key]))
    for key in dataset_dict:
        dataset_dict[key] = np.array(dataset_dict[key])

    x = (
        dataset_dict["input_ids"],
        dataset_dict["token_type_ids"],
        dataset_dict["attention_mask"])
    y = (dataset_dict["start_token_idx"], dataset_dict["end_token_idx"])
    return x, y


def merge_squad_results(squad_examples, start_preds, end_preds):
    ii = 0
    tally = []
    answers = []
    f1_list = []
    for ex in squad_examples:
        if ex.skip_doc is False:
            n_sub = len(ex.skip)
            pred_out = ex.inference_from_onehot(start_preds[ii:(ii+n_sub),:], end_preds[ii:(ii+n_sub),:])
            tally.append(pred_out[0].lower() in [a.lower() for a in ex.all_answers])
            answers.append(pred_out)
            tp = len(pred_out[1]["tokens_pred"].intersection(pred_out[1]["tokens"]))
            fp = len(pred_out[1]["tokens_pred"].difference(pred_out[1]["tokens"]))
            fn = len(pred_out[1]["tokens"].difference(pred_out[1]["tokens_pred"]))
            ii = ii + n_sub
            if tp>0:
                precision = tp/(tp+fp)
                recall=tp/(tp+fn)
                f1_list.append((2*precision*recall)/(precision+recall))
            else:
                f1_list.append(0)
    return (np.mean(tally), 
            np.mean(f1_list), 
            answers)


# train_squad_examples = create_squad_examples(raw_train_data, seq_len, max_len)
# x_train, y_train = create_inputs_targets(train_squad_examples)
# print(f"{len(train_squad_examples)} docs, {x_train.shape[0]} training points created.")


span_examples = create_squad_examples(ccc_tune, seq_len, max_len)
x_span, y_span = create_inputs_targets(span_examples)
print(f"{len(span_examples)} docs, {x_span[0].shape} span points created.")

test_examples = create_squad_examples(ccc_test, seq_len, max_len)
x_test, y_test = create_inputs_targets(test_examples)
print(f"{len(test_examples)} docs, {x_test[0].shape} test points created.")

valid_examples = create_squad_examples(ccc_valid, seq_len, max_len)
x_valid, y_valid = create_inputs_targets(valid_examples)
print(f"{len(valid_examples)} docs, {x_valid[0].shape} valid points created.")
# Out:
# 25 docs, (25, 512) span points created.
# 925 docs, (3306, 512) test points created.
# 200 docs, (725, 512) valid points created.

# %% [markdown]
# # Train and Validate

# %%
strategy = tf.distribute.MirroredStrategy()
print("Number of devices: {}".format(strategy.num_replicas_in_sync))

with strategy.scope():
    model = keras.models.load_model('./roberta_base_squad2_512in')
model.summary()

def makeMask(x):
    x_cumsum = tf.math.cumsum(x[0], axis=1)
    y_cumsum = tf.math.cumsum(x[1], axis=1, reverse=True)
    prod = tf.math.multiply(x_cumsum, y_cumsum)
    return prod

# def makeMask(x):
#     x_argmax = tf.math.argmax(x[0], axis=1)
#     y_argmax = tf.math.argmax(x[1], axis=1)
#     x_onehot = tf.one_hot(x_argmax, 512, axis=1)
#     y_onehot = tf.one_hot(y_argmax, 512, axis=1)
#     x_cumsum = tf.cumsum(x_onehot, axis=1)
#     y_cumsum = tf.cumsum(y_onehot, axis=1, reverse=True)
#     prod = tf.math.multiply(x_cumsum,y_cumsum)
#     return prod

def expandDims(x):
    return tf.expand_dims(x,2)

with strategy.scope():
    out_start = model.get_layer("activation_4").output
    out_end = model.get_layer("activation_5").output
    span_mask = layers.ActivityRegularization(l1=0.01)(layers.Lambda(makeMask)([out_start,out_end]))
    span_mask_2d = layers.Lambda(tf.tile, arguments={'multiples':(1,1,768)})(layers.Lambda(expandDims)(span_mask))
    roberta_embedding = model.get_layer("roberta").output["last_hidden_state"]
    masked_embedding = layers.Multiply()([span_mask_2d,roberta_embedding])
    
    avg_layer = layers.GlobalMaxPooling1D(data_format="channels_last")(masked_embedding)
    out_count = layers.Dense(1, activation="linear")(avg_layer)

    new_optimizer = keras.optimizers.Adam(lr=(5e-5))
    model_cat = keras.models.Model(inputs=[model.input],outputs=[out_count])
    model_cat.compile(optimizer=new_optimizer, loss=["mean_squared_error"])
    
    model_mask = keras.models.Model(inputs=[model.input],outputs=[span_mask])
    
model_cat.summary()

keras.backend.set_value(model.optimizer.learning_rate, (5e-6))
keras.backend.set_value(model_cat.optimizer.learning_rate, (5e-6))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# roberta (TFRobertaMainLayer)    {'last_hidden_state' 124645632   input_1[0][0]
# __________________________________________________________________________________________________
# start_logit (Dense)             (None, 512, 1)       768         roberta[0][0]
# __________________________________________________________________________________________________
# end_logit (Dense)               (None, 512, 1)       768         roberta[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           start_logit[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           end_logit[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 512)          0           flatten[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 512)          0           flatten_1[0][0]
# ==================================================================================================
# Total params: 124,647,168
# Trainable params: 124,647,168
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# roberta (TFRobertaMainLayer)    {'last_hidden_state' 124645632   input_1[0][0]
# __________________________________________________________________________________________________
# start_logit (Dense)             (None, 512, 1)       768         roberta[0][0]
# __________________________________________________________________________________________________
# end_logit (Dense)               (None, 512, 1)       768         roberta[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           start_logit[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           end_logit[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 512)          0           flatten[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 512)          0           flatten_1[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 512)          0           activation_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# activity_regularization (Activi (None, 512)          0           lambda[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 512, 1)       0           activity_regularization[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 512, 768)     0           lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 512, 768)     0           lambda_1[0][0]
#                                                                  roberta[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d (GlobalMax (None, 768)          0           multiply[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            769         global_max_pooling1d[0][0]
# ==================================================================================================
# Total params: 124,647,937
# Trainable params: 124,647,937
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
pred_start_v, pred_end_v = model.predict((x_valid[0], x_valid[1], x_valid[2]), batch_size=36, verbose=1)
valid_acc = merge_squad_results(valid_examples, pred_start_v, pred_end_v)

pred_start_t, pred_end_t = model.predict((x_test[0], x_test[1], x_test[2]), batch_size=36, verbose=1)
test_acc = merge_squad_results(test_examples, pred_start_t, pred_end_t)

print(f"Validation set accuracy (EM): {valid_acc[0]}")
print(f"Test set accuracy (EM): {test_acc[0]}")
print(f"Validation set F1: {valid_acc[1]}")
print(f"Test set F1: {test_acc[1]}")
# Out:
# 21/21 [==============================] - 6s 263ms/step
# 92/92 [==============================] - 26s 288ms/step
# Validation set accuracy (EM): 0.19
# Test set accuracy (EM): 0.16972972972972972
# Validation set F1: 0.27271624189581933
# Test set F1: 0.2658847892310077

# %%
log_list = []
batch_size = 12


for ii in range(75):
    
    print(f"ITERATION: {ii} of 75.")
    
#     valid_loss = model.evaluate((x_valid[0],
#                             x_valid[1],
#                             x_valid[2]),
#                             y_valid,
#                            verbose=1,
#                            batch_size=36,
#                            return_dict=True)
#     pred_start, pred_end = model.predict((x_valid[0], x_valid[1], x_valid[2]), batch_size=36, verbose=1)
#     valid_acc = merge_squad_results(valid_examples, pred_start, pred_end)[0]
    
#     print(f"ACCURACY: {valid_acc}")
    
#     validation_loss.append(valid_loss)
#     validation_accuracy.append(valid_acc)
#     batch.append(ii*2)
    
    span_ii = np.random.choice(range(x_span[0].shape[0]), batch_size, replace=True)
    cat_ii = np.random.choice(range(x_cat[0].shape[0]), batch_size, replace=True)
    
    model_cat.fit(
        (x_cat[0][cat_ii,:],
         x_cat[1][cat_ii,:],
         x_cat[2][cat_ii,:]),
        (y_cat[cat_ii]),
        epochs=1,  # For demonstration, 3 epochs are recommended
        verbose=1,
        batch_size=batch_size,  # Made this smaller. Bump up.
    )
    
    log = model.fit(
        (x_span[0][span_ii,:],
         x_span[1][span_ii,:],
         x_span[2][span_ii,:]),
        (y_span[0][span_ii],
         y_span[1][span_ii]),
        epochs=1,  # For demonstration, 3 epochs are recommended
        verbose=1,
        batch_size=batch_size,  # Made this smaller. Bump up.
        validation_data=((x_valid[0],
                                        x_valid[1],
                                        x_valid[2]),
                                        y_valid[0]),
                    validation_batch_size=36
    )
    
    log_list.append(log.history)
    
# valid_loss = model.evaluate((x_valid[0],
#                             x_valid[1],
#                             x_valid[2]),
#                             y_valid[0],
#                            verbose=1,
#                            batch_size=36,
#                            return_dict=True)

# pred_start, pred_end = model.predict((x_valid[0], x_valid[1], x_valid[2]), batch_size=36, verbose=1)
# valid_acc = merge_squad_results(valid_examples, pred_start, pred_end)[0]

# validation_loss.append(valid_loss)
# validation_accuracy.append(valid_acc)
# batch.append(ii*2)
# Out:
# ITERATION: 0 of 75.
# WARNING:tensorflow:5 out of the last 5 calls to <function recreate_function.<locals>.restored_function_body at 0x7f27b874c488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function recreate_function.<locals>.restored_function_body at 0x7f27b874c488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# INFO:tensorflow:batch_all_reduce: 200 all-reduces with algorithm = nccl, num_packs = 1
# WARNING:tensorflow:Efficient allreduce is not supported for 3 IndexedSlices
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 200 all-reduces with algorithm = nccl, num_packs = 1
# WARNING:tensorflow:Efficient allreduce is not supported for 3 IndexedSlices
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4325
# 1/1 [==============================] - 9s 9s/step - loss: 1.5808 - activation_5_loss: 0.4540 - activation_4_loss: 1.1268 - val_loss: 4.1928 - val_activation_5_loss: 2.9086 - val_activation_4_loss: 1.2842
# ITERATION: 1 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3214
# 1/1 [==============================] - 6s 6s/step - loss: 2.0100 - activation_5_loss: 0.7775 - activation_4_loss: 1.2325 - val_loss: 4.1923 - val_activation_5_loss: 2.9188 - val_activation_4_loss: 1.2734
# ITERATION: 2 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2954
# 1/1 [==============================] - 6s 6s/step - loss: 1.5573 - activation_5_loss: 0.3509 - activation_4_loss: 1.2064 - val_loss: 4.2050 - val_activation_5_loss: 2.9384 - val_activation_4_loss: 1.2665
# ITERATION: 3 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9305
# 1/1 [==============================] - 6s 6s/step - loss: 2.8149 - activation_5_loss: 0.6985 - activation_4_loss: 2.1164 - val_loss: 4.2560 - val_activation_5_loss: 2.9801 - val_activation_4_loss: 1.2759
# ITERATION: 4 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8514
# 1/1 [==============================] - 6s 6s/step - loss: 1.6349 - activation_5_loss: 0.4332 - activation_4_loss: 1.2017 - val_loss: 4.3457 - val_activation_5_loss: 3.0403 - val_activation_4_loss: 1.3054
# ITERATION: 5 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 4.0577
# 1/1 [==============================] - 6s 6s/step - loss: 1.2340 - activation_5_loss: 0.2078 - activation_4_loss: 1.0262 - val_loss: 4.4553 - val_activation_5_loss: 3.1089 - val_activation_4_loss: 1.3464
# ITERATION: 6 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6474
# 1/1 [==============================] - 6s 6s/step - loss: 0.8700 - activation_5_loss: 0.2580 - activation_4_loss: 0.6120 - val_loss: 4.5942 - val_activation_5_loss: 3.1918 - val_activation_4_loss: 1.4024
# ITERATION: 7 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2833
# 1/1 [==============================] - 6s 6s/step - loss: 1.2017 - activation_5_loss: 0.2917 - activation_4_loss: 0.9100 - val_loss: 4.7761 - val_activation_5_loss: 3.2964 - val_activation_4_loss: 1.4798
# ITERATION: 8 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4920
# 1/1 [==============================] - 6s 6s/step - loss: 0.9971 - activation_5_loss: 0.2611 - activation_4_loss: 0.7360 - val_loss: 5.0062 - val_activation_5_loss: 3.4279 - val_activation_4_loss: 1.5783
# ITERATION: 9 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9724
# 1/1 [==============================] - 6s 6s/step - loss: 0.5734 - activation_5_loss: 0.1202 - activation_4_loss: 0.4533 - val_loss: 5.2762 - val_activation_5_loss: 3.5815 - val_activation_4_loss: 1.6948
# ITERATION: 10 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8647
# 1/1 [==============================] - 6s 6s/step - loss: 0.6271 - activation_5_loss: 0.2738 - activation_4_loss: 0.3533 - val_loss: 5.5562 - val_activation_5_loss: 3.7427 - val_activation_4_loss: 1.8135
# ITERATION: 11 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6730
# 1/1 [==============================] - 6s 6s/step - loss: 0.4751 - activation_5_loss: 0.1265 - activation_4_loss: 0.3486 - val_loss: 5.8614 - val_activation_5_loss: 3.9184 - val_activation_4_loss: 1.9430
# ITERATION: 12 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0853
# 1/1 [==============================] - 6s 6s/step - loss: 1.1934 - activation_5_loss: 0.4330 - activation_4_loss: 0.7605 - val_loss: 6.1598 - val_activation_5_loss: 4.0899 - val_activation_4_loss: 2.0699
# ITERATION: 13 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4534
# 1/1 [==============================] - 6s 6s/step - loss: 0.4862 - activation_5_loss: 0.1398 - activation_4_loss: 0.3463 - val_loss: 6.4416 - val_activation_5_loss: 4.2515 - val_activation_4_loss: 2.1901
# ITERATION: 14 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9738
# 1/1 [==============================] - 6s 6s/step - loss: 0.9082 - activation_5_loss: 0.2366 - activation_4_loss: 0.6716 - val_loss: 6.6941 - val_activation_5_loss: 4.3964 - val_activation_4_loss: 2.2976
# ITERATION: 15 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4644
# 1/1 [==============================] - 6s 6s/step - loss: 0.2889 - activation_5_loss: 0.0604 - activation_4_loss: 0.2285 - val_loss: 6.9442 - val_activation_5_loss: 4.5401 - val_activation_4_loss: 2.4041
# ITERATION: 16 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2092
# 1/1 [==============================] - 6s 6s/step - loss: 0.2801 - activation_5_loss: 0.0902 - activation_4_loss: 0.1899 - val_loss: 7.2008 - val_activation_5_loss: 4.6880 - val_activation_4_loss: 2.5128
# ITERATION: 17 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9020
# 1/1 [==============================] - 6s 6s/step - loss: 0.3020 - activation_5_loss: 0.1011 - activation_4_loss: 0.2009 - val_loss: 7.4461 - val_activation_5_loss: 4.8320 - val_activation_4_loss: 2.6140
# ITERATION: 18 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2496
# 1/1 [==============================] - 6s 6s/step - loss: 0.5055 - activation_5_loss: 0.0867 - activation_4_loss: 0.4187 - val_loss: 7.6903 - val_activation_5_loss: 4.9736 - val_activation_4_loss: 2.7168
# ITERATION: 19 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0335
# 1/1 [==============================] - 6s 6s/step - loss: 0.5471 - activation_5_loss: 0.1240 - activation_4_loss: 0.4230 - val_loss: 7.9248 - val_activation_5_loss: 5.1077 - val_activation_4_loss: 2.8171
# ITERATION: 20 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1903
# 1/1 [==============================] - 6s 6s/step - loss: 0.6295 - activation_5_loss: 0.0467 - activation_4_loss: 0.5828 - val_loss: 8.1317 - val_activation_5_loss: 5.2294 - val_activation_4_loss: 2.9023
# ITERATION: 21 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9108
# 1/1 [==============================] - 6s 6s/step - loss: 0.1808 - activation_5_loss: 0.0785 - activation_4_loss: 0.1022 - val_loss: 8.3309 - val_activation_5_loss: 5.3479 - val_activation_4_loss: 2.9831
# ITERATION: 22 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8754
# 1/1 [==============================] - 6s 6s/step - loss: 0.3345 - activation_5_loss: 0.0426 - activation_4_loss: 0.2919 - val_loss: 8.5127 - val_activation_5_loss: 5.4555 - val_activation_4_loss: 3.0572
# ITERATION: 23 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5864
# 1/1 [==============================] - 6s 6s/step - loss: 0.2211 - activation_5_loss: 0.0282 - activation_4_loss: 0.1929 - val_loss: 8.6874 - val_activation_5_loss: 5.5592 - val_activation_4_loss: 3.1282
# ITERATION: 24 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7708
# 1/1 [==============================] - 6s 6s/step - loss: 0.5027 - activation_5_loss: 0.0787 - activation_4_loss: 0.4240 - val_loss: 8.8727 - val_activation_5_loss: 5.6700 - val_activation_4_loss: 3.2028
# ITERATION: 25 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6783
# 1/1 [==============================] - 6s 6s/step - loss: 0.3095 - activation_5_loss: 0.0617 - activation_4_loss: 0.2478 - val_loss: 9.0517 - val_activation_5_loss: 5.7759 - val_activation_4_loss: 3.2758
# ITERATION: 26 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4467
# 1/1 [==============================] - 6s 6s/step - loss: 0.0712 - activation_5_loss: 0.0269 - activation_4_loss: 0.0443 - val_loss: 9.2138 - val_activation_5_loss: 5.8729 - val_activation_4_loss: 3.3409
# ITERATION: 27 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3991
# 1/1 [==============================] - 6s 6s/step - loss: 0.1216 - activation_5_loss: 0.0123 - activation_4_loss: 0.1092 - val_loss: 9.3601 - val_activation_5_loss: 5.9584 - val_activation_4_loss: 3.4017
# ITERATION: 28 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5720
# 1/1 [==============================] - 6s 6s/step - loss: 0.0902 - activation_5_loss: 0.0291 - activation_4_loss: 0.0611 - val_loss: 9.4828 - val_activation_5_loss: 6.0298 - val_activation_4_loss: 3.4530
# ITERATION: 29 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6988
# 1/1 [==============================] - 6s 6s/step - loss: 0.1801 - activation_5_loss: 0.0605 - activation_4_loss: 0.1196 - val_loss: 9.5950 - val_activation_5_loss: 6.0946 - val_activation_4_loss: 3.5003
# ITERATION: 30 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3945
# 1/1 [==============================] - 6s 6s/step - loss: 0.1820 - activation_5_loss: 0.0144 - activation_4_loss: 0.1676 - val_loss: 9.6936 - val_activation_5_loss: 6.1526 - val_activation_4_loss: 3.5410
# ITERATION: 31 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4857
# 1/1 [==============================] - 6s 6s/step - loss: 0.1012 - activation_5_loss: 0.0137 - activation_4_loss: 0.0875 - val_loss: 9.7811 - val_activation_5_loss: 6.2051 - val_activation_4_loss: 3.5760
# ITERATION: 32 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4401
# 1/1 [==============================] - 6s 6s/step - loss: 0.0827 - activation_5_loss: 0.0168 - activation_4_loss: 0.0659 - val_loss: 9.8477 - val_activation_5_loss: 6.2464 - val_activation_4_loss: 3.6013
# ITERATION: 33 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0054
# 1/1 [==============================] - 6s 6s/step - loss: 0.2689 - activation_5_loss: 0.0181 - activation_4_loss: 0.2508 - val_loss: 9.9224 - val_activation_5_loss: 6.2917 - val_activation_4_loss: 3.6307
# ITERATION: 34 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6744
# 1/1 [==============================] - 6s 6s/step - loss: 0.2287 - activation_5_loss: 0.0155 - activation_4_loss: 0.2133 - val_loss: 9.9967 - val_activation_5_loss: 6.3364 - val_activation_4_loss: 3.6603
# ITERATION: 35 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4381
# 1/1 [==============================] - 6s 6s/step - loss: 0.2751 - activation_5_loss: 0.0379 - activation_4_loss: 0.2372 - val_loss: 10.0621 - val_activation_5_loss: 6.3744 - val_activation_4_loss: 3.6877
# ITERATION: 36 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4782
# 1/1 [==============================] - 6s 6s/step - loss: 0.4187 - activation_5_loss: 0.0557 - activation_4_loss: 0.3631 - val_loss: 10.1160 - val_activation_5_loss: 6.4064 - val_activation_4_loss: 3.7096
# ITERATION: 37 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4388
# 1/1 [==============================] - 6s 6s/step - loss: 0.1062 - activation_5_loss: 0.0089 - activation_4_loss: 0.0973 - val_loss: 10.1732 - val_activation_5_loss: 6.4398 - val_activation_4_loss: 3.7335
# ITERATION: 38 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3498
# 1/1 [==============================] - 6s 6s/step - loss: 0.1542 - activation_5_loss: 0.0105 - activation_4_loss: 0.1436 - val_loss: 10.2319 - val_activation_5_loss: 6.4726 - val_activation_4_loss: 3.7593
# ITERATION: 39 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5132
# 1/1 [==============================] - 6s 6s/step - loss: 0.0367 - activation_5_loss: 0.0065 - activation_4_loss: 0.0302 - val_loss: 10.2692 - val_activation_5_loss: 6.4942 - val_activation_4_loss: 3.7749
# ITERATION: 40 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8118
# 1/1 [==============================] - 6s 6s/step - loss: 0.0880 - activation_5_loss: 0.0104 - activation_4_loss: 0.0776 - val_loss: 10.2929 - val_activation_5_loss: 6.5070 - val_activation_4_loss: 3.7859
# ITERATION: 41 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3228
# 1/1 [==============================] - 6s 6s/step - loss: 0.0875 - activation_5_loss: 0.0060 - activation_4_loss: 0.0815 - val_loss: 10.3129 - val_activation_5_loss: 6.5180 - val_activation_4_loss: 3.7949
# ITERATION: 42 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4608
# 1/1 [==============================] - 6s 6s/step - loss: 0.0527 - activation_5_loss: 0.0034 - activation_4_loss: 0.0493 - val_loss: 10.3273 - val_activation_5_loss: 6.5255 - val_activation_4_loss: 3.8018
# ITERATION: 43 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3422
# 1/1 [==============================] - 6s 6s/step - loss: 0.1091 - activation_5_loss: 0.0035 - activation_4_loss: 0.1056 - val_loss: 10.3510 - val_activation_5_loss: 6.5380 - val_activation_4_loss: 3.8130
# ITERATION: 44 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4981
# 1/1 [==============================] - 6s 6s/step - loss: 0.0852 - activation_5_loss: 0.0051 - activation_4_loss: 0.0801 - val_loss: 10.3837 - val_activation_5_loss: 6.5552 - val_activation_4_loss: 3.8285
# ITERATION: 45 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4590
# 1/1 [==============================] - 6s 6s/step - loss: 0.0550 - activation_5_loss: 0.0052 - activation_4_loss: 0.0498 - val_loss: 10.3943 - val_activation_5_loss: 6.5607 - val_activation_4_loss: 3.8336
# ITERATION: 46 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4846
# 1/1 [==============================] - 6s 6s/step - loss: 0.2228 - activation_5_loss: 0.0170 - activation_4_loss: 0.2058 - val_loss: 10.3859 - val_activation_5_loss: 6.5566 - val_activation_4_loss: 3.8293
# ITERATION: 47 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2615
# 1/1 [==============================] - 6s 6s/step - loss: 0.0127 - activation_5_loss: 0.0027 - activation_4_loss: 0.0099 - val_loss: 10.3804 - val_activation_5_loss: 6.5544 - val_activation_4_loss: 3.8260
# ITERATION: 48 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7073
# 1/1 [==============================] - 6s 6s/step - loss: 0.1612 - activation_5_loss: 0.0161 - activation_4_loss: 0.1452 - val_loss: 10.3653 - val_activation_5_loss: 6.5472 - val_activation_4_loss: 3.8181
# ITERATION: 49 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7701
# 1/1 [==============================] - 6s 6s/step - loss: 0.0108 - activation_5_loss: 0.0037 - activation_4_loss: 0.0071 - val_loss: 10.3561 - val_activation_5_loss: 6.5448 - val_activation_4_loss: 3.8112
# ITERATION: 50 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3843
# 1/1 [==============================] - 6s 6s/step - loss: 0.2103 - activation_5_loss: 0.0208 - activation_4_loss: 0.1895 - val_loss: 10.3507 - val_activation_5_loss: 6.5444 - val_activation_4_loss: 3.8063
# ITERATION: 51 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3264
# 1/1 [==============================] - 6s 6s/step - loss: 0.0191 - activation_5_loss: 0.0034 - activation_4_loss: 0.0156 - val_loss: 10.3444 - val_activation_5_loss: 6.5440 - val_activation_4_loss: 3.8004
# ITERATION: 52 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6160
# 1/1 [==============================] - 6s 6s/step - loss: 0.1398 - activation_5_loss: 0.0106 - activation_4_loss: 0.1291 - val_loss: 10.3384 - val_activation_5_loss: 6.5438 - val_activation_4_loss: 3.7946
# ITERATION: 53 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3619
# 1/1 [==============================] - 6s 6s/step - loss: 0.0234 - activation_5_loss: 0.0015 - activation_4_loss: 0.0219 - val_loss: 10.3154 - val_activation_5_loss: 6.5340 - val_activation_4_loss: 3.7814
# ITERATION: 54 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4285
# 1/1 [==============================] - 6s 6s/step - loss: 0.0196 - activation_5_loss: 0.0077 - activation_4_loss: 0.0119 - val_loss: 10.2888 - val_activation_5_loss: 6.5216 - val_activation_4_loss: 3.7672
# ITERATION: 55 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4748
# 1/1 [==============================] - 6s 6s/step - loss: 0.0442 - activation_5_loss: 0.0022 - activation_4_loss: 0.0421 - val_loss: 10.2502 - val_activation_5_loss: 6.5021 - val_activation_4_loss: 3.7481
# ITERATION: 56 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8922
# 1/1 [==============================] - 6s 6s/step - loss: 0.0193 - activation_5_loss: 0.0027 - activation_4_loss: 0.0165 - val_loss: 10.2065 - val_activation_5_loss: 6.4798 - val_activation_4_loss: 3.7267
# ITERATION: 57 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7811
# 1/1 [==============================] - 6s 6s/step - loss: 0.0450 - activation_5_loss: 0.0015 - activation_4_loss: 0.0436 - val_loss: 10.1707 - val_activation_5_loss: 6.4616 - val_activation_4_loss: 3.7091
# ITERATION: 58 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0971
# 1/1 [==============================] - 6s 6s/step - loss: 0.1137 - activation_5_loss: 0.0037 - activation_4_loss: 0.1100 - val_loss: 10.1488 - val_activation_5_loss: 6.4504 - val_activation_4_loss: 3.6984
# ITERATION: 59 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4977
# 1/1 [==============================] - 6s 6s/step - loss: 0.0657 - activation_5_loss: 0.0023 - activation_4_loss: 0.0635 - val_loss: 10.1331 - val_activation_5_loss: 6.4424 - val_activation_4_loss: 3.6907
# ITERATION: 60 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3640
# 1/1 [==============================] - 6s 6s/step - loss: 0.0364 - activation_5_loss: 9.4395e-04 - activation_4_loss: 0.0354 - val_loss: 10.1053 - val_activation_5_loss: 6.4281 - val_activation_4_loss: 3.6772
# ITERATION: 61 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7127
# 1/1 [==============================] - 6s 6s/step - loss: 0.0317 - activation_5_loss: 0.0025 - activation_4_loss: 0.0292 - val_loss: 10.0702 - val_activation_5_loss: 6.4103 - val_activation_4_loss: 3.6599
# ITERATION: 62 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4788
# 1/1 [==============================] - 6s 6s/step - loss: 0.0600 - activation_5_loss: 8.2876e-04 - activation_4_loss: 0.0591 - val_loss: 10.0325 - val_activation_5_loss: 6.3919 - val_activation_4_loss: 3.6406
# ITERATION: 63 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3575
# 1/1 [==============================] - 7s 7s/step - loss: 0.0284 - activation_5_loss: 0.0025 - activation_4_loss: 0.0260 - val_loss: 10.0040 - val_activation_5_loss: 6.3788 - val_activation_4_loss: 3.6252
# ITERATION: 64 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5236
# 1/1 [==============================] - 6s 6s/step - loss: 0.0093 - activation_5_loss: 6.7427e-04 - activation_4_loss: 0.0087 - val_loss: 9.9882 - val_activation_5_loss: 6.3719 - val_activation_4_loss: 3.6163
# ITERATION: 65 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6031
# 1/1 [==============================] - 6s 6s/step - loss: 0.2470 - activation_5_loss: 0.0095 - activation_4_loss: 0.2375 - val_loss: 9.9942 - val_activation_5_loss: 6.3785 - val_activation_4_loss: 3.6158
# ITERATION: 66 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3022
# 1/1 [==============================] - 6s 6s/step - loss: 0.0980 - activation_5_loss: 0.0290 - activation_4_loss: 0.0691 - val_loss: 10.0005 - val_activation_5_loss: 6.3843 - val_activation_4_loss: 3.6162
# ITERATION: 67 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3246
# 1/1 [==============================] - 6s 6s/step - loss: 0.0184 - activation_5_loss: 9.8752e-04 - activation_4_loss: 0.0174 - val_loss: 10.0133 - val_activation_5_loss: 6.3929 - val_activation_4_loss: 3.6204
# ITERATION: 68 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5410
# 1/1 [==============================] - 6s 6s/step - loss: 0.0391 - activation_5_loss: 0.0032 - activation_4_loss: 0.0359 - val_loss: 10.0460 - val_activation_5_loss: 6.4120 - val_activation_4_loss: 3.6341
# ITERATION: 69 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4486
# 1/1 [==============================] - 6s 6s/step - loss: 0.1320 - activation_5_loss: 0.0080 - activation_4_loss: 0.1240 - val_loss: 10.0869 - val_activation_5_loss: 6.4346 - val_activation_4_loss: 3.6523
# ITERATION: 70 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8893
# 1/1 [==============================] - 6s 6s/step - loss: 0.0549 - activation_5_loss: 0.0054 - activation_4_loss: 0.0495 - val_loss: 10.1479 - val_activation_5_loss: 6.4676 - val_activation_4_loss: 3.6803
# ITERATION: 71 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3314
# 1/1 [==============================] - 6s 6s/step - loss: 0.0913 - activation_5_loss: 0.0013 - activation_4_loss: 0.0900 - val_loss: 10.2080 - val_activation_5_loss: 6.4999 - val_activation_4_loss: 3.7081
# ITERATION: 72 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3407
# 1/1 [==============================] - 6s 6s/step - loss: 0.0799 - activation_5_loss: 0.0017 - activation_4_loss: 0.0782 - val_loss: 10.2598 - val_activation_5_loss: 6.5269 - val_activation_4_loss: 3.7328
# ITERATION: 73 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3223
# 1/1 [==============================] - 6s 6s/step - loss: 0.1553 - activation_5_loss: 0.0126 - activation_4_loss: 0.1427 - val_loss: 10.3155 - val_activation_5_loss: 6.5561 - val_activation_4_loss: 3.7594
# ITERATION: 74 of 75.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3664
# 1/1 [==============================] - 6s 6s/step - loss: 0.0119 - activation_5_loss: 0.0010 - activation_4_loss: 0.0109 - val_loss: 10.3642 - val_activation_5_loss: 6.5821 - val_activation_4_loss: 3.7822

# %%
import pandas as pd

stats = pd.DataFrame(log_list)
stats.to_csv("results/roberta_base_squad2_512in_cccspans_sizecats_75ii.csv")
model.save("roberta_base_squad2_512in_cccspans_sizecats_75ii")
model_cat.save("roberta_base_squad2_512in_cccspans_sizecats_75ii_auxiliary")
# Out:
# WARNING:tensorflow:From /home/ben/anaconda3/envs/distant_crowds/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: roberta_base_squad2_512in_cccspans_sizecats_75ii/assets
# INFO:tensorflow:Assets written to: roberta_base_squad2_512in_cccspans_sizecats_75ii_auxiliary/assets

# %%
pred_start_v, pred_end_v = model.predict((x_valid[0], x_valid[1], x_valid[2]), batch_size=36, verbose=1)
valid_acc = merge_squad_results(valid_examples, pred_start_v, pred_end_v)

pred_start_t, pred_end_t = model.predict((x_test[0], x_test[1], x_test[2]), batch_size=36, verbose=1)
test_acc = merge_squad_results(test_examples, pred_start_t, pred_end_t)

print(f"Validation set accuracy (EM): {valid_acc[0]}")
print(f"Test set accuracy (EM): {test_acc[0]}")
print(f"Validation set F1: {valid_acc[1]}")
print(f"Test set F1: {test_acc[1]}")

pd.DataFrame([{"model":"roberta_base_squad2_512in_cccspans_sizecats_75ii",
              "f1_valid":valid_acc[1],"f1_test":test_acc[1],
              "em_valid":valid_acc[0],"em_test":test_acc[0]}]).to_csv("results/roberta_f1v_f1t_emv_emt.csv",mode="a",header=False)
# Out:
# 21/21 [==============================] - 6s 273ms/step
# 92/92 [==============================] - 28s 299ms/step
# Validation set accuracy (EM): 0.68
# Test set accuracy (EM): 0.6691891891891892
# Validation set F1: 0.6580003320180792
# Test set F1: 0.6498851631310648

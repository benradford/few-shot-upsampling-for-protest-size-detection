# %%
import os
# os.environ["CUDA_VISIBLE_DEVICES"]="0"
import re
import json
import string
import numpy as np
import tensorflow as tf
from pprint import pprint
from tensorflow import keras
from tensorflow.keras import layers
from tokenizers import BertWordPieceTokenizer
from transformers import RobertaTokenizer, RobertaTokenizerFast, TFRobertaModel
from tensorflow import keras

tf.random.set_seed(1234)
np.random.seed(1234)

seq_len = 450
max_len = 512

###################
## TRAINING DATA ##
###################
ccc_train = []

with open('/home/ben/GDrive/Projects/distant_crowds/data/ccc_train.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    ccc_train.append(json.loads(json_str))

for ex in ccc_train:
    ex["text"] = " ".join(ex["text"].split())
    ex["size_text"] = " ".join(ex["size_text"].split())

print(f"Training examples from raw data: {len(ccc_train)}")
# ccc_train = [a for a in ccc_train if a["size_text"].lower() in a["text"].lower()]
print(f"Training examples after removing unmatched size_text strings: {len(ccc_train)}")


######################
## SPAN TUNING DATA ##
######################
ccc_tune = []

with open('../data/ccc_span_tune.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    ccc_tune.append(json.loads(json_str))

for ex in ccc_tune:
    ex["para"] = " ".join(ex["para"].split())
    ex["size_text"] = " ".join(ex["size_text"].split())    

print(f"Span tune examples in raw data: {len(ccc_tune)}")
ccc_tune = [a for a in ccc_tune if a["size_text"].lower() in a["para"].lower()]
print(f"Span tune examples after removing unmatched size_text strings: {len(ccc_tune)}")

ccc_tune = {"data":[{"paragraphs":[{"context":qq["para"],
                             "qas":[
                                 {"answers":[{"answer_start":qq["para"].lower().index(qq["size_text"].lower()),
                                              "text":qq["size_text"]}],
                                  "question":"How many people protested?"}
                             ]}]} for qq in ccc_tune]}

##################
## TESTING DATA ##
##################
ccc_test = []

with open('../data/ccc_test_set.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    ccc_test.append(json.loads(json_str))
    
for ex in ccc_test:
    ex["text"] = " ".join(ex["text"].split())
    ex["size_text"] = " ".join(ex["size_text"].split())
    
print(f"Testing examples from raw data: {len(ccc_test)}")
ccc_test = [a for a in ccc_test if a["size_text"].lower() in a["text"].lower()]
print(f"Testing examples after removing unmatched size_text strings: {len(ccc_test)}")

ccc_test = {"data":[{"paragraphs":[{"context":" ".join(qq["text"].split()),
                             "qas":[
                                 {"answers":[{"answer_start":qq["text"].lower().index(qq["size_text"].lower()),
                                              "text":qq["size_text"]}],
                                  "question":"How many people protested?"}
                             ]}]} for qq in ccc_test]}

#####################
## VALIDATION DATA ##
#####################
ccc_valid = []

with open('../data/ccc_validation_set.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    ccc_valid.append(json.loads(json_str))
    
for ex in ccc_valid:
    ex["text"] = " ".join(ex["text"].split())
    ex["size_text"] = " ".join(ex["size_text"].split())
    
print(f"Valid examples from raw data: {len(ccc_valid)}")
ccc_valid = [a for a in ccc_valid if a["size_text"].lower() in a["text"].lower()]
print(f"Valid examples after removing unmatched size_text strings: {len(ccc_valid)}")

ccc_valid = {"data":[{"paragraphs":[{"context":" ".join(qq["text"].split()),
                             "qas":[
                                 {"answers":[{"answer_start":qq["text"].lower().index(qq["size_text"].lower()),
                                              "text":qq["size_text"]}],
                                  "question":"How many people protested?"}
                             ]}]} for qq in ccc_valid]}

########################
## SOFT-LABELED TRAIN ##
########################
soft_train = []

with open('../data/soft_labeled_train.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    soft_train.append(json.loads(json_str))
    
for ex in soft_train:
    ex["context"] = " ".join(ex["context"].split())
    ex["labeled_text"] = " ".join(ex["labeled_text"].split())
    
# print(f"Soft examples from raw data: {len(soft_train)}")
# soft_train = [a for a in soft_train if a["labeled_text"].lower() in a["context"].lower()]
# print(f"Soft examples after removing unmatched size_text strings: {len(soft_train)}")

# soft_train = {"data":[{"paragraphs":[{"context":" ".join(qq["context"].split()),
#                              "qas":[
#                                  {"answers":[{"answer_start":qq["context"].lower().index(qq["labeled_text"].lower()),
#                                               "text":qq["labeled_text"]}],
#                                   "question":"How many people protested?"}
#                              ]}]} for qq in soft_train]}

#########################
## TOKENIZER AND MODEL ##
#########################

tokenizer = RobertaTokenizerFast.from_pretrained("roberta-base")
# Out:
# Training examples from raw data: 2694
# Training examples after removing unmatched size_text strings: 2694
# Span tune examples in raw data: 25
# Span tune examples after removing unmatched size_text strings: 25
# Testing examples from raw data: 930
# Testing examples after removing unmatched size_text strings: 925
# Valid examples from raw data: 200
# Valid examples after removing unmatched size_text strings: 200

# %%
x_cat_inputs = []
x_cat_attentions = []
x_cat_types = []
y_cat = []
y_start = []
y_end = []

for ii, ex in enumerate(ccc_train):
    text = ex["text"]
    answer = soft_train[ii]["labeled_text"]
    
    tokenized_context = tokenizer(text, return_offsets_mapping=True)
    tokenized_question = tokenizer("</s> How many people protested?", return_offsets_mapping=True)
    
    if len(tokenized_context.input_ids) > seq_len:
        continue
    
    ########################
    ## MERGE IN SOFT SPAN ##
    ########################
    try:
        start_char_idx = text.lower().index(answer.lower())
    except:
        continue
    
    # Find end character index of answer in context
    end_char_idx = start_char_idx + len(answer)

    # Mark the character indexes in context that are in answer
    is_char_in_ans = [0] * len(text)
    for idx in range(start_char_idx, end_char_idx):
        is_char_in_ans[idx] = 1

    # Find tokens that were created from answer characters
    ans_token_idx = []
    for idx, (start, end) in enumerate(tokenized_context.offset_mapping):
        if sum(is_char_in_ans[start:end]) > 0:
            ans_token_idx.append(idx)

    # Find start and end token index for tokens from answer
    start_token_idx = ans_token_idx[0]
    end_token_idx = ans_token_idx[-1]
    y_start.append(start_token_idx)
    y_end.append(end_token_idx)
    #######################
    ##                   ##
    #######################                                    
    
    context_ids = tokenized_context.input_ids[0:-1]
    question_ids = tokenized_question.input_ids[1:]
    input_ids = context_ids + question_ids
    
    padding = [0]*(max_len - len(input_ids))
    
    input_ids = input_ids + (np.array(padding)+1).tolist()
    attention_mask = [1]*len(context_ids) + [1]*len(question_ids) + [0]*len(padding)
    token_type_ids = [0]*len(context_ids) + [1]*len(question_ids) + [1]*len(padding)
    
    x_cat_inputs.append(input_ids)
    x_cat_attentions.append(attention_mask)
    x_cat_types.append(token_type_ids)
    y_cat.append(ex["size_cat"])

x_cat = (np.array(x_cat_inputs),
         np.array(x_cat_types),
         np.array(x_cat_attentions))
y_cat = (np.array(y_cat),
         np.array(y_start),
         np.array(y_end))
print(len(x_cat_inputs))
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1134 > 512). Running this sequence through the model will result in indexing errors
# 606

# %%
class SquadExample:
    def __init__(self, question, context, start_char_idx, answer_text, all_answers, seq_len, max_len):
        
        # Clean context, answer and question
        context = " ".join(str(context).split())
        question = " ".join(str(question).split())
        answer = " ".join(str(answer_text).split())

        self.question = str(question)
        self.context = str(context)
        self.start_char_idx = start_char_idx
        self.answer_text = str(answer)
        self.all_answers = all_answers
        self.max_len = max_len
        self.seq_len = seq_len
        self.skip_doc = False
        
        self.input_ids = None
        self.attention_mask = None
        self.token_type_ids = None
        self.start_token_idx = None
        self.end_token_idx = None
        self.skip = None
        
    def __str__(self):
        print(np.stack(self.input_ids).shape)
        print(np.stack(self.token_type_ids).shape)
        print(np.stack(self.attention_mask).shape)
        return "<SquadExample>"
        
    def __repr__(self):
        return repr({"input_ids":self.input_ids, 
                     "token_type_ids":self.token_type_ids, 
                     "attention_mask":self.attention_mask,
                     "start_token_idx":self.start_token_idx,
                     "end_token_idx":self.end_token_idx,
                     "skip":self.skip})

    def preprocess(self):
        context = self.context
        question = self.question
        answer = self.answer_text
        start_char_idx = self.start_char_idx

        # Find end character index of answer in context
        end_char_idx = start_char_idx + len(answer)
        if (end_char_idx >= len(context)) or (start_char_idx < 0):
            self.skip_doc = True
            return

        # Mark the character indexes in context that are in answer
        is_char_in_ans = [0] * len(context)
        for idx in range(start_char_idx, end_char_idx):
            is_char_in_ans[idx] = 1
            
        # Tokenize context
        tokenized_context = tokenizer(context, return_offsets_mapping=True)
        
        context_input_ids = tokenized_context.input_ids
        context_offset_mapping = tokenized_context.offset_mapping
        context_attention_mask = tokenized_context.attention_mask
        
        self.context_input_ids = context_input_ids
        self.context_offset_mapping = context_offset_mapping
        
        # Find tokens that were created from answer characters
        ans_token_idx = []
        for idx, (start, end) in enumerate(context_offset_mapping):
            if sum(is_char_in_ans[start:end]) > 0:
                ans_token_idx.append(idx)

#         if len(ans_token_idx) == 0:
#             self.skip_doc = True
#             return
        if (len(ans_token_idx) == 0):
            ans_token_idx = [-1]

        # Find start and end token index for tokens from answer
        start_token_idx = ans_token_idx[0]
        end_token_idx = ans_token_idx[-1]
        
        self.start_token_idx_master = start_token_idx
        self.end_token_idx_master = end_token_idx
        
        # Tokenize question
        tokenized_question = tokenizer("</s> "+question, return_offsets_mapping=True)
        
        ## Crop start and end tokens
        question_input_ids = tokenized_question.input_ids[1:]
        context_input_ids = context_input_ids[1:-1]

        ##
        ## SPLIT UP CONTEXT INTO MULTIPLE QUESTIONS OF max_len
        ##
        
        if seq_len >= len(context_input_ids):
            offsets = [0]
        else:
            ii = 0
            offsets = []
            while (ii+seq_len) <= len(context_input_ids):
                offsets.append(ii)
                ii = ii + round(seq_len/2)
            offsets = offsets + [len(context_input_ids)-seq_len]
        
        list_input_ids = []
        list_start_token_idx = []
        list_end_token_idx = []
        list_attention_mask = []
        list_token_type_ids = []
        list_skip = []
        
        for ii in offsets:
            subcontext_input_ids = [0]+context_input_ids[ii:(ii+seq_len)]+question_input_ids
            subcontext_start_token_idx = start_token_idx - ii
            subcontext_end_token_idx = end_token_idx - ii
            subcontext_padding = [0] * (self.max_len - len(subcontext_input_ids))
            
            subcontext_attention_mask = [1] * len(subcontext_input_ids) + subcontext_padding
            subcontext_token_type_ids = [0] + [0]*len(context_input_ids[ii:(ii+seq_len)]) + [1]*len(question_input_ids) + (np.array(subcontext_padding)+1).tolist()
            subcontext_input_ids = subcontext_input_ids + (np.array(subcontext_padding)+1).tolist()
            
            if (subcontext_start_token_idx >= 0) and (subcontext_end_token_idx < seq_len):
                skip = False
            else:
                subcontext_start_token_idx = 0
                subcontext_end_token_idx = 0
                skip = False
                
            list_input_ids.append(subcontext_input_ids)
            list_attention_mask.append(subcontext_attention_mask)
            list_token_type_ids.append(subcontext_token_type_ids)
            list_start_token_idx.append(subcontext_start_token_idx)
            list_end_token_idx.append(subcontext_end_token_idx)
            list_skip.append(skip)
        
        self.input_ids = (list_input_ids)
        self.attention_mask = (list_attention_mask)
        self.token_type_ids = (list_token_type_ids)
        self.start_token_idx = (list_start_token_idx)
        self.end_token_idx = (list_end_token_idx)
        self.skip = list_skip
        self.example_offset = offsets
        
    def train_examples(self, include_impossible=False):
        for idx, skip_ex in enumerate(self.skip):
            if include_impossible is False:
                if skip_ex is False:
                    yield  {"input_ids":self.input_ids[idx],
                            "token_type_ids":self.token_type_ids[idx],
                            "attention_mask":self.attention_mask[idx],
                            "start_token_idx":self.start_token_idx[idx],
                            "end_token_idx":self.end_token_idx[idx]}
            else:
                yield  {"input_ids":self.input_ids[idx],
                            "token_type_ids":self.token_type_ids[idx],
                            "attention_mask":self.attention_mask[idx],
                            "start_token_idx":self.start_token_idx[idx],
                            "end_token_idx":self.end_token_idx[idx]}
    
    
    def inference_from_onehot(self, pred_start, pred_end):

#         if force_answer == False:
        if (np.max(np.argmax(pred_start, axis=1)) == 0) and (np.max(np.argmax(pred_end, axis=1)) == 0):
            return("", {"all_answers":self.all_answers,
                        "start_token_pred":-1, 
                        "end_token_pred":-1, 
                        "start_char_pred":-1, 
                        "end_char_pred":-1,
                        "start_token":self.start_token_idx_master,
                        "end_token":self.end_token_idx_master,
                        "tokens_pred":set(list([])),
                        "tokens":set(list(range(self.start_token_idx_master,(self.end_token_idx_master+1))))})
        
        seq_len = min(self.seq_len, len(self.context_input_ids))
        
        pred_start_matrix = np.zeros((len(self.input_ids), len(self.context_input_ids)))
        pred_end_matrix = np.zeros((len(self.input_ids), len(self.context_input_ids)))
        
        for idx, value in enumerate(pred_start):
            offset = self.example_offset[idx]+1
            pred_start_sub = pred_start[idx][1:seq_len]
            pred_end_sub   = pred_end[idx][1:seq_len]
            pred_start_matrix[idx,(offset):(offset+seq_len-1)] = pred_start_sub
            pred_end_matrix[idx,(offset):(offset+seq_len-1)] = pred_end_sub
            
        highest_prob = np.argmax(np.max(pred_start_matrix, axis=1) + np.max(pred_end_matrix, axis=1))
        
        top_start = np.argmax(pred_start_matrix[highest_prob,:])
        top_end   = np.argmax(pred_end_matrix[highest_prob,:])
        
#         pred_start = np.max(pred_start_matrix, axis=0)
#         pred_end   = np.max(pred_end_matrix, axis=0)
        
#         top_start = np.argmax(pred_start)
#         top_end = np.argmax(pred_end)
        
        start_char = self.context_offset_mapping[top_start][0]
        end_char = self.context_offset_mapping[top_end][1]
        
        return (self.context[start_char:end_char], {"all_answers":self.all_answers,
                                                    "start_token_pred":top_start, 
                                                    "end_token_pred":top_end, 
                                                    "start_char_pred":start_char, 
                                                    "end_char_pred":end_char,
                                                    "start_token":self.start_token_idx_master,
                                                    "end_token":self.end_token_idx_master,
                                                    "tokens_pred":set(list(range(top_start,(top_end+1)))),
                                                    "tokens":set(list(range(self.start_token_idx_master,(self.end_token_idx_master+1))))})
                
    def model_inference(self, model):
        pred = model.predict([np.stack(self.input_ids),
                      np.stack(self.attention_mask),
                      np.stack(self.token_type_ids)], batch_size=8)
        pred_start = pred[0]
        pred_end   = pred[1]
        
        return self.inference_from_onehot(pred_start, pred_end)
    
    def fake_inference(self):
        pred_start_mat = []
        pred_end_mat = []
        for idx, val in enumerate(self.start_token_idx):
            pred_start = np.zeros_like(np.array(self.input_ids[idx]))
            pred_end = np.zeros_like(np.array(self.input_ids[idx]))
            if self.skip[idx] == False:
                pred_start[val] = 1.0
                pred_end[self.end_token_idx[idx]] = 1.0
            pred_start_mat.append(pred_start)
            pred_end_mat.append(pred_end)
            
        pred_start_mat = np.array(pred_start_mat)
        pred_end_mat = np.array(pred_end_mat)
        
        return self.inference_from_onehot(pred_start_mat,pred_end_mat)
        

def create_squad_examples(raw_data, seq_len, max_len):
    squad_examples = []
    for item in raw_data["data"]:
        for para in item["paragraphs"]:
            context = para["context"]
            for qa in para["qas"]:
                if len(qa["answers"]) > 0:
                    question = qa["question"]
                    answer_text = qa["answers"][0]["text"]
                    all_answers = [_["text"] for _ in qa["answers"]]
                    start_char_idx = qa["answers"][0]["answer_start"]
                    squad_eg = SquadExample(
                        question, context, start_char_idx, answer_text, all_answers, seq_len, max_len
                    )
                    squad_eg.preprocess()
                    squad_examples.append(squad_eg)
                else:
                    question = qa["question"]
                    answer_text = ""
                    all_answers = [""]
                    start_char_idx = 0
                    squad_eg = SquadExample(
                        question, context, start_char_idx, answer_text, all_answers, seq_len, max_len
                    )
                    squad_eg.preprocess()
                    squad_examples.append(squad_eg)
    return squad_examples


def create_inputs_targets(squad_examples, include_impossible=False):
    dataset_dict = {
        "input_ids": [],
        "token_type_ids": [],
        "attention_mask": [],
        "start_token_idx": [],
        "end_token_idx": [],
    }
    for item in squad_examples:
        if item.skip_doc is False:
            for example in item.train_examples(include_impossible):
                for key in dataset_dict:
                    dataset_dict[key].append(np.array(example[key]))
    for key in dataset_dict:
        dataset_dict[key] = np.array(dataset_dict[key])

    x = (
        dataset_dict["input_ids"],
        dataset_dict["token_type_ids"],
        dataset_dict["attention_mask"])
    y = (dataset_dict["start_token_idx"], dataset_dict["end_token_idx"])
    return x, y


def merge_squad_results(squad_examples, start_preds, end_preds):
    ii = 0
    tally = []
    answers = []
    f1_list = []
    for ex in squad_examples:
        if ex.skip_doc is False:
            n_sub = len(ex.skip)
            pred_out = ex.inference_from_onehot(start_preds[ii:(ii+n_sub),:], end_preds[ii:(ii+n_sub),:])
            tally.append(pred_out[0].lower() in [a.lower() for a in ex.all_answers])
            answers.append(pred_out)
            tp = len(pred_out[1]["tokens_pred"].intersection(pred_out[1]["tokens"]))
            fp = len(pred_out[1]["tokens_pred"].difference(pred_out[1]["tokens"]))
            fn = len(pred_out[1]["tokens"].difference(pred_out[1]["tokens_pred"]))
            ii = ii + n_sub
            if tp>0:
                precision = tp/(tp+fp)
                recall=tp/(tp+fn)
                f1_list.append((2*precision*recall)/(precision+recall))
            else:
                f1_list.append(0)
    return (np.mean(tally), 
            np.mean(f1_list), 
            answers)


# train_squad_examples = create_squad_examples(raw_train_data, seq_len, max_len)
# x_train, y_train = create_inputs_targets(train_squad_examples)
# print(f"{len(train_squad_examples)} docs, {x_train.shape[0]} training points created.")


span_examples = create_squad_examples(ccc_tune, seq_len, max_len)
x_span, y_span = create_inputs_targets(span_examples)
print(f"{len(span_examples)} docs, {x_span[0].shape} span points created.")

test_examples = create_squad_examples(ccc_test, seq_len, max_len)
x_test, y_test = create_inputs_targets(test_examples)
print(f"{len(test_examples)} docs, {x_test[0].shape} test points created.")

valid_examples = create_squad_examples(ccc_valid, seq_len, max_len)
x_valid, y_valid = create_inputs_targets(valid_examples)
print(f"{len(valid_examples)} docs, {x_valid[0].shape} valid points created.")
# Out:
# 25 docs, (25, 512) span points created.
# 925 docs, (3306, 512) test points created.
# 200 docs, (725, 512) valid points created.

# %% [markdown]
# # Train and Validate

# %%
strategy = tf.distribute.MirroredStrategy()
print("Number of devices: {}".format(strategy.num_replicas_in_sync))

with strategy.scope():
    model = keras.models.load_model('./roberta_base_squad2_512in')
model.summary()

def makeMask(x):
    x_cumsum = tf.math.cumsum(x[0], axis=1)
    y_cumsum = tf.math.cumsum(x[1], axis=1, reverse=True)
    prod = tf.math.multiply(x_cumsum, y_cumsum)
    return prod

# def makeMask(x):
#     x_argmax = tf.math.argmax(x[0], axis=1)
#     y_argmax = tf.math.argmax(x[1], axis=1)
#     x_onehot = tf.one_hot(x_argmax, 512, axis=1)
#     y_onehot = tf.one_hot(y_argmax, 512, axis=1)
#     x_cumsum = tf.cumsum(x_onehot, axis=1)
#     y_cumsum = tf.cumsum(y_onehot, axis=1, reverse=True)
#     prod = tf.math.multiply(x_cumsum,y_cumsum)
#     return prod

def expandDims(x):
    return tf.expand_dims(x,2)

with strategy.scope():
    out_start = model.get_layer("activation_4").output
    out_end = model.get_layer("activation_5").output
    span_mask = layers.ActivityRegularization(l1=0.01)(layers.Lambda(makeMask)([out_start,out_end]))
    span_mask_2d = layers.Lambda(tf.tile, arguments={'multiples':(1,1,768)})(layers.Lambda(expandDims)(span_mask))
    roberta_embedding = model.get_layer("roberta").output["last_hidden_state"]
    masked_embedding = layers.Multiply()([span_mask_2d,roberta_embedding])
    
    avg_layer = layers.GlobalMaxPooling1D(data_format="channels_last")(masked_embedding)
    out_count = layers.Dense(1, activation="linear")(avg_layer)

    new_optimizer = keras.optimizers.Adam(lr=(5e-5)*(1/10))
    model_cat = keras.models.Model(inputs=[model.input],outputs=[out_count, out_start, out_end])
    model_cat.compile(optimizer=new_optimizer, 
                      loss=["mean_squared_error",
                            "sparse_categorical_crossentropy",
                            "sparse_categorical_crossentropy"])
    
    model_mask = keras.models.Model(inputs=[model.input],outputs=[span_mask])
    
model_cat.summary()

keras.backend.set_value(model.optimizer.learning_rate, (5e-6))
keras.backend.set_value(model_cat.optimizer.learning_rate, (5e-6))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# roberta (TFRobertaMainLayer)    {'pooler_output': (N 124645632   input_1[0][0]
# __________________________________________________________________________________________________
# start_logit (Dense)             (None, 512, 1)       768         roberta[0][0]
# __________________________________________________________________________________________________
# end_logit (Dense)               (None, 512, 1)       768         roberta[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           start_logit[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           end_logit[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 512)          0           flatten[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 512)          0           flatten_1[0][0]
# ==================================================================================================
# Total params: 124,647,168
# Trainable params: 124,647,168
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# roberta (TFRobertaMainLayer)    {'pooler_output': (N 124645632   input_1[0][0]
# __________________________________________________________________________________________________
# start_logit (Dense)             (None, 512, 1)       768         roberta[0][0]
# __________________________________________________________________________________________________
# end_logit (Dense)               (None, 512, 1)       768         roberta[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           start_logit[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           end_logit[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 512)          0           flatten[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 512)          0           flatten_1[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 512)          0           activation_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# activity_regularization (Activi (None, 512)          0           lambda[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 512, 1)       0           activity_regularization[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 512, 768)     0           lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 512, 768)     0           lambda_1[0][0]
#                                                                  roberta[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d (GlobalMax (None, 768)          0           multiply[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            769         global_max_pooling1d[0][0]
# ==================================================================================================
# Total params: 124,647,937
# Trainable params: 124,647,937
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
pred_start_v, pred_end_v = model.predict((x_valid[0], x_valid[1], x_valid[2]), batch_size=36, verbose=1)
valid_acc = merge_squad_results(valid_examples, pred_start_v, pred_end_v)

pred_start_t, pred_end_t = model.predict((x_test[0], x_test[1], x_test[2]), batch_size=36, verbose=1)
test_acc = merge_squad_results(test_examples, pred_start_t, pred_end_t)

print(f"Validation set accuracy (EM): {valid_acc[0]}")
print(f"Test set accuracy (EM): {test_acc[0]}")
print(f"Validation set F1: {valid_acc[1]}")
print(f"Test set F1: {test_acc[1]}")
# Out:
# 21/21 [==============================] - 5s 262ms/step
# 92/92 [==============================] - 26s 286ms/step
# Validation set accuracy (EM): 0.19
# Test set accuracy (EM): 0.16972972972972972
# Validation set F1: 0.27271624189581933
# Test set F1: 0.2658847892310077

# %%
log_list = []

batch_size = 12


for ii in range(75):
    print(f"ITERATION: {ii} of 75.")
    
#     valid_loss = model.evaluate((x_valid[0],
#                             x_valid[1],
#                             x_valid[2]),
#                             y_valid,
#                            verbose=1,
#                            batch_size=36,
#                            return_dict=True)
#     pred_start, pred_end = model.predict((x_valid[0], x_valid[1], x_valid[2]), batch_size=36, verbose=1)
#     valid_acc = merge_squad_results(valid_examples, pred_start, pred_end)[0]
    
#     print(f"ACCURACY: {valid_acc}")
    
#     validation_loss.append(valid_loss)
#     validation_accuracy.append(valid_acc)
#     batch.append(ii*2)
    
    cat_ii = np.random.choice(range(x_cat[0].shape[0]), batch_size, replace=True)
    
    model_cat.fit(
        (x_cat[0][cat_ii,:],
         x_cat[1][cat_ii,:],
         x_cat[2][cat_ii,:]),
        (y_cat[0][cat_ii],
         y_cat[1][cat_ii],
         y_cat[2][cat_ii]),
        epochs=1,  # For demonstration, 3 epochs are recommended
        verbose=1,
        batch_size=batch_size,  # Made this smaller. Bump up.
    )
    
    cat_ii = np.random.choice(range(x_cat[0].shape[0]), batch_size, replace=True)
    
    model_cat.fit(
        (x_cat[0][cat_ii,:],
         x_cat[1][cat_ii,:],
         x_cat[2][cat_ii,:]),
        (y_cat[0][cat_ii],
         y_cat[1][cat_ii],
         y_cat[2][cat_ii]),
        epochs=1,  # For demonstration, 3 epochs are recommended
        verbose=1,
        batch_size=batch_size,  # Made this smaller. Bump up.
    )
  
    
# valid_loss = model.evaluate((x_valid[0],
#                             x_valid[1],
#                             x_valid[2]),
#                             y_valid[0],
#                            verbose=1,
#                            batch_size=36,
#                            return_dict=True)

# pred_start, pred_end = model.predict((x_valid[0], x_valid[1], x_valid[2]), batch_size=36, verbose=1)
# valid_acc = merge_squad_results(valid_examples, pred_start, pred_end)[0]

# validation_loss.append(valid_loss)
# validation_accuracy.append(valid_acc)
# batch.append(ii*2)
# Out:
# ITERATION: 0 of 75.
# WARNING:tensorflow:5 out of the last 5 calls to <function recreate_function.<locals>.restored_function_body at 0x7fe44c5c5488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function recreate_function.<locals>.restored_function_body at 0x7fe44c5c5488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# INFO:tensorflow:batch_all_reduce: 200 all-reduces with algorithm = nccl, num_packs = 1
# WARNING:tensorflow:Efficient allreduce is not supported for 3 IndexedSlices
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 200 all-reduces with algorithm = nccl, num_packs = 1
# WARNING:tensorflow:Efficient allreduce is not supported for 3 IndexedSlices
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 2.5891 - activation_5_loss: 3.6188 - loss: 9.9019 - activation_4_loss: 3.5176
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 1.8099 - activation_5_loss: 3.8952 - loss: 8.8244 - activation_4_loss: 2.9144
# ITERATION: 1 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 2.1437 - activation_5_loss: 2.7288 - loss: 7.1829 - activation_4_loss: 2.0780
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 2.0661 - activation_5_loss: 2.9597 - loss: 7.6051 - activation_4_loss: 2.3995
# ITERATION: 2 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 2.6025 - activation_5_loss: 1.6787 - loss: 6.6058 - activation_4_loss: 2.1374
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 3.8867 - activation_5_loss: 2.6463 - loss: 9.0946 - activation_4_loss: 2.3210
# ITERATION: 3 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 2.4782 - activation_5_loss: 1.7616 - loss: 6.2552 - activation_4_loss: 1.7903
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 1.7499 - activation_5_loss: 1.3084 - loss: 4.5756 - activation_4_loss: 1.4162
# ITERATION: 4 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 1.4887 - activation_5_loss: 2.5378 - loss: 6.0896 - activation_4_loss: 1.8336
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 3.8002 - activation_5_loss: 0.9312 - loss: 6.3370 - activation_4_loss: 1.3587
# ITERATION: 5 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 1.7651 - activation_5_loss: 3.0535 - loss: 8.7357 - activation_4_loss: 3.5724
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 1.6273 - activation_5_loss: 2.0726 - loss: 6.4791 - activation_4_loss: 2.6462
# ITERATION: 6 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.7596 - activation_5_loss: 1.6324 - loss: 4.1016 - activation_4_loss: 1.5792
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 2.0525 - activation_5_loss: 2.5810 - loss: 6.5617 - activation_4_loss: 1.7702
# ITERATION: 7 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 1.6103 - activation_5_loss: 1.9538 - loss: 5.7957 - activation_4_loss: 1.9624
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.9785 - activation_5_loss: 1.4865 - loss: 3.8976 - activation_4_loss: 1.2202
# ITERATION: 8 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 1.4086 - activation_5_loss: 1.9621 - loss: 4.7975 - activation_4_loss: 1.2800
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 1.9035 - activation_5_loss: 0.8698 - loss: 4.3172 - activation_4_loss: 1.3018
# ITERATION: 9 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 1.5309 - activation_5_loss: 1.6732 - loss: 4.7588 - activation_4_loss: 1.2650
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 1.4564 - activation_5_loss: 2.5230 - loss: 5.5187 - activation_4_loss: 1.3547
# ITERATION: 10 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 1.1815 - activation_5_loss: 1.5125 - loss: 4.7432 - activation_4_loss: 1.9047
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 1.2824 - activation_5_loss: 1.3835 - loss: 4.3660 - activation_4_loss: 1.5358
# ITERATION: 11 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 1.8593 - activation_5_loss: 3.4453 - loss: 7.6320 - activation_4_loss: 2.0597
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 1.1039 - activation_5_loss: 0.9049 - loss: 2.9645 - activation_4_loss: 0.8393
# ITERATION: 12 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 1.1129 - activation_5_loss: 2.2501 - loss: 5.6989 - activation_4_loss: 2.1744
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.9895 - activation_5_loss: 1.5545 - loss: 4.4050 - activation_4_loss: 1.6096
# ITERATION: 13 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.9209 - activation_5_loss: 2.4544 - loss: 5.2987 - activation_4_loss: 1.8112
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 1.1992 - activation_5_loss: 1.5698 - loss: 4.0751 - activation_4_loss: 1.2259
# ITERATION: 14 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 1.6654 - activation_5_loss: 2.5318 - loss: 6.9713 - activation_4_loss: 2.6128
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.8811 - activation_5_loss: 3.0164 - loss: 5.2219 - activation_4_loss: 1.1871
# ITERATION: 15 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 1.3544 - activation_5_loss: 3.0382 - loss: 5.9452 - activation_4_loss: 1.3237
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4548 - activation_5_loss: 1.2449 - loss: 2.9803 - activation_4_loss: 1.2040
# ITERATION: 16 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4806 - activation_5_loss: 1.6407 - loss: 3.1321 - activation_4_loss: 0.8825
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.8339 - activation_5_loss: 2.5556 - loss: 4.8639 - activation_4_loss: 1.3243
# ITERATION: 17 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.6508 - activation_5_loss: 1.7469 - loss: 3.5393 - activation_4_loss: 0.9522
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.7042 - activation_5_loss: 1.1464 - loss: 3.2298 - activation_4_loss: 1.1448
# ITERATION: 18 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.7576 - activation_5_loss: 0.6537 - loss: 2.3540 - activation_4_loss: 0.7200
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.9476 - activation_5_loss: 1.1558 - loss: 3.4948 - activation_4_loss: 1.2210
# ITERATION: 19 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.7998 - activation_5_loss: 1.4812 - loss: 3.3494 - activation_4_loss: 0.8302
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 1.1255 - activation_5_loss: 0.8073 - loss: 2.4970 - activation_4_loss: 0.4302
# ITERATION: 20 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3052 - activation_5_loss: 1.5264 - loss: 3.5138 - activation_4_loss: 1.5183
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4359 - activation_5_loss: 2.6419 - loss: 5.2908 - activation_4_loss: 2.0526
# ITERATION: 21 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.8138 - activation_5_loss: 1.0078 - loss: 2.7145 - activation_4_loss: 0.6400
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4182 - activation_5_loss: 1.3185 - loss: 2.9805 - activation_4_loss: 1.1504
# ITERATION: 22 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.5985 - activation_5_loss: 1.6401 - loss: 3.8189 - activation_4_loss: 1.4918
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4622 - activation_5_loss: 2.0475 - loss: 5.2102 - activation_4_loss: 2.5122
# ITERATION: 23 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4395 - activation_5_loss: 0.5986 - loss: 2.0451 - activation_4_loss: 0.8437
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4378 - activation_5_loss: 1.6065 - loss: 3.3555 - activation_4_loss: 1.2493
# ITERATION: 24 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.2958 - activation_5_loss: 1.6248 - loss: 4.1318 - activation_4_loss: 2.0744
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3774 - activation_5_loss: 3.1257 - loss: 5.1655 - activation_4_loss: 1.5141
# ITERATION: 25 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3736 - activation_5_loss: 0.8412 - loss: 2.1547 - activation_4_loss: 0.8374
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.5494 - activation_5_loss: 0.6366 - loss: 1.6770 - activation_4_loss: 0.3426
# ITERATION: 26 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3248 - activation_5_loss: 1.7195 - loss: 3.9255 - activation_4_loss: 1.6871
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3414 - activation_5_loss: 0.7923 - loss: 1.7887 - activation_4_loss: 0.5544
# ITERATION: 27 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4688 - activation_5_loss: 1.2312 - loss: 3.5869 - activation_4_loss: 1.7433
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3803 - activation_5_loss: 1.1487 - loss: 3.3056 - activation_4_loss: 1.5866
# ITERATION: 28 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3889 - activation_5_loss: 1.4541 - loss: 3.0495 - activation_4_loss: 1.1045
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.5517 - activation_5_loss: 3.6669 - loss: 6.1319 - activation_4_loss: 1.7394
# ITERATION: 29 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 1.4380 - activation_5_loss: 2.0975 - loss: 4.7890 - activation_4_loss: 1.0695
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.2888 - activation_5_loss: 1.7009 - loss: 2.9058 - activation_4_loss: 0.8022
# ITERATION: 30 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.6101 - activation_5_loss: 0.6165 - loss: 1.8355 - activation_4_loss: 0.5217
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.2896 - activation_5_loss: 1.9343 - loss: 2.7548 - activation_4_loss: 0.4010
# ITERATION: 31 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.2787 - activation_5_loss: 1.8963 - loss: 4.5040 - activation_4_loss: 2.1732
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4273 - activation_5_loss: 0.9178 - loss: 2.6849 - activation_4_loss: 1.2029
# ITERATION: 32 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.7097 - activation_5_loss: 1.4410 - loss: 3.6176 - activation_4_loss: 1.2988
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3117 - activation_5_loss: 2.2717 - loss: 3.8797 - activation_4_loss: 1.1994
# ITERATION: 33 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3829 - activation_5_loss: 1.4108 - loss: 2.9367 - activation_4_loss: 1.0184
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.2353 - activation_5_loss: 2.0761 - loss: 3.4224 - activation_4_loss: 0.9784
# ITERATION: 34 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4772 - activation_5_loss: 1.0288 - loss: 2.4122 - activation_4_loss: 0.7461
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.2765 - activation_5_loss: 1.8174 - loss: 3.0832 - activation_4_loss: 0.8190
# ITERATION: 35 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.6213 - activation_5_loss: 1.4815 - loss: 3.9555 - activation_4_loss: 1.6388
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4445 - activation_5_loss: 0.6328 - loss: 2.3558 - activation_4_loss: 1.0430
# ITERATION: 36 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3335 - activation_5_loss: 1.1341 - loss: 3.1232 - activation_4_loss: 1.5406
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3945 - activation_5_loss: 1.0513 - loss: 2.5604 - activation_4_loss: 0.9668
# ITERATION: 37 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4431 - activation_5_loss: 0.3295 - loss: 1.3337 - activation_4_loss: 0.4318
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.1359 - activation_5_loss: 1.5594 - loss: 2.3623 - activation_4_loss: 0.5715
# ITERATION: 38 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4332 - activation_5_loss: 0.7097 - loss: 1.7316 - activation_4_loss: 0.3975
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3149 - activation_5_loss: 0.9782 - loss: 2.2799 - activation_4_loss: 0.8409
# ITERATION: 39 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4319 - activation_5_loss: 2.3116 - loss: 5.0717 - activation_4_loss: 2.1345
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3302 - activation_5_loss: 0.2571 - loss: 0.8382 - activation_4_loss: 0.1949
# ITERATION: 40 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.2722 - activation_5_loss: 2.6971 - loss: 5.5757 - activation_4_loss: 2.3764
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.5729 - activation_5_loss: 2.7630 - loss: 5.9222 - activation_4_loss: 2.3624
# ITERATION: 41 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4338 - activation_5_loss: 1.8001 - loss: 3.3331 - activation_4_loss: 1.0342
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3548 - activation_5_loss: 0.8252 - loss: 3.0747 - activation_4_loss: 1.7199
# ITERATION: 42 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4899 - activation_5_loss: 0.8753 - loss: 2.6362 - activation_4_loss: 1.1150
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.7277 - activation_5_loss: 1.2370 - loss: 2.7470 - activation_4_loss: 0.6292
# ITERATION: 43 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.6630 - activation_5_loss: 1.2494 - loss: 2.9410 - activation_4_loss: 0.8536
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.2797 - activation_5_loss: 1.5886 - loss: 3.2220 - activation_4_loss: 1.1957
# ITERATION: 44 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.2721 - activation_5_loss: 1.1566 - loss: 2.1171 - activation_4_loss: 0.5528
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3906 - activation_5_loss: 2.2723 - loss: 4.3383 - activation_4_loss: 1.4557
# ITERATION: 45 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3761 - activation_5_loss: 0.5522 - loss: 1.7535 - activation_4_loss: 0.7138
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.2713 - activation_5_loss: 1.3416 - loss: 2.4114 - activation_4_loss: 0.6556
# ITERATION: 46 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.1623 - activation_5_loss: 1.6239 - loss: 3.3397 - activation_4_loss: 1.3441
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.2294 - activation_5_loss: 1.6146 - loss: 3.2017 - activation_4_loss: 1.1217
# ITERATION: 47 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.5480 - activation_5_loss: 0.8609 - loss: 2.6547 - activation_4_loss: 1.0329
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3342 - activation_5_loss: 1.9809 - loss: 4.5518 - activation_4_loss: 1.8873
# ITERATION: 48 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4271 - activation_5_loss: 0.7239 - loss: 2.1243 - activation_4_loss: 0.8279
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3606 - activation_5_loss: 1.7439 - loss: 3.9774 - activation_4_loss: 1.6855
# ITERATION: 49 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3145 - activation_5_loss: 1.9945 - loss: 4.3216 - activation_4_loss: 1.7465
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.8535 - activation_5_loss: 2.7507 - loss: 5.9930 - activation_4_loss: 2.0894
# ITERATION: 50 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 1.4259 - activation_5_loss: 1.7113 - loss: 4.4803 - activation_4_loss: 1.1498
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4221 - activation_5_loss: 1.2477 - loss: 2.8288 - activation_4_loss: 1.0343
# ITERATION: 51 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.5106 - activation_5_loss: 1.2178 - loss: 3.1720 - activation_4_loss: 1.2600
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.5708 - activation_5_loss: 0.9484 - loss: 2.8751 - activation_4_loss: 1.1481
# ITERATION: 52 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.2321 - activation_5_loss: 1.5984 - loss: 3.5856 - activation_4_loss: 1.6134
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3484 - activation_5_loss: 1.7890 - loss: 4.8160 - activation_4_loss: 2.4304
# ITERATION: 53 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.9603 - activation_5_loss: 2.3965 - loss: 5.4937 - activation_4_loss: 1.9234
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.2710 - activation_5_loss: 1.0753 - loss: 3.3158 - activation_4_loss: 1.7210
# ITERATION: 54 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4526 - activation_5_loss: 1.9939 - loss: 4.9674 - activation_4_loss: 2.2866
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3750 - activation_5_loss: 1.0054 - loss: 2.8128 - activation_4_loss: 1.1840
# ITERATION: 55 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3274 - activation_5_loss: 1.1247 - loss: 2.5833 - activation_4_loss: 0.9661
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.6503 - activation_5_loss: 1.2401 - loss: 2.8933 - activation_4_loss: 0.8332
# ITERATION: 56 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3650 - activation_5_loss: 0.7385 - loss: 1.9041 - activation_4_loss: 0.6443
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4778 - activation_5_loss: 1.9854 - loss: 4.0586 - activation_4_loss: 1.4054
# ITERATION: 57 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.9373 - activation_5_loss: 1.6365 - loss: 4.4500 - activation_4_loss: 1.6020
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.1374 - activation_5_loss: 1.0747 - loss: 2.8163 - activation_4_loss: 1.4124
# ITERATION: 58 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.1881 - activation_5_loss: 0.8784 - loss: 1.9448 - activation_4_loss: 0.7209
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3924 - activation_5_loss: 1.1280 - loss: 3.1531 - activation_4_loss: 1.3902
# ITERATION: 59 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.7143 - activation_5_loss: 1.2453 - loss: 3.3192 - activation_4_loss: 1.0703
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3138 - activation_5_loss: 1.0629 - loss: 2.1410 - activation_4_loss: 0.6199
# ITERATION: 60 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.2874 - activation_5_loss: 2.1614 - loss: 4.8649 - activation_4_loss: 2.1376
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.9414 - activation_5_loss: 1.5189 - loss: 3.7967 - activation_4_loss: 1.1456
# ITERATION: 61 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.6745 - activation_5_loss: 1.4223 - loss: 3.1975 - activation_4_loss: 0.9643
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.2090 - activation_5_loss: 0.7879 - loss: 2.0632 - activation_4_loss: 0.8223
# ITERATION: 62 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3278 - activation_5_loss: 1.8726 - loss: 3.7599 - activation_4_loss: 1.3583
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3898 - activation_5_loss: 0.8600 - loss: 2.6683 - activation_4_loss: 1.1643
# ITERATION: 63 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.2157 - activation_5_loss: 1.3086 - loss: 3.5620 - activation_4_loss: 1.7892
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4026 - activation_5_loss: 0.9354 - loss: 2.1892 - activation_4_loss: 0.6427
# ITERATION: 64 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.5505 - activation_5_loss: 1.1773 - loss: 3.1048 - activation_4_loss: 1.2100
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.2175 - activation_5_loss: 0.8605 - loss: 1.9677 - activation_4_loss: 0.6260
# ITERATION: 65 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.1892 - activation_5_loss: 1.2908 - loss: 3.4317 - activation_4_loss: 1.7637
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.2877 - activation_5_loss: 0.6983 - loss: 2.3148 - activation_4_loss: 1.1011
# ITERATION: 66 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.6206 - activation_5_loss: 0.5230 - loss: 2.0782 - activation_4_loss: 0.7582
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.2490 - activation_5_loss: 0.7978 - loss: 2.1031 - activation_4_loss: 0.8777
# ITERATION: 67 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.2992 - activation_5_loss: 1.0041 - loss: 2.6492 - activation_4_loss: 1.1609
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.2241 - activation_5_loss: 2.1274 - loss: 3.8094 - activation_4_loss: 1.3150
# ITERATION: 68 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.2525 - activation_5_loss: 1.4698 - loss: 3.1810 - activation_4_loss: 1.2655
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4431 - activation_5_loss: 1.5142 - loss: 3.2005 - activation_4_loss: 1.0733
# ITERATION: 69 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.5072 - activation_5_loss: 0.8214 - loss: 2.5194 - activation_4_loss: 0.9782
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.9602 - activation_5_loss: 1.7790 - loss: 4.4417 - activation_4_loss: 1.5270
# ITERATION: 70 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3113 - activation_5_loss: 2.0326 - loss: 3.4896 - activation_4_loss: 0.8389
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.5184 - activation_5_loss: 0.4529 - loss: 1.6284 - activation_4_loss: 0.5028
# ITERATION: 71 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.4527 - activation_5_loss: 1.2940 - loss: 2.1205 - activation_4_loss: 0.2600
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3577 - activation_5_loss: 0.8509 - loss: 2.2330 - activation_4_loss: 0.8987
# ITERATION: 72 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.3986 - activation_5_loss: 1.9844 - loss: 4.0626 - activation_4_loss: 1.5706
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.1376 - activation_5_loss: 1.2296 - loss: 2.5885 - activation_4_loss: 1.1327
# ITERATION: 73 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.1827 - activation_5_loss: 0.7899 - loss: 2.3295 - activation_4_loss: 1.1917
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.9386 - activation_5_loss: 1.9084 - loss: 4.5086 - activation_4_loss: 1.3963
# ITERATION: 74 of 75.
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.6458 - activation_5_loss: 0.5064 - loss: 1.9340 - activation_4_loss: 0.6504
# 1/1 [==============================] - 0s 2ms/step - dense_loss: 0.5433 - activation_5_loss: 0.8829 - loss: 2.6136 - activation_4_loss: 1.0245

# %%
import pandas as pd

stats = pd.DataFrame(log_list)
stats.to_csv("results/roberta_base_squad2_512in_sizecats_softspans_75ii.csv")
model.save("roberta_base_squad2_512in_sizecats_softspans_75ii")
model_cat.save("roberta_base_squad2_512in_sizecats_softspans_75ii_auxiliary")
# Out:
# WARNING:tensorflow:7 out of the last 9 calls to <function recreate_function.<locals>.restored_function_body at 0x7fe44c5c5488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:8 out of the last 10 calls to <function recreate_function.<locals>.restored_function_body at 0x7fe44c5c5488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:From /home/ben/anaconda3/envs/distant_crowds/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: roberta_base_squad2_512in_sizecats_softspans_75ii/assets
# INFO:tensorflow:Assets written to: roberta_base_squad2_512in_sizecats_softspans_75ii_auxiliary/assets

# %%
pred_start_v, pred_end_v = model.predict((x_valid[0], x_valid[1], x_valid[2]), batch_size=36, verbose=1)
valid_acc = merge_squad_results(valid_examples, pred_start_v, pred_end_v)

pred_start_t, pred_end_t = model.predict((x_test[0], x_test[1], x_test[2]), batch_size=36, verbose=1)
test_acc = merge_squad_results(test_examples, pred_start_t, pred_end_t)

print(f"Validation set accuracy (EM): {valid_acc[0]}")
print(f"Test set accuracy (EM): {test_acc[0]}")
print(f"Validation set F1: {valid_acc[1]}")
print(f"Test set F1: {test_acc[1]}")

pd.DataFrame([{"model":"roberta_base_squad2_512in_sizecats_softspans_75ii",
              "f1_valid":valid_acc[1],"f1_test":test_acc[1],
              "em_valid":valid_acc[0],"em_test":test_acc[0]}]).to_csv("results/roberta_f1v_f1t_emv_emt.csv",mode="a",header=False)
# Out:
# 21/21 [==============================] - 6s 269ms/step
# 92/92 [==============================] - 27s 296ms/step
# Validation set accuracy (EM): 0.715
# Test set accuracy (EM): 0.6583783783783784
# Validation set F1: 0.6642428315412187
# Test set F1: 0.6321377088687068

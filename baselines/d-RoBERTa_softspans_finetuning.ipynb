# %%
import os
import re
import json
import string
import numpy as np
import tensorflow as tf
from pprint import pprint
from tensorflow import keras
from tensorflow.keras import layers
from tokenizers import BertWordPieceTokenizer
from transformers import RobertaTokenizer, RobertaTokenizerFast, TFRobertaModel
from tensorflow import keras
import jsonlines

tf.random.set_seed(1234)
np.random.seed(1234)

# %% [markdown]
# # Load Data

# %%
seq_len = 450
max_len = 512

###################
## TRAINING DATA ##
###################
ccc_train = []

with open('../data/ccc_train.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    ccc_train.append(json.loads(json_str))

for ex in ccc_train:
    ex["text"] = " ".join(ex["text"].split())
    ex["size_text"] = " ".join(ex["size_text"].split())

print(f"Training examples from raw data: {len(ccc_train)}")
ccc_train = [a for a in ccc_train if a["size_text"].lower() in a["text"].lower()]
print(f"Training examples after removing unmatched size_text strings: {len(ccc_train)}")


######################
## SPAN TUNING DATA ##
######################
ccc_tune = []

with open('../data/ccc_span_tune.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    ccc_tune.append(json.loads(json_str))

for ex in ccc_tune:
    ex["para"] = " ".join(ex["para"].split())
    ex["size_text"] = " ".join(ex["size_text"].split())    

print(f"Span tune examples in raw data: {len(ccc_tune)}")
ccc_tune = [a for a in ccc_tune if a["size_text"].lower() in a["para"].lower()]
print(f"Span tune examples after removing unmatched size_text strings: {len(ccc_tune)}")

ccc_tune = {"data":[{"paragraphs":[{"context":qq["para"],
                             "qas":[
                                 {"answers":[{"answer_start":qq["para"].lower().index(qq["size_text"].lower()),
                                              "text":qq["size_text"]}],
                                  "question":"How many people protested?"}
                             ]}]} for qq in ccc_tune]}


##################
## TESTING DATA ##
##################
ccc_test = []

with open('../data/ccc_test_set.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    ccc_test.append(json.loads(json_str))
    
for ex in ccc_test:
    ex["text"] = " ".join(ex["text"].split())
    ex["size_text"] = " ".join(ex["size_text"].split())
    
print(f"Testing examples from raw data: {len(ccc_test)}")
ccc_test = [a for a in ccc_test if a["size_text"].lower() in a["text"].lower()]
print(f"Testing examples after removing unmatched size_text strings: {len(ccc_test)}")

ccc_test = {"data":[{"paragraphs":[{"context":" ".join(qq["text"].split()),
                             "qas":[
                                 {"answers":[{"answer_start":qq["text"].lower().index(qq["size_text"].lower()),
                                              "text":qq["size_text"]}],
                                  "question":"How many people protested?"}
                             ]}]} for qq in ccc_test]}

#####################
## VALIDATION DATA ##
#####################
ccc_valid = []

with open('../data/ccc_validation_set.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    ccc_valid.append(json.loads(json_str))
    
for ex in ccc_valid:
    ex["text"] = " ".join(ex["text"].split())
    ex["size_text"] = " ".join(ex["size_text"].split())
    
print(f"Valid examples from raw data: {len(ccc_valid)}")
ccc_valid = [a for a in ccc_valid if a["size_text"].lower() in a["text"].lower()]
print(f"Valid examples after removing unmatched size_text strings: {len(ccc_valid)}")

ccc_valid = {"data":[{"paragraphs":[{"context":" ".join(qq["text"].split()),
                             "qas":[
                                 {"answers":[{"answer_start":qq["text"].lower().index(qq["size_text"].lower()),
                                              "text":qq["size_text"]}],
                                  "question":"How many people protested?"}
                             ]}]} for qq in ccc_valid]}

########################
## SOFT-LABELED TRAIN ##
########################
soft_train = []

with open('../data/soft_labeled_train.jsonl', 'r') as json_file:
    json_list = list(json_file)
for json_str in json_list:
    soft_train.append(json.loads(json_str))
    
for ex in soft_train:
    ex["context"] = " ".join(ex["context"].split())
    ex["labeled_text"] = " ".join(ex["labeled_text"].split())
    
print(f"Soft examples from raw data: {len(soft_train)}")
soft_train = [a for a in soft_train if a["labeled_text"].lower() in a["context"].lower()]
print(f"Soft examples after removing unmatched size_text strings: {len(soft_train)}")

soft_train = {"data":[{"paragraphs":[{"context":" ".join(qq["context"].split()),
                             "qas":[
                                 {"answers":[{"answer_start":qq["context"].lower().index(qq["labeled_text"].lower()),
                                              "text":qq["labeled_text"]}],
                                  "question":"How many people protested?"}
                             ]}]} for qq in soft_train]}

#########################
## TOKENIZER AND MODEL ##
#########################

tokenizer = RobertaTokenizerFast.from_pretrained("roberta-base")
# Out:
# Training examples from raw data: 2694
# Training examples after removing unmatched size_text strings: 2685
# Span tune examples in raw data: 25
# Span tune examples after removing unmatched size_text strings: 25
# Testing examples from raw data: 930
# Testing examples after removing unmatched size_text strings: 925
# Valid examples from raw data: 200
# Valid examples after removing unmatched size_text strings: 200
# Soft examples from raw data: 2694
# Soft examples after removing unmatched size_text strings: 2351

# %% [markdown]
# # Prepare Data

# %%
class SquadExample:
    def __init__(self, question, context, start_char_idx, answer_text, all_answers, seq_len, max_len):
        
        # Clean context, answer and question
        context = " ".join(str(context).split())
        question = " ".join(str(question).split())
        answer = " ".join(str(answer_text).split())

        self.question = str(question)
        self.context = str(context)
        self.start_char_idx = start_char_idx
        self.answer_text = str(answer)
        self.all_answers = all_answers
        self.max_len = max_len
        self.seq_len = seq_len
        self.skip_doc = False
        
        self.input_ids = None
        self.attention_mask = None
        self.token_type_ids = None
        self.start_token_idx = None
        self.end_token_idx = None
        self.skip = None
        
    def __str__(self):
        print(np.stack(self.input_ids).shape)
        print(np.stack(self.token_type_ids).shape)
        print(np.stack(self.attention_mask).shape)
        return "<SquadExample>"
        
    def __repr__(self):
        return repr({"input_ids":self.input_ids, 
                     "token_type_ids":self.token_type_ids, 
                     "attention_mask":self.attention_mask,
                     "start_token_idx":self.start_token_idx,
                     "end_token_idx":self.end_token_idx,
                     "skip":self.skip})

    def preprocess(self):
        context = self.context
        question = self.question
        answer = self.answer_text
        start_char_idx = self.start_char_idx

        # Find end character index of answer in context
        end_char_idx = start_char_idx + len(answer)
        if (end_char_idx >= len(context)) or (start_char_idx < 0):
            self.skip_doc = True
            return

        # Mark the character indexes in context that are in answer
        is_char_in_ans = [0] * len(context)
        for idx in range(start_char_idx, end_char_idx):
            is_char_in_ans[idx] = 1
            
        # Tokenize context
        tokenized_context = tokenizer(context, return_offsets_mapping=True)
        
        context_input_ids = tokenized_context.input_ids
        context_offset_mapping = tokenized_context.offset_mapping
        context_attention_mask = tokenized_context.attention_mask
        
        self.context_input_ids = context_input_ids
        self.context_offset_mapping = context_offset_mapping
        
        # Find tokens that were created from answer characters
        ans_token_idx = []
        for idx, (start, end) in enumerate(context_offset_mapping):
            if sum(is_char_in_ans[start:end]) > 0:
                ans_token_idx.append(idx)

#         if len(ans_token_idx) == 0:
#             self.skip_doc = True
#             return
        if (len(ans_token_idx) == 0):
            ans_token_idx = [-1]

        # Find start and end token index for tokens from answer
        start_token_idx = ans_token_idx[0]
        end_token_idx = ans_token_idx[-1]
        
        self.start_token_idx_master = start_token_idx
        self.end_token_idx_master = end_token_idx
        
        # Tokenize question
        tokenized_question = tokenizer("</s> "+question, return_offsets_mapping=True)
        
        ## Crop start and end tokens
        question_input_ids = tokenized_question.input_ids[1:]
        context_input_ids = context_input_ids[1:-1]

        ##
        ## SPLIT UP CONTEXT INTO MULTIPLE QUESTIONS OF max_len
        ##
        
        if seq_len >= len(context_input_ids):
            offsets = [0]
        else:
            ii = 0
            offsets = []
            while (ii+seq_len) <= len(context_input_ids):
                offsets.append(ii)
                ii = ii + round(seq_len/2)
            offsets = offsets + [len(context_input_ids)-seq_len]
        
        list_input_ids = []
        list_start_token_idx = []
        list_end_token_idx = []
        list_attention_mask = []
        list_token_type_ids = []
        list_skip = []
        
        for ii in offsets:
            subcontext_input_ids = [0]+context_input_ids[ii:(ii+seq_len)]+question_input_ids
            subcontext_start_token_idx = start_token_idx - ii
            subcontext_end_token_idx = end_token_idx - ii
            subcontext_padding = [0] * (self.max_len - len(subcontext_input_ids))
            
            subcontext_attention_mask = [1] * len(subcontext_input_ids) + subcontext_padding
            subcontext_token_type_ids = [0] + [0]*len(context_input_ids[ii:(ii+seq_len)]) + [1]*len(question_input_ids) + (np.array(subcontext_padding)+1).tolist()
            subcontext_input_ids = subcontext_input_ids + (np.array(subcontext_padding)+1).tolist()
            
            if (subcontext_start_token_idx >= 0) and (subcontext_end_token_idx < seq_len):
                skip = False
            else:
                subcontext_start_token_idx = 0
                subcontext_end_token_idx = 0
                skip = False
                
            list_input_ids.append(subcontext_input_ids)
            list_attention_mask.append(subcontext_attention_mask)
            list_token_type_ids.append(subcontext_token_type_ids)
            list_start_token_idx.append(subcontext_start_token_idx)
            list_end_token_idx.append(subcontext_end_token_idx)
            list_skip.append(skip)
        
        self.input_ids = (list_input_ids)
        self.attention_mask = (list_attention_mask)
        self.token_type_ids = (list_token_type_ids)
        self.start_token_idx = (list_start_token_idx)
        self.end_token_idx = (list_end_token_idx)
        self.skip = list_skip
        self.example_offset = offsets
        
    def train_examples(self, include_impossible=False):
        for idx, skip_ex in enumerate(self.skip):
            if include_impossible is False:
                if skip_ex is False:
                    yield  {"input_ids":self.input_ids[idx],
                            "token_type_ids":self.token_type_ids[idx],
                            "attention_mask":self.attention_mask[idx],
                            "start_token_idx":self.start_token_idx[idx],
                            "end_token_idx":self.end_token_idx[idx]}
            else:
                yield  {"input_ids":self.input_ids[idx],
                            "token_type_ids":self.token_type_ids[idx],
                            "attention_mask":self.attention_mask[idx],
                            "start_token_idx":self.start_token_idx[idx],
                            "end_token_idx":self.end_token_idx[idx]}
    
    
    def inference_from_onehot(self, pred_start, pred_end):

#         if force_answer == False:
        if (np.max(np.argmax(pred_start, axis=1)) == 0) and (np.max(np.argmax(pred_end, axis=1)) == 0):
            return("", {"all_answers":self.all_answers,
                        "start_token_pred":-1, 
                        "end_token_pred":-1, 
                        "start_char_pred":-1, 
                        "end_char_pred":-1,
                        "start_token":self.start_token_idx_master,
                        "end_token":self.end_token_idx_master,
                        "tokens_pred":set(list([])),
                        "tokens":set(list(range(self.start_token_idx_master,(self.end_token_idx_master+1))))})
        
        seq_len = min(self.seq_len, len(self.context_input_ids))
        
        pred_start_matrix = np.zeros((len(self.input_ids), len(self.context_input_ids)))
        pred_end_matrix = np.zeros((len(self.input_ids), len(self.context_input_ids)))
        
        for idx, value in enumerate(pred_start):
            offset = self.example_offset[idx]+1
            pred_start_sub = pred_start[idx][1:seq_len]
            pred_end_sub   = pred_end[idx][1:seq_len]
            pred_start_matrix[idx,(offset):(offset+seq_len-1)] = pred_start_sub
            pred_end_matrix[idx,(offset):(offset+seq_len-1)] = pred_end_sub
            
        highest_prob = np.argmax(np.max(pred_start_matrix, axis=1) + np.max(pred_end_matrix, axis=1))
        
        top_start = np.argmax(pred_start_matrix[highest_prob,:])
        top_end   = np.argmax(pred_end_matrix[highest_prob,:])
        
#         pred_start = np.max(pred_start_matrix, axis=0)
#         pred_end   = np.max(pred_end_matrix, axis=0)
        
#         top_start = np.argmax(pred_start)
#         top_end = np.argmax(pred_end)
        
        start_char = self.context_offset_mapping[top_start][0]
        end_char = self.context_offset_mapping[top_end][1]
        
        return (self.context[start_char:end_char], {"all_answers":self.all_answers,
                                                    "start_token_pred":top_start, 
                                                    "end_token_pred":top_end, 
                                                    "start_char_pred":start_char, 
                                                    "end_char_pred":end_char,
                                                    "start_token":self.start_token_idx_master,
                                                    "end_token":self.end_token_idx_master,
                                                    "tokens_pred":set(list(range(top_start,(top_end+1)))),
                                                    "tokens":set(list(range(self.start_token_idx_master,(self.end_token_idx_master+1))))})
                
    def model_inference(self, model):
        pred = model.predict([np.stack(self.input_ids),
                      np.stack(self.attention_mask),
                      np.stack(self.token_type_ids)], batch_size=8)
        pred_start = pred[0]
        pred_end   = pred[1]
        
        return self.inference_from_onehot(pred_start, pred_end)
    
    def fake_inference(self):
        pred_start_mat = []
        pred_end_mat = []
        for idx, val in enumerate(self.start_token_idx):
            pred_start = np.zeros_like(np.array(self.input_ids[idx]))
            pred_end = np.zeros_like(np.array(self.input_ids[idx]))
            if self.skip[idx] == False:
                pred_start[val] = 1.0
                pred_end[self.end_token_idx[idx]] = 1.0
            pred_start_mat.append(pred_start)
            pred_end_mat.append(pred_end)
            
        pred_start_mat = np.array(pred_start_mat)
        pred_end_mat = np.array(pred_end_mat)
        
        return self.inference_from_onehot(pred_start_mat,pred_end_mat)
        

def create_squad_examples(raw_data, seq_len, max_len):
    squad_examples = []
    for item in raw_data["data"]:
        for para in item["paragraphs"]:
            context = para["context"]
            for qa in para["qas"]:
                if len(qa["answers"]) > 0:
                    question = qa["question"]
                    answer_text = qa["answers"][0]["text"]
                    all_answers = [_["text"] for _ in qa["answers"]]
                    start_char_idx = qa["answers"][0]["answer_start"]
                    squad_eg = SquadExample(
                        question, context, start_char_idx, answer_text, all_answers, seq_len, max_len
                    )
                    squad_eg.preprocess()
                    squad_examples.append(squad_eg)
                else:
                    question = qa["question"]
                    answer_text = ""
                    all_answers = [""]
                    start_char_idx = 0
                    squad_eg = SquadExample(
                        question, context, start_char_idx, answer_text, all_answers, seq_len, max_len
                    )
                    squad_eg.preprocess()
                    squad_examples.append(squad_eg)
    return squad_examples


def create_inputs_targets(squad_examples, include_impossible=False):
    dataset_dict = {
        "input_ids": [],
        "token_type_ids": [],
        "attention_mask": [],
        "start_token_idx": [],
        "end_token_idx": [],
    }
    for item in squad_examples:
        if item.skip_doc is False:
            for example in item.train_examples(include_impossible):
                for key in dataset_dict:
                    dataset_dict[key].append(np.array(example[key]))
    for key in dataset_dict:
        dataset_dict[key] = np.array(dataset_dict[key])

    x = (
        dataset_dict["input_ids"],
        dataset_dict["token_type_ids"],
        dataset_dict["attention_mask"])
    y = (dataset_dict["start_token_idx"], dataset_dict["end_token_idx"])
    return x, y


def merge_squad_results(squad_examples, start_preds, end_preds):
    ii = 0
    tally = []
    answers = []
    f1_list = []
    for ex in squad_examples:
        if ex.skip_doc is False:
            n_sub = len(ex.skip)
            pred_out = ex.inference_from_onehot(start_preds[ii:(ii+n_sub),:], end_preds[ii:(ii+n_sub),:])
            tally.append(pred_out[0].lower() in [a.lower() for a in ex.all_answers])
            answers.append(pred_out)
            tp = len(pred_out[1]["tokens_pred"].intersection(pred_out[1]["tokens"]))
            fp = len(pred_out[1]["tokens_pred"].difference(pred_out[1]["tokens"]))
            fn = len(pred_out[1]["tokens"].difference(pred_out[1]["tokens_pred"]))
            ii = ii + n_sub
            if tp>0:
                precision = tp/(tp+fp)
                recall=tp/(tp+fn)
                f1_list.append((2*precision*recall)/(precision+recall))
            else:
                f1_list.append(0)
    return (np.mean(tally), 
            np.mean(f1_list), 
            answers)


#train_squad_examples = create_squad_examples(ccc_train, seq_len, max_len)
#x_train, y_train = create_inputs_targets(train_squad_examples)
#print(f"{len(train_squad_examples)} docs, {x_train.shape[0]} training points created.")

test_examples = create_squad_examples(ccc_test, seq_len, max_len)
x_test, y_test = create_inputs_targets(test_examples)
print(f"{len(test_examples)} docs, {x_test[0].shape} test points created.")

valid_examples = create_squad_examples(ccc_valid, seq_len, max_len)
x_valid, y_valid = create_inputs_targets(valid_examples)
print(f"{len(valid_examples)} docs, {x_valid[0].shape} valid points created.")

span_examples = create_squad_examples(ccc_tune, seq_len, max_len)
x_span, y_span = create_inputs_targets(span_examples)
print(f"{len(span_examples)} docs, {x_span[0].shape} span points created.")

soft_examples = create_squad_examples(soft_train, seq_len, max_len)
x_soft, y_soft = create_inputs_targets(soft_examples)
print(f"{len(soft_examples)} docs, {x_soft[0].shape} soft points created.")
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1205 > 512). Running this sequence through the model will result in indexing errors
# 925 docs, (3306, 512) test points created.
# 200 docs, (725, 512) valid points created.
# 25 docs, (25, 512) span points created.
# 2351 docs, (2346, 512) soft points created.

# %% [markdown]
# # Train and Validate

# %%
strategy = tf.distribute.MirroredStrategy()
print("Number of devices: {}".format(strategy.num_replicas_in_sync))

with strategy.scope():
    model = keras.models.load_model('./roberta_base_squad2_512in')
model.summary()
keras.backend.set_value(model.optimizer.learning_rate, (5e-6))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# roberta (TFRobertaMainLayer)    {'pooler_output': (N 124645632   input_1[0][0]
# __________________________________________________________________________________________________
# start_logit (Dense)             (None, 512, 1)       768         roberta[0][0]
# __________________________________________________________________________________________________
# end_logit (Dense)               (None, 512, 1)       768         roberta[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           start_logit[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           end_logit[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 512)          0           flatten[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 512)          0           flatten_1[0][0]
# ==================================================================================================
# Total params: 124,647,168
# Trainable params: 124,647,168
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
pred_start_v, pred_end_v = model.predict((x_valid[0], x_valid[1], x_valid[2]), batch_size=36, verbose=1)
valid_acc = merge_squad_results(valid_examples, pred_start_v, pred_end_v)

pred_start_t, pred_end_t = model.predict((x_test[0], x_test[1], x_test[2]), batch_size=36, verbose=1)
test_acc = merge_squad_results(test_examples, pred_start_t, pred_end_t)

print(f"Validation set accuracy (EM): {valid_acc[0]}")
print(f"Test set accuracy (EM): {test_acc[0]}")
print(f"Validation set F1: {valid_acc[1]}")
print(f"Test set F1: {test_acc[1]}")
# Out:
# 21/21 [==============================] - 5s 262ms/step
# 92/92 [==============================] - 26s 285ms/step
# Validation set accuracy (EM): 0.19
# Test set accuracy (EM): 0.16972972972972972
# Validation set F1: 0.27271624189581933
# Test set F1: 0.2658847892310077

# %%
# validation_loss = []
# validation_accuracy = []
# batch = []
log_list = []

batch_size = 12


for ii in range(75):
    print(f"ITERATION: {ii} of 75.")
    
#     valid_loss = model.evaluate((x_valid[0],
#                             x_valid[1],
#                             x_valid[2]),
#                             y_valid,
#                            verbose=1,
#                            batch_size=36,
#                            return_dict=True)
#     pred_start, pred_end = model.predict((x_valid[0], x_valid[1], x_valid[2]), batch_size=36, verbose=1)
#     valid_acc = merge_squad_results(valid_examples, pred_start, pred_end)[0]
    
#     print(f"ACCURACY: {valid_acc}")
    
#     validation_loss.append(valid_loss)
#     validation_accuracy.append(valid_acc)
#     batch.append(ii*2)
    
    soft_ii = np.random.choice(range(x_soft[0].shape[0]), batch_size, replace=True)
    
    model.fit(
        (x_soft[0][soft_ii,:], 
         x_soft[1][soft_ii,:], 
         x_soft[2][soft_ii,:]),
        (y_soft[0][soft_ii],
         y_soft[1][soft_ii]),
        epochs=1,  # Just one epoch for the rough data
        verbose=1,
        batch_size=batch_size,  # Made this smaller. Bump up.
    )

    soft_ii = np.random.choice(range(x_soft[0].shape[0]), batch_size, replace=True)
    
    log = model.fit(
        (x_soft[0][soft_ii,:], 
         x_soft[1][soft_ii,:], 
         x_soft[2][soft_ii,:]),
        (y_soft[0][soft_ii],
         y_soft[1][soft_ii]),
        epochs=1,  # For demonstration, 3 epochs are recommended
        verbose=1,
        batch_size=batch_size,  # Made this smaller. Bump up.
        validation_data=((x_valid[0],
                            x_valid[1],
                            x_valid[2]),
                            y_valid[0]),
                    validation_batch_size=36
    )
    
    log_list.append(log.history)
    
# valid_loss = model.evaluate((x_valid[0],
#                             x_valid[1],
#                             x_valid[2]),
#                             y_valid[0],
#                            verbose=1,
#                            batch_size=36,
#                            return_dict=True)
# pred_start, pred_end = model.predict((x_valid[0], x_valid[1], x_valid[2]), batch_size=36, verbose=1)
# valid_acc = merge_squad_results(valid_examples, pred_start, pred_end)[0]

# validation_loss.append(valid_loss)
# validation_accuracy.append(valid_acc)
# batch.append(ii*2)
# Out:
# ITERATION: 0 of 75.
# WARNING:tensorflow:5 out of the last 5 calls to <function recreate_function.<locals>.restored_function_body at 0x7feb4c3182f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function recreate_function.<locals>.restored_function_body at 0x7feb4c3182f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# INFO:tensorflow:batch_all_reduce: 198 all-reduces with algorithm = nccl, num_packs = 1
# WARNING:tensorflow:Efficient allreduce is not supported for 3 IndexedSlices
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 198 all-reduces with algorithm = nccl, num_packs = 1
# WARNING:tensorflow:Efficient allreduce is not supported for 3 IndexedSlices
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:GPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1').
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 2.5509 - activation_5_loss: 2.3423 - loss: 4.8932
# 1/1 [==============================] - 9s 9s/step - activation_4_loss: 1.4305 - activation_5_loss: 1.9798 - loss: 3.4103 - val_activation_4_loss: 1.2720 - val_activation_5_loss: 2.8792 - val_loss: 4.1511
# ITERATION: 1 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.8072 - activation_5_loss: 0.6467 - loss: 1.4539
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.9349 - activation_5_loss: 1.1197 - loss: 2.0546 - val_activation_4_loss: 1.2910 - val_activation_5_loss: 2.9012 - val_loss: 4.1923
# ITERATION: 2 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 1.8078 - activation_5_loss: 0.8037 - loss: 2.6116
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 1.0956 - activation_5_loss: 1.4278 - loss: 2.5234 - val_activation_4_loss: 1.3513 - val_activation_5_loss: 2.9644 - val_loss: 4.3157
# ITERATION: 3 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 1.5765 - activation_5_loss: 1.5109 - loss: 3.0874
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.7741 - activation_5_loss: 1.5136 - loss: 2.2877 - val_activation_4_loss: 1.4314 - val_activation_5_loss: 3.0360 - val_loss: 4.4674
# ITERATION: 4 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 1.0505 - activation_5_loss: 0.6906 - loss: 1.7411
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 1.4297 - activation_5_loss: 0.8908 - loss: 2.3205 - val_activation_4_loss: 1.5162 - val_activation_5_loss: 3.1132 - val_loss: 4.6294
# ITERATION: 5 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 1.0911 - activation_5_loss: 0.7426 - loss: 1.8337
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.7550 - activation_5_loss: 0.4296 - loss: 1.1846 - val_activation_4_loss: 1.5980 - val_activation_5_loss: 3.1882 - val_loss: 4.7862
# ITERATION: 6 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 1.5107 - activation_5_loss: 0.3419 - loss: 1.8525
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.9315 - activation_5_loss: 0.3666 - loss: 1.2980 - val_activation_4_loss: 1.6757 - val_activation_5_loss: 3.2618 - val_loss: 4.9374
# ITERATION: 7 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 1.0444 - activation_5_loss: 0.5771 - loss: 1.6215
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.5416 - activation_5_loss: 0.3704 - loss: 0.9120 - val_activation_4_loss: 1.7472 - val_activation_5_loss: 3.3354 - val_loss: 5.0826
# ITERATION: 8 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 1.0240 - activation_5_loss: 0.4010 - loss: 1.4250
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 1.1802 - activation_5_loss: 1.1776 - loss: 2.3578 - val_activation_4_loss: 1.8088 - val_activation_5_loss: 3.4006 - val_loss: 5.2094
# ITERATION: 9 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.7212 - activation_5_loss: 0.1891 - loss: 0.9102
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.6092 - activation_5_loss: 0.8612 - loss: 1.4704 - val_activation_4_loss: 1.8688 - val_activation_5_loss: 3.4647 - val_loss: 5.3336
# ITERATION: 10 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.9323 - activation_5_loss: 0.4704 - loss: 1.4027
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.8846 - activation_5_loss: 0.5992 - loss: 1.4838 - val_activation_4_loss: 1.9382 - val_activation_5_loss: 3.5382 - val_loss: 5.4764
# ITERATION: 11 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.5606 - activation_5_loss: 0.8367 - loss: 1.3973
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.8550 - activation_5_loss: 0.3653 - loss: 1.2203 - val_activation_4_loss: 1.9901 - val_activation_5_loss: 3.5953 - val_loss: 5.5854
# ITERATION: 12 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.4729 - activation_5_loss: 0.1310 - loss: 0.6038
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.5999 - activation_5_loss: 0.2970 - loss: 0.8970 - val_activation_4_loss: 2.0319 - val_activation_5_loss: 3.6454 - val_loss: 5.6773
# ITERATION: 13 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.8101 - activation_5_loss: 0.6731 - loss: 1.4832
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 1.3309 - activation_5_loss: 0.5940 - loss: 1.9249 - val_activation_4_loss: 2.0696 - val_activation_5_loss: 3.6888 - val_loss: 5.7584
# ITERATION: 14 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.7491 - activation_5_loss: 0.5979 - loss: 1.3470
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.5517 - activation_5_loss: 0.2167 - loss: 0.7684 - val_activation_4_loss: 2.1010 - val_activation_5_loss: 3.7257 - val_loss: 5.8267
# ITERATION: 15 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.6042 - activation_5_loss: 0.2946 - loss: 0.8989
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.6982 - activation_5_loss: 0.3175 - loss: 1.0158 - val_activation_4_loss: 2.1285 - val_activation_5_loss: 3.7602 - val_loss: 5.8887
# ITERATION: 16 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.4390 - activation_5_loss: 0.3354 - loss: 0.7744
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.2593 - activation_5_loss: 0.0489 - loss: 0.3082 - val_activation_4_loss: 2.1522 - val_activation_5_loss: 3.7920 - val_loss: 5.9442
# ITERATION: 17 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.8518 - activation_5_loss: 0.7899 - loss: 1.6417
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.2280 - activation_5_loss: 0.0526 - loss: 0.2806 - val_activation_4_loss: 2.1816 - val_activation_5_loss: 3.8325 - val_loss: 6.0141
# ITERATION: 18 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.3745 - activation_5_loss: 0.2053 - loss: 0.5799
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.8660 - activation_5_loss: 0.9113 - loss: 1.7773 - val_activation_4_loss: 2.2057 - val_activation_5_loss: 3.8659 - val_loss: 6.0717
# ITERATION: 19 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.4777 - activation_5_loss: 0.2763 - loss: 0.7540
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.4405 - activation_5_loss: 0.2804 - loss: 0.7210 - val_activation_4_loss: 2.2277 - val_activation_5_loss: 3.8950 - val_loss: 6.1228
# ITERATION: 20 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.5955 - activation_5_loss: 0.5378 - loss: 1.1332
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.3053 - activation_5_loss: 0.1935 - loss: 0.4988 - val_activation_4_loss: 2.2450 - val_activation_5_loss: 3.9187 - val_loss: 6.1637
# ITERATION: 21 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.3668 - activation_5_loss: 0.5044 - loss: 0.8712
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.4088 - activation_5_loss: 0.6499 - loss: 1.0587 - val_activation_4_loss: 2.2569 - val_activation_5_loss: 3.9370 - val_loss: 6.1940
# ITERATION: 22 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.7162 - activation_5_loss: 0.3222 - loss: 1.0384
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 1.0273 - activation_5_loss: 0.7792 - loss: 1.8065 - val_activation_4_loss: 2.2646 - val_activation_5_loss: 3.9513 - val_loss: 6.2158
# ITERATION: 23 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.5702 - activation_5_loss: 0.7541 - loss: 1.3243
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.3140 - activation_5_loss: 0.8420 - loss: 1.1561 - val_activation_4_loss: 2.2683 - val_activation_5_loss: 3.9540 - val_loss: 6.2223
# ITERATION: 24 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.4968 - activation_5_loss: 0.2228 - loss: 0.7197
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.8667 - activation_5_loss: 0.2650 - loss: 1.1317 - val_activation_4_loss: 2.2745 - val_activation_5_loss: 3.9619 - val_loss: 6.2365
# ITERATION: 25 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.8419 - activation_5_loss: 0.6836 - loss: 1.5255
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.3637 - activation_5_loss: 0.2743 - loss: 0.6380 - val_activation_4_loss: 2.2774 - val_activation_5_loss: 3.9650 - val_loss: 6.2424
# ITERATION: 26 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.4633 - activation_5_loss: 0.7303 - loss: 1.1936
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.2114 - activation_5_loss: 0.0851 - loss: 0.2965 - val_activation_4_loss: 2.2770 - val_activation_5_loss: 3.9601 - val_loss: 6.2371
# ITERATION: 27 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.3753 - activation_5_loss: 0.4238 - loss: 0.7991
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.3267 - activation_5_loss: 0.4218 - loss: 0.7484 - val_activation_4_loss: 2.2808 - val_activation_5_loss: 3.9578 - val_loss: 6.2386
# ITERATION: 28 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.8809 - activation_5_loss: 0.7570 - loss: 1.6379
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.6206 - activation_5_loss: 0.3955 - loss: 1.0161 - val_activation_4_loss: 2.2981 - val_activation_5_loss: 3.9677 - val_loss: 6.2658
# ITERATION: 29 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.8935 - activation_5_loss: 0.3274 - loss: 1.2208
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.4985 - activation_5_loss: 0.4107 - loss: 0.9091 - val_activation_4_loss: 2.3179 - val_activation_5_loss: 3.9827 - val_loss: 6.3006
# ITERATION: 30 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 1.0929 - activation_5_loss: 0.3002 - loss: 1.3931
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.5393 - activation_5_loss: 0.3843 - loss: 0.9236 - val_activation_4_loss: 2.3500 - val_activation_5_loss: 4.0142 - val_loss: 6.3643
# ITERATION: 31 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0899 - activation_5_loss: 0.0283 - loss: 0.1182
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.2315 - activation_5_loss: 0.0969 - loss: 0.3284 - val_activation_4_loss: 2.3814 - val_activation_5_loss: 4.0472 - val_loss: 6.4286
# ITERATION: 32 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.7140 - activation_5_loss: 0.4284 - loss: 1.1424
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.8878 - activation_5_loss: 0.1654 - loss: 1.0531 - val_activation_4_loss: 2.4082 - val_activation_5_loss: 4.0776 - val_loss: 6.4859
# ITERATION: 33 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.6807 - activation_5_loss: 0.2385 - loss: 0.9193
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.3466 - activation_5_loss: 0.2560 - loss: 0.6026 - val_activation_4_loss: 2.4344 - val_activation_5_loss: 4.1109 - val_loss: 6.5452
# ITERATION: 34 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.4548 - activation_5_loss: 0.4449 - loss: 0.8997
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.5030 - activation_5_loss: 0.2121 - loss: 0.7151 - val_activation_4_loss: 2.4706 - val_activation_5_loss: 4.1569 - val_loss: 6.6275
# ITERATION: 35 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.7546 - activation_5_loss: 0.3100 - loss: 1.0646
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.6244 - activation_5_loss: 0.2894 - loss: 0.9138 - val_activation_4_loss: 2.5013 - val_activation_5_loss: 4.1954 - val_loss: 6.6968
# ITERATION: 36 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.3790 - activation_5_loss: 0.3807 - loss: 0.7597
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.2457 - activation_5_loss: 0.4196 - loss: 0.6652 - val_activation_4_loss: 2.5235 - val_activation_5_loss: 4.2253 - val_loss: 6.7488
# ITERATION: 37 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.6284 - activation_5_loss: 0.3980 - loss: 1.0264
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.4002 - activation_5_loss: 0.1740 - loss: 0.5742 - val_activation_4_loss: 2.5380 - val_activation_5_loss: 4.2464 - val_loss: 6.7843
# ITERATION: 38 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.5536 - activation_5_loss: 0.2159 - loss: 0.7696
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 1.1310 - activation_5_loss: 0.5582 - loss: 1.6892 - val_activation_4_loss: 2.5615 - val_activation_5_loss: 4.2779 - val_loss: 6.8394
# ITERATION: 39 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.6512 - activation_5_loss: 0.3055 - loss: 0.9567
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.3262 - activation_5_loss: 0.2314 - loss: 0.5576 - val_activation_4_loss: 2.5968 - val_activation_5_loss: 4.3207 - val_loss: 6.9176
# ITERATION: 40 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.1542 - activation_5_loss: 0.1419 - loss: 0.2960
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.3339 - activation_5_loss: 0.2472 - loss: 0.5811 - val_activation_4_loss: 2.6215 - val_activation_5_loss: 4.3557 - val_loss: 6.9772
# ITERATION: 41 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.2353 - activation_5_loss: 0.1323 - loss: 0.3676
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.6244 - activation_5_loss: 0.2712 - loss: 0.8956 - val_activation_4_loss: 2.6412 - val_activation_5_loss: 4.3881 - val_loss: 7.0293
# ITERATION: 42 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.8053 - activation_5_loss: 0.4546 - loss: 1.2599
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.2025 - activation_5_loss: 0.0783 - loss: 0.2808 - val_activation_4_loss: 2.6675 - val_activation_5_loss: 4.4289 - val_loss: 7.0964
# ITERATION: 43 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.8751 - activation_5_loss: 0.9798 - loss: 1.8549
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.3111 - activation_5_loss: 0.2268 - loss: 0.5379 - val_activation_4_loss: 2.7065 - val_activation_5_loss: 4.4778 - val_loss: 7.1843
# ITERATION: 44 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.7716 - activation_5_loss: 0.2272 - loss: 0.9987
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.4479 - activation_5_loss: 0.6112 - loss: 1.0591 - val_activation_4_loss: 2.7288 - val_activation_5_loss: 4.5104 - val_loss: 7.2392
# ITERATION: 45 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.3688 - activation_5_loss: 0.2228 - loss: 0.5916
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.3869 - activation_5_loss: 0.1386 - loss: 0.5254 - val_activation_4_loss: 2.7515 - val_activation_5_loss: 4.5426 - val_loss: 7.2941
# ITERATION: 46 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.3741 - activation_5_loss: 0.3307 - loss: 0.7048
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.2666 - activation_5_loss: 0.2458 - loss: 0.5123 - val_activation_4_loss: 2.7736 - val_activation_5_loss: 4.5690 - val_loss: 7.3425
# ITERATION: 47 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.5118 - activation_5_loss: 0.3614 - loss: 0.8732
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.2020 - activation_5_loss: 0.1115 - loss: 0.3135 - val_activation_4_loss: 2.7935 - val_activation_5_loss: 4.5917 - val_loss: 7.3852
# ITERATION: 48 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.3298 - activation_5_loss: 0.2259 - loss: 0.5557
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.8699 - activation_5_loss: 0.1296 - loss: 0.9995 - val_activation_4_loss: 2.8070 - val_activation_5_loss: 4.6102 - val_loss: 7.4172
# ITERATION: 49 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.6065 - activation_5_loss: 0.3818 - loss: 0.9883
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.3094 - activation_5_loss: 0.1498 - loss: 0.4592 - val_activation_4_loss: 2.8127 - val_activation_5_loss: 4.6238 - val_loss: 7.4365
# ITERATION: 50 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.3056 - activation_5_loss: 0.5042 - loss: 0.8098
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.2701 - activation_5_loss: 0.2286 - loss: 0.4987 - val_activation_4_loss: 2.8309 - val_activation_5_loss: 4.6488 - val_loss: 7.4798
# ITERATION: 51 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.5416 - activation_5_loss: 0.0761 - loss: 0.6177
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.4553 - activation_5_loss: 0.2777 - loss: 0.7330 - val_activation_4_loss: 2.8457 - val_activation_5_loss: 4.6732 - val_loss: 7.5190
# ITERATION: 52 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.1907 - activation_5_loss: 0.1521 - loss: 0.3427
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.5564 - activation_5_loss: 0.5111 - loss: 1.0675 - val_activation_4_loss: 2.8706 - val_activation_5_loss: 4.7053 - val_loss: 7.5759
# ITERATION: 53 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.1809 - activation_5_loss: 0.0653 - loss: 0.2461
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.4053 - activation_5_loss: 0.7250 - loss: 1.1302 - val_activation_4_loss: 2.8914 - val_activation_5_loss: 4.7318 - val_loss: 7.6232
# ITERATION: 54 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.5992 - activation_5_loss: 0.6417 - loss: 1.2409
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0878 - activation_5_loss: 0.0428 - loss: 0.1306 - val_activation_4_loss: 2.9151 - val_activation_5_loss: 4.7569 - val_loss: 7.6720
# ITERATION: 55 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.3311 - activation_5_loss: 0.1299 - loss: 0.4611
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.9645 - activation_5_loss: 0.6695 - loss: 1.6341 - val_activation_4_loss: 2.9419 - val_activation_5_loss: 4.7847 - val_loss: 7.7266
# ITERATION: 56 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.6528 - activation_5_loss: 0.1981 - loss: 0.8508
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 1.2260 - activation_5_loss: 0.3751 - loss: 1.6010 - val_activation_4_loss: 2.9687 - val_activation_5_loss: 4.8108 - val_loss: 7.7796
# ITERATION: 57 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.7082 - activation_5_loss: 0.5307 - loss: 1.2389
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.4915 - activation_5_loss: 0.2264 - loss: 0.7179 - val_activation_4_loss: 2.9806 - val_activation_5_loss: 4.8232 - val_loss: 7.8038
# ITERATION: 58 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 1.3266 - activation_5_loss: 0.8624 - loss: 2.1890
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.3108 - activation_5_loss: 0.1714 - loss: 0.4823 - val_activation_4_loss: 2.9752 - val_activation_5_loss: 4.8092 - val_loss: 7.7845
# ITERATION: 59 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.2193 - activation_5_loss: 0.2286 - loss: 0.4479
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.3281 - activation_5_loss: 0.1524 - loss: 0.4805 - val_activation_4_loss: 2.9810 - val_activation_5_loss: 4.8096 - val_loss: 7.7905
# ITERATION: 60 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.3012 - activation_5_loss: 0.2450 - loss: 0.5461
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 1.1151 - activation_5_loss: 0.4959 - loss: 1.6110 - val_activation_4_loss: 2.9879 - val_activation_5_loss: 4.8135 - val_loss: 7.8014
# ITERATION: 61 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.9026 - activation_5_loss: 0.9267 - loss: 1.8294
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.0995 - activation_5_loss: 0.0876 - loss: 0.1871 - val_activation_4_loss: 3.0180 - val_activation_5_loss: 4.8310 - val_loss: 7.8489
# ITERATION: 62 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.4411 - activation_5_loss: 0.2736 - loss: 0.7147
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.8894 - activation_5_loss: 0.5878 - loss: 1.4772 - val_activation_4_loss: 3.0348 - val_activation_5_loss: 4.8340 - val_loss: 7.8688
# ITERATION: 63 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.7603 - activation_5_loss: 0.3377 - loss: 1.0979
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.9751 - activation_5_loss: 0.5853 - loss: 1.5604 - val_activation_4_loss: 3.0465 - val_activation_5_loss: 4.8357 - val_loss: 7.8821
# ITERATION: 64 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.2441 - activation_5_loss: 0.0266 - loss: 0.2707
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.1337 - activation_5_loss: 0.0999 - loss: 0.2336 - val_activation_4_loss: 3.0694 - val_activation_5_loss: 4.8497 - val_loss: 7.9191
# ITERATION: 65 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.5233 - activation_5_loss: 0.2856 - loss: 0.8089
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.7595 - activation_5_loss: 0.6801 - loss: 1.4396 - val_activation_4_loss: 3.0949 - val_activation_5_loss: 4.8669 - val_loss: 7.9617
# ITERATION: 66 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.4368 - activation_5_loss: 0.0571 - loss: 0.4939
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 1.7497 - activation_5_loss: 0.2620 - loss: 2.0118 - val_activation_4_loss: 3.1187 - val_activation_5_loss: 4.8898 - val_loss: 8.0086
# ITERATION: 67 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.7860 - activation_5_loss: 0.4820 - loss: 1.2680
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.6453 - activation_5_loss: 0.2354 - loss: 0.8807 - val_activation_4_loss: 3.1608 - val_activation_5_loss: 4.9339 - val_loss: 8.0947
# ITERATION: 68 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.6770 - activation_5_loss: 0.6160 - loss: 1.2930
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.4066 - activation_5_loss: 0.1702 - loss: 0.5768 - val_activation_4_loss: 3.2064 - val_activation_5_loss: 4.9834 - val_loss: 8.1898
# ITERATION: 69 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.0736 - activation_5_loss: 0.0315 - loss: 0.1052
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.4640 - activation_5_loss: 0.5956 - loss: 1.0595 - val_activation_4_loss: 3.2473 - val_activation_5_loss: 5.0280 - val_loss: 8.2753
# ITERATION: 70 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 1.8295 - activation_5_loss: 0.4917 - loss: 2.3212
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.1327 - activation_5_loss: 0.0752 - loss: 0.2079 - val_activation_4_loss: 3.2537 - val_activation_5_loss: 5.0441 - val_loss: 8.2978
# ITERATION: 71 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.3982 - activation_5_loss: 0.1588 - loss: 0.5570
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.7751 - activation_5_loss: 0.5554 - loss: 1.3305 - val_activation_4_loss: 3.2648 - val_activation_5_loss: 5.0646 - val_loss: 8.3294
# ITERATION: 72 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.1507 - activation_5_loss: 0.0699 - loss: 0.2206
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.5614 - activation_5_loss: 0.0661 - loss: 0.6275 - val_activation_4_loss: 3.2838 - val_activation_5_loss: 5.0912 - val_loss: 8.3750
# ITERATION: 73 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.7267 - activation_5_loss: 0.3814 - loss: 1.1081
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.2587 - activation_5_loss: 0.2723 - loss: 0.5310 - val_activation_4_loss: 3.3085 - val_activation_5_loss: 5.1249 - val_loss: 8.4334
# ITERATION: 74 of 75.
# 1/1 [==============================] - 0s 2ms/step - activation_4_loss: 0.6262 - activation_5_loss: 0.3436 - loss: 0.9698
# 1/1 [==============================] - 6s 6s/step - activation_4_loss: 0.6097 - activation_5_loss: 0.2988 - loss: 0.9084 - val_activation_4_loss: 3.3200 - val_activation_5_loss: 5.1435 - val_loss: 8.4635

# %%
import pandas as pd

stats = pd.DataFrame(log_list)
stats.to_csv("results/roberta_base_squad2_512in_softspans_75ii.csv")

# %%
pred_start_v, pred_end_v = model.predict((x_valid[0], x_valid[1], x_valid[2]), batch_size=36, verbose=1)
valid_acc = merge_squad_results(valid_examples, pred_start_v, pred_end_v)

pred_start_t, pred_end_t = model.predict((x_test[0], x_test[1], x_test[2]), batch_size=36, verbose=1)
test_acc = merge_squad_results(test_examples, pred_start_t, pred_end_t)

print(f"Validation set accuracy (EM): {valid_acc[0]}")
print(f"Test set accuracy (EM): {test_acc[0]}")
print(f"Validation set F1: {valid_acc[1]}")
print(f"Test set F1: {test_acc[1]}")

pd.DataFrame([{"model":"roberta_base_squad2_512in_softspans_75ii",
              "f1_valid":valid_acc[1],"f1_test":test_acc[1],
              "em_valid":valid_acc[0],"em_test":test_acc[0]}]).to_csv("results/roberta_f1v_f1t_emv_emt.csv",mode="a",header=False)
# Out:
# 21/21 [==============================] - 6s 280ms/step
# 92/92 [==============================] - 28s 302ms/step
# Validation set accuracy (EM): 0.555
# Test set accuracy (EM): 0.5102702702702703
# Validation set F1: 0.5149068680330816
# Test set F1: 0.5012137652086145

# %%
model.save("roberta_base_squad2_512in_softspans_75ii")
# Out:
# WARNING:tensorflow:7 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7feb4c3182f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:7 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7feb4c3182f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:From /home/ben/anaconda3/envs/distant_crowds/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: roberta_base_squad2_512in_softspans_75ii/assets
